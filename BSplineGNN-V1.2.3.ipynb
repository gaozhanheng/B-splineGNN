# %% [markdown]
# # 修改自V1.2.2  20251229
#
# # <font color=red> 主要是用来写论文的，预测部分的代码改动较大</font>

# %% [markdown]
# # 模型输入为规范化之后的数据点，输出为控制顶点（未反规范化）
# # 因此，对模型的使用必须是：<font color=red>1、数据数据必须通过PointCloudDataset（其中包含数据点规范化、采样等操作），2、控制顶点预测必须通过apply_trained_model函数（其中包括控制顶点饭规范化操作）3、要确保规范化和反规范化函数的匹配</font>

# %% [markdown]
# # 模型定义

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torch_geometric.data import Dataset, Data
from torch_geometric.nn import MessagePassing
from torch_geometric.utils import add_self_loops
from torch_geometric.loader import DataLoader

import time,datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# ================== 改进的GNN模型 =================
class ControlUpdateLayer(MessagePassing):
    """基于基函数加权的残差传播层 """
    '''
    图神经网络的parameter在哪里定义的？
    难道是gru中才有吗？
    通过在forward中奖gru注释掉发现，BSplineGNN中的ctrlfeat就是相同的，从而可知：本层的可训练参数在gru中
    '''

    def __init__(self, hidden_dim,useGru=False,useAttn=False):
        '''
        通过后面调用过程看到，hiddendim=256
        这个hiddendim必须和BsplineGNN的hidendim一样，否则程序编译就有问题了。
        
        是否使用gru和attn模块，对于最终的迭代结果似乎影响不大，都是0.001左右的精度，但加上gru和/或attn后，仅3次epoch就迭代到了0.00x的级别，且第一次的迭代（epoch=1）的误差未0.x级别。速度上可进行比较一下。
        '''
        super().__init__(aggr='add', flow='source_to_target')
        self.hidden_dim = hidden_dim
        
        HighlightPrint('ControlUpdateLayer key parameters:')
        
        
        self.useGru = useGru
        self.gru = nn.GRUCell(hidden_dim, hidden_dim) #使用gru效果显著：3个epoches就迭代到了0.0014
        if self.useGru:
            print('\tUsing Gru in ControlUpdateLayer')
        else:
            print('\tNot using Gru in ControlUpdateLayer')
        
        # 据论文中说，不用注意力机制其实效果更好，所以王基栋将其注释掉了。但我测试之后发现，其实效果挺好的。
        self.useAttn = useAttn
        self.attn = nn.Sequential( 
            nn.Linear(hidden_dim + 1, 1),  # x_j||basis_weight
            nn.LeakyReLU(0.2)
        )
        if self.useAttn:
            print('\tUsing attention in ControlUpdateLayerr.message')
        else:
            print('\tNot using attention in ControlUpdateLayerr.message')

    def forward(self, point_feat, edge_index, edge_attr, num_src_nodes, num_dst_nodes): # 
        '''
        从后续可以看到，num_src_nodes是数据点个数，num_dst_nodes是控制顶点个数
        point_feat是通过计算得到的每个node的feature，可以是原始的每个node的坐标，也可以是经过一些计算之后的feature向量。反正只要是合理的图结构即可.注意，通过print shape和查看代码，pointfeat是数据点的feature，其存储的是数据点与B样条曲线之间逐点  !差异向量!,feature 的维度是256
        edge_attr是每个数据点与其对应控制顶点之间的基函数系数，预先计算好
        param point_feat: 数据点与B样条曲线之间差异（numdata × 2）经过mlp之后的feature（numdata × hiddendim）。例：131 × 256。131是数据点个数，256是设定的feature的维度。
        param edge_index:  例：2 × 524
        param edge_attr:   例：524 × 3
        param num_src_nodes: 源node个数。此处是数据点个数 例：131
        param num_dst_nodes: 目的node个数。此处是控制点个数。 例：30
        return: 返回的是numdstnodes × feature的向量，feature可以是256也可以是别的，取决于gru的设置。
        '''
#         print('num_src_nodes:',num_src_nodes)
#         print('num_dst_nodes:',num_dst_nodes)
#         print('point feat shape:',point_feat.shape)
#         print('edge_index shape:',edge_index.shape)
#         print('edge_attr shape:',edge_attr.shape)

        h = torch.zeros(num_dst_nodes, self.hidden_dim).to(point_feat.device)
    
        aggr_msg = self.propagate(edge_index, x=point_feat, edge_attr=edge_attr,
                                  size=(num_src_nodes, num_dst_nodes)) # size的作用是什么？
        
        if self.useGru:# 使用gru模块
            h = self.gru(aggr_msg, h)# aggr_mst应该是输入信息，h？
        else:# 不适用gru模块
            h = aggr_msg# 去掉gru，直接用二分图的聚合结果
            
        
#         print(h.shape) # 30 × 256
#         print(aggr_msg.shape) # also 30 × 256
#         h = aggr_msg # 为了验证这里其实在传递、聚合、更新的过程中并没有可训练的参数，只是在更新之后用一个gru层进行处理，才产生了可训练参数。验证结论：确实如此。
        return h

    def message(self, x_j, edge_attr): # 
        basis_weight = edge_attr[:, 0].unsqueeze(-1)
        msg = x_j * basis_weight

        if not self.useAttn:# 不用图注意力机制
            alpha = 1
        else: # # 使用 图注意力机制
            alpha = torch.sigmoid(self.attn(torch.cat([x_j, basis_weight], dim=1)))

        return  alpha * msg

    def update(self, aggr_out): #
        return F.layer_norm(aggr_out, (aggr_out.size(-1),)) #什么作用？不加行不行？

    
    
    
    

class BSplineGNN(nn.Module):
    def __init__(self, k=3, hidden_dim=256, num_iter=5,num_GNN_layers = 5,ctlptUpdateSpeed = 10):
        super().__init__()
        self.k = k # B样条曲线次数
        self.iterations = num_iter  # 一共的迭代次数。见forward
        self.nlayers = num_GNN_layers # ControlUpdateLayer的层数
        self.ctlptUpdateSpeed = ctlptUpdateSpeed # 在forword中对控制顶点与控制顶点delta的累加的速度
        HighlightPrint('BSplineGNN key parameters:')
        print(f'\tnum iterations:{num_iter}')
        print(f'\tnum Gnn layers:{num_GNN_layers}')

        # 节点特征初始化网络
        # mlp。 
#         self.ctrl_emb = nn.Sequential(
#             nn.Linear(2, hidden_dim), # 
#             nn.LayerNorm(hidden_dim)
#         )
        
        # mlp
        # 把point residual 编码
        self.point_emb = nn.Sequential(
            nn.Linear(2, hidden_dim), # 
            nn.LayerNorm(hidden_dim)
        )

        # 多个图卷积网络
        useGru = False
        useAttn = False
        self.gnn_layers = nn.ModuleList([
            ControlUpdateLayer(hidden_dim,useGru=useGru,useAttn=useAttn) for _ in range(num_GNN_layers)])

        # 从图卷积网络的输出映射到控制顶点改变量的mlp
        # 也就是对control delta的feature的decoding
        self.ctrl_update = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.ReLU(),
            nn.Linear(hidden_dim // 2, 2),
            nn.Tanh()  # 限制输出范围为[-1,1]范围。真的合适吗？数据点范围是多少？不限制范围行不行
        )

    def find_span(self, u_val, knots, num_ctrl):
        """
        节点区间查找
        给定一个u，给定一个节点向量，查找u位于节点向量的第几个区间内。
        u\in k[returnval,returnval+1]区间内。
        其实完全不必要用二分法，一个一个查就行了，或者用一些数学的技巧，或者用geomdl库现成的函数
        但不必改了，除非将来有效率方面的考虑
        """
        n = num_ctrl - 1  # 控制点索引上限
        if u_val >= 1.0 - 1e-6:
            return n - self.k # ？ 应为n - 1 吧？
        low = self.k # √ 第一个非退化节点区间
        high = num_ctrl
        mid = (low + high) // 2
        while u_val < knots[mid] or u_val >= knots[mid + 1]:
            '''
            退出此循环的时候，满足条件：knots[mid] ≤ u_val < knots[mid + 1]，即恰好找到了所在的节点区间
            '''
            if u_val < knots[mid]:
                high = mid
            else:
                low = mid
            mid = (low + high) // 2
        return mid

    def calculate_basis(self, u, indices, knots, num_ctrl):
        """
        向量化基函数计算（优化计算速度）
        这里面u可能是个tensor，因此有可能是批量计算。从后面bipartitygraph中的使用来看，其实不是张量，就是
        普通的数。其存储的是某数据点的参数值。
        
        计算B样条基函数在u点的非零的函数值。对于任意一个u，其涉及的非零B样条基函数个数是
        k+1个（[span-k,span]），但在计算的时候我们看到，其是通过temp把整个节点向量的函数值递推了一遍，然后
        在获取返回值的时候用indices提取需要的函数值
        
        param u: possibly a tensor. 待计算的参数u。我们就是要计算所有在u点非零的B样条基函数的函数值
        param indices: 与u相关的B样条基函数的下标，即[span-k,span]
        param knots: 全部B样条基函数是在哪个节点向量上定义的
        param num_ctrl:顾名思义
        """
        device = knots.device
        u_tensor = u if isinstance(u, torch.Tensor) else torch.tensor(u, device=device)

        basis = torch.zeros(num_ctrl + self.k, device=device) # 可能代表knots的全部节点区间（恰好比节点数少1）
        span = self.find_span(u_tensor.item(), knots, num_ctrl) # 此变量可能为tensor
        basis[span] = 1.0 # 在若干个节点区间上置1

        # 递推计算的向量化实现
        # 应该就是de Boor-Cox公式的实现
        for p in range(1, self.k + 1):
            temp = torch.zeros(num_ctrl + self.k - p, device=device)
            valid_start = max(0, span - p)
            valid_end = min(span + 1, len(temp))
            valid_indices = slice(valid_start, valid_end) # 生成切片数据，可用于做数组下标

            left = knots[valid_indices.start + p: valid_indices.stop + p] - knots[valid_indices]
            right = (knots[valid_indices.start + p + 1: valid_indices.stop + p + 1] -
                     knots[valid_indices.start + 1: valid_indices.stop + 1])

            term_left = (u_tensor - knots[valid_indices]) / left * basis[valid_indices]
            term_right = ((knots[valid_indices.start + p + 1: valid_indices.stop + p + 1] - u_tensor) / right *
                          basis[valid_indices.start + 1: valid_indices.stop + 1])

            temp[valid_indices] = torch.nan_to_num(term_left, 0) + torch.nan_to_num(term_right, 0) # 如果出现 0/0，就用这个函数变为0，比较安全
            basis = temp

        return basis[indices]

    def build_bipartite_graph(self, data):
        '''
        本函数仅支持batchsize=1的情况
        data是什么样子的？
        data.x:前numctrl个数据是什么？从numctrl+1个数据开始到最后，是该文件中的数据点数据.x可能代表的是
        当前的二分图中的全部节点数量。因为正好是控制顶点+数据点
        但为什么又用initcontrol来存储控制顶点了呢？
        data.init_controls:tensor, 30 × 2
        data.u_params: 数量与points相同的列表，存储每个数据点的参数值
        
        主要作用是构建图结构的边、边特征
        edgeindex是2 × E，具体来说E等于多少对不同的图是不一样的。取决于数据点与初始控制顶点的相互影响范围
        edgeattr是E × 3的，存储每条边上B样条基函数的值，即N_{i}(u_j)
        '''
        num_ctrl = data.init_controls.shape[0] # 30 × batchsize
#         print('num_ctrl:',num_ctrl)
        points = data.x[num_ctrl:] # shape:[xx,2]。这里，points从第num_ctrl开始到最后，那么，前num_ctrl个数据是干什么用的呢？
        num_points = points.shape[0] # 这个数据竟然是变化的，因为每个文件的数据点个数并不一致
#         print(points.shape,data.u_params.shape,data.u_params) # numpoints 恰好与data.u_params中元素个数一致，即u_paramshi每个数据点的参数


        # 生成clamped节点向量
        prefix = torch.zeros(self.k + 1, device=data.init_controls.device) # 左侧k+1个相等节点
        suffix = torch.ones(self.k + 1, device=data.init_controls.device) # 右侧k+1个相等节点
        internal = torch.linspace(0, 1, num_ctrl - self.k + 1, device=data.init_controls.device)[1:-1] # 中间节点。但最左侧和最右侧与prefix和suffix重复了，所以只要了1到-1之间的那些
        knots = torch.cat([prefix, internal, suffix]) # 节点个数n+k+1个.

        edge_list = [] # 存储每个数据点和那些控制顶点有链接关系，即构建一个[N,2]的数组，记录二分图中边的连接关系。edgelist构建的是数据点到控制点的边
        edge_features = [] # 即edge attr。是E × 3的tensor。第一个维度是数据点j对控制顶点i的B样条基函数的函数值。第2、3个维度是数据点j减去控制顶点i的差向量
        for point_idx, u in enumerate(data.u_params): # 对每一个数据点
            '''
            逻辑：对每一个数据点，首先确定其所属节点区间，之后，将对该节点区间有贡献的B样条基函数拿到，
            
            '''
            u_clamped = torch.clamp(u, 1e-6, 1.0 - 1e-6) # 避免u跑到[0,1]区间外
            span = self.find_span(u_clamped.item(), knots, num_ctrl)  # 找到当前数据点在位于节点向量的哪个区间内

            point_pos = points[point_idx] # 数据点的坐标
            for ctrl_idx in range(span - self.k, span + 1): # 从span - k到span，正好是构成k次B样条的某个区间的全部非零基函数的下标
                if 0 <= ctrl_idx < num_ctrl: 
                    '''
                    确保ctrl_idx在正确的范围内，以便计算基函数等数据。这些拿到的控制顶点都会对u点的曲线值有
                    贡献，因此就拿他们。
                    '''
                    ctrl_pos = data.init_controls[ctrl_idx] # 获取该  ！初始！  控制顶点
                    delta = point_pos[:2] - ctrl_pos[:2] # 比较当前数据点与当前控制顶点之间的差异。该数据会被保存在edgefeature也就是edgeattr中进入网络，后面会用到吗？
                    basis = self.calculate_basis(u_clamped, ctrl_idx, knots, num_ctrl) # 获取在u点非零的全部B样条基函数的函数值，共k+1个。但在这个内部循环中，其实就是计算一个：ctrl_idx的那个基函数的函数值

                    edge_list.append([point_idx, ctrl_idx]) 
                    '''
                    把当前数据点和与其有关的控制顶点之间构造一条边。
                    这里，没有考虑数据点之间是否应该有关联，而对于有噪声的点，是不是把数据点之间也连接
                    一条边比较合适？可考虑
                    这个地方在写论文的时候应该给个可视化的图
                    '''
                    
                    edge_feature_tensor = torch.cat([basis.view(1), delta]).to(data.init_controls.device)
                    '''
                    这个变量就是用来记录每条边的我想保留的数据的：控制顶点对应的B样条基函数在该数据点参数处的函数值、数据点与控制顶点之间的差异
                    basis是一个单个的值，delta本来是1 × 2的向量，二者cat之后是1 × 3 的向量
                    '''

                    edge_features.append(edge_feature_tensor)
                else:
                    raise ValueError(f'ctrl_idx 不在正确的范围内。[0,{num_ctrl - 1}]')

        '''
        至此，二分图构造完成。node有了，edge有了，edgelist有了，edgefeature有了
        '''
        '''
        edge_list原本是列表，每个元素使一个1 × 2向量，通过下面的操作，将其转换为tensor，形状为 2 × n，n为边数
        edge_features原本是一个列表，有n个，每个元素使一个1 × 3 的张量，经过下面的操作，将其转换为 n × 3的张量
        '''
        edge_index = torch.tensor(edge_list, device=data.init_controls.device).t().contiguous() if edge_list else torch.empty(2, 0).long()
#         print(edge_index.shape)
        edge_attr = torch.stack(edge_features) if edge_features else torch.empty(0, 3, device=data.init_controls.device)
#         print(edge_attr.shape)

        return edge_index, edge_attr, num_ctrl, num_points

    def calculate_residuals(self, data, controls):
        '''
        这是一个重要函数。在forward中输入的数据是用它处理的。
        此函数的主要作用是根据传入的data中的数据点和用controls作为控制顶点计算出的B样条曲线的数据点之间进行最小二乘  残差   的计算。以便用于forward. 先放置控制顶点残差，然后放置数据点与曲线残差。
        param data: 传入的batch中的data
        param controls: 控制顶点
        return: 返回原始数据点与计算出来的B样条曲线上的数据点之间的delta，以及controls与data中initcontrols之间的delta。也就是数据拟合程度与控制顶点移动量。但控制顶点移动量似乎没用上。
        '''
        num_ctrl = controls.shape[0]
        num_points = data.x.shape[0] - num_ctrl

        # 生成节点向量
        prefix = torch.zeros(self.k + 1, device=data.init_controls.device)
        suffix = torch.ones(self.k + 1, device=data.init_controls.device)
        internal = torch.linspace(0, 1, num_ctrl - self.k + 1, device=data.init_controls.device)[1:-1]  # 去掉首尾避免重复
        knots = torch.cat([prefix, internal, suffix])

        # 构建基函数矩阵
        # 这一部分其实用calculate_basis实现也是可以的。具体可以看train函数
        basis_matrix = torch.zeros(num_points, num_ctrl, device=controls.device)
        for i, u in enumerate(data.u_params):
            u_clamped = torch.clamp(u, 1e-6, 1.0 - 1e-6)
            span = self.find_span(u_clamped.item(), knots, num_ctrl)
            for j in range(max(0, span - self.k), min(num_ctrl, span + 1)):
                basis_matrix[i, j] = self.calculate_basis(u_clamped, j, knots, num_ctrl)

        curve_pts = torch.einsum('ij,jk->ik', basis_matrix, controls)
        # print(curve_pts)
        point_residuals = data.x[num_ctrl:, :2] - curve_pts
        control_residuals = controls - data.init_controls # 当前传入的控制顶点与 初始 控制顶点之间的残差

        return torch.cat([control_residuals, point_residuals], dim=0)

    def forward(self, data):
        '''
        param data:图数据。即每个待拟合的数据点集及其它计算出来的数据。
        param data.x: [batchsize,num_数据点+num_控制点,2]
        param data.u_param: [batchsize,num_数据点]
        param data.init_controls:[batchsize,num_控制点,2]，一般是通过某种初始化方法获得的。例如：在数据点之间均匀采样
        
        '''
#         print('batch data:',data)
#         print('new forward of BSplineGNN')
        edge_index, edge_attr, num_ctrl, num_points = self.build_bipartite_graph(data) # 生成图的边数据
        
#         assert data.init_controls.shape[0] == num_ctrl
#         assert data.x[num_ctrl:].shape[0] == num_points

        # 初始化节点特征
        # ctrl_feat 和 point_feat除了构造全局变量名之外，似乎没啥特殊意义
#         ctrl_feat = self.ctrl_emb(data.init_controls) # 把初始控制顶点编码
#         point_feat = self.point_emb(data.x[num_ctrl:, :2])  # 修正数据维度。 不用修正啊，data。x本来就是[numctrl+numdata，2]的。把数据点编码
        
        controls = data.init_controls.clone() # 有点用处：第一次迭代的时候用于构建初始的B样条曲线与数据点之间的残差        
        # 两个循环变量都是以numiter作为最大值的，未区分开
        # 这些iteration相当于构建多个layer
        # 这两个的作用类似，都可以快速的迭代收敛到0.001x的程度
        for _ in range(self.iterations):
#             print('_ iteration:',_)
#             layer = self.gnn_layers[0]
            for k,layer in enumerate(self.gnn_layers):
                residuals = self.calculate_residuals(data, controls)# 这个计算出来的是numctrls+numdata个数据，分别存储控制顶点与上一次迭代的控制顶点之间的之间的差异，以及数据点与用controls计算出来的B样条曲线之间的差异。第一次计算的是初始控制顶点曲线与数据点之间的差异，后续计算的是
                point_feat = self.point_emb(residuals[num_ctrl:]) # 从residuals中提取数据点与B样条曲线逐点差异并用mlp编码

                # 用了多个图卷积网络
                # 每次的pointfeat、edge_index、edge_arrt, num_points, num_ctrl都是一样的。
    #             如果ctrl_feat和 point_feat无关，这里进行多少层都是无用的呀？
    #             gnn的可训练参数在gru，还是要搞懂它才行
    #             之后，对照论文来分析下面的循环
    #             如果真的向进行若干次的gnn，应该把delta、controls的更新全放到循环里面去。
     
                ctrl_feat = layer(point_feat, edge_index, edge_attr, num_points, num_ctrl)
    #                 print('k,ctrl_feat:',k,edge_attr[:num_ctrl,:2])

                delta = self.ctrl_update(ctrl_feat) # 用mlp把图卷积网络的输出映射成控制顶点的delta该变量
                controls = controls + self.ctlptUpdateSpeed * delta  # 降低更新幅度 .这里论文中beta被设置成了10，应该进行消融实验。

        return controls

    
    
    
    

# ================== 数据预处理模块 ==================
# def parameterize_points(points):
#     # 改用向心参数化（更适合尖锐特征）
#     chord_lengths = np.linalg.norm(np.diff(points, axis=0), axis=1)
#     total_length = np.sum(chord_lengths)
#     u = np.zeros(len(points))
#     for i in range(1, len(points)):
#         u[i] = u[i - 1] + np.sqrt(chord_lengths[i - 1] / total_length)  # 平方根参数化
#     return np.clip(u, 0.0, 1.0 - 1e-6)

def parameterize_points(points):
    # 改用弦长参数化（更稳定）
    chord_lengths = np.linalg.norm(np.diff(points, axis=0), axis=1)
    total_length = np.sum(chord_lengths)
    u = np.zeros(len(points))
    for i in range(1, len(points)):
        u[i] = u[i - 1] + chord_lengths[i - 1] / total_length
    return np.clip(u, 0.0, 1.0 - 1e-6)


def generate_initial_controls(points, num_ctrl=30, method='uniform'):
    '''
    通过某种方法选取的初始控制顶点。
    目前提供两种，论文中说uniform更好一些
    实际上这个初始控制顶点不应该对结果有重大影响，例如，王文平论文中随便找的点都可以作为初始点。
    如果用uniform来初始化，最后结果好是不是因为控制顶点本身就与数据点契合较好呢？
    '''
    if method == 'random':
        '''
        由于我们采用zscore预先将数据标准化，其数据范围应该在-1,1之间，所以，这里我们其实可以采用固定的初始化控制顶点的方法。
        对于不想这样处理的，可以把注释部分取消掉
        '''
#         points = np.array(points)
#         minv = np.min(points,axis=0)
#         maxv = np.max(points,axis=0)
#         center = (minv + maxv) / 2
#         minwidth = np.min(maxv - minv)
#         radius = 0.5 * minwidth
        radius = 0.618
        
        theta = np.linspace(0,2 * np.pi ,num_ctrl + 1)[:-1] # num_ctrl + 1是对的。这个也没问题。更体现了算法的robustness
        
        cps = np.zeros(shape=(num_ctrl,2))
        for k,t in enumerate(theta):
            cps[k][0] = np.cos(t) * radius
            cps[k][1] = np.sin(t) * radius
        
        return cps
    # 后两种都不需要了：如果随机初始化的控制顶点可以达到很好的效果，还需要特殊选择初始控制顶点干啥
    elif method == 'uniform':
        '''
        经测试，效果基本类似，但收敛不太稳定，有的时候快，有的时候慢。
        '''
        indices = np.linspace(0, len(points) - 1, num_ctrl).astype(int)
        return points[indices]

    elif method == 'curvature':
        if len(points) < 3:
            return generate_initial_controls(points, num_ctrl, 'uniform')

        # 将2D点转换为3D（添加z=0）
        points_3d = np.hstack([points, np.zeros((len(points), 1))])
        diffs = np.diff(points_3d, axis=0)

        curvatures = np.zeros(len(points))
        for i in range(1, len(points) - 1):
            # 使用3D向量计算叉积
            v_prev = diffs[i - 1]  # 形状(3,)
            v_next = diffs[i]  # 形状(3,)
            cross = np.cross(v_prev, v_next)
            curvatures[i] = np.linalg.norm(cross) / (
                    np.linalg.norm(v_prev) * np.linalg.norm(v_next) + 1e-6
            )

        # 滑动窗口采样法
        window_size = max(1, len(points) // num_ctrl)
        selected = []

        # 第一轮：选择各窗口内最大曲率点
        for i in range(0, len(curvatures), window_size):
            window = curvatures[i:i + window_size]
            if len(window) == 0:
                continue
            max_idx = i + np.argmax(window)
            if max_idx not in selected:
                selected.append(max_idx)

        # 第二轮：补充不足的点（按曲率降序）
        if len(selected) < num_ctrl:
            remaining = num_ctrl - len(selected)
            top_indices = np.argsort(curvatures)[-remaining:][::-1]
            for idx in top_indices:
                if idx not in selected:
                    selected.append(idx)
                    if len(selected) == num_ctrl:
                        break

        # 按原始点顺序排序并截断
        selected = sorted(selected[:num_ctrl])
        return points[selected]

    else:
        raise ValueError("Unsupported sampling method")

# Z-score标准化：按列进行
def z_score_normalize(data):
    '''
    使数据符合均值为0、标准差为1的标准正态分布
    param data: N × 2 ndarray
    return: 
    '''
    mean = np.mean(data, axis=0)  # 按列计算均值
    std = np.std(data, axis=0)    # 按列计算标准差
    normalized_data = (data - mean) / std
    return normalized_data, mean, std

def min_max_normalize(data):
    '''
    将数据缩放到[0, 1]范围
    '''
    min_vals = np.min(data, axis=0)
    max_vals = np.max(data, axis=0)
    normalized_data = (data - min_vals) / (max_vals - min_vals)
    return normalized_data, min_vals, max_vals

def range_normalize(data, a=-1, b=1):
    '''
    缩放到任意范围[a, b]
    '''
    min_vals = np.min(data, axis=0)
    max_vals = np.max(data, axis=0)
    normalized_data = a + (data - min_vals) * (b - a) / (max_vals - min_vals)
    return normalized_data,min_vals,max_vals

# 反规范化
def inverse_z_score(normalized_data, original_mean, original_std):
    return normalized_data * original_std + original_mean

def inverse_min_max(normalized_data, original_min, original_max):
    return normalized_data * (original_max - original_min) + original_min

def inverse_range_normalize(normalized_data, original_min, original_max,a=-1,b=1):
    # 避免除零
    range_target = b - a
    if range_target == 0:
        range_target = 1

    range_original = original_max - original_min
    range_original[range_original == 0] = 1  # 如果某列全相同，避免除零

    original_data = original_min + (normalized_data - a) * range_original / range_target
    return original_data 






class PointCloudDataset(Dataset):
    '''
    这部分代码比较好理解，不做深入注释了
    全部数据均应通过本类导入模型，因其中设计数据采样、规范化等操作。
    '''
    def __init__(self, root, transform=None, num_ctrl=30,initControlMethod='random',numFilesSelected = None,randomseed = None,shufflepoints=False):
        '''
        :param numFilesSelected: None or int.  如果数据文件过多，我们可以仅选择其中的若干文件。通过randomseed来控制是否可复现结果。
        :param randomseed: None or int. 
        :param shufflepoints: bool. 在处理每个数据文件时，可以通过这个函数控制是否对数据点进行无序化。注意，这个参数与randomseed没有什么关系，比较独立。
        '''
        super().__init__(root, transform)
        self.num_ctrl = num_ctrl
        self.initControlMethod = initControlMethod
        self.shufflepoints = shufflepoints # 是否将数据点打乱：有序变无序 ordered to unordered
        
        f_list = [f for f in os.listdir(root) if f.endswith('.txt')]
        numAllFiles = len(f_list)
        if randomseed is not None:
            random.seed(randomseed)
        random.shuffle(f_list)
        f_list = f_list[:numFilesSelected] if numFilesSelected is not None and numFilesSelected > 0 and numFilesSelected < len(f_list) else f_list
        self.file_list = f_list
        self.data_list = [self.get(i) for i in range(len(self.file_list))]
        HighlightPrint(f'数据集中有{numAllFiles} 个文件，我们只使用其中的{len(self.file_list)}个文件。')
    
    def len(self):
        return len(self.file_list)
    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        return self.data_list[idx]

    def get(self, idx):
        try:
            filename = self.file_list[idx]
            points = np.loadtxt(os.path.join(self.root, filename))
            
            '''
            由于后面要随机选取1000个采样点，因此，为了保证训练时规范化和预测后的反规范化的一致，我们应该先进行规范化，然后再重采样
            '''
#             print('before normalization:',np.min(points,axis=0))
            points = self._normalizeDataExtent(points) # 将数据规范化
#             print('after normalization:',np.min(points,axis=0))

            points = self._preprocess(points) # 随机 选取1000个代表性数据点。


            # 生成u_params时直接转换为Tensor
            u_params = torch.tensor(
                parameterize_points(points),  # 原为Numpy数组
                dtype=torch.float32, # 显式指定类型
            )

            # 修正数据维度
            points_tensor = torch.tensor(points, dtype=torch.float32)
            controls = generate_initial_controls(points, self.num_ctrl,method=self.initControlMethod)
            controls_tensor = torch.tensor(controls, dtype=torch.float32)

            return Data(
                x=torch.cat([controls_tensor, points_tensor], dim=0), # 每个Data.x把控制顶点和数据点整合到一个张量里面了
                u_params=u_params,
                init_controls=controls_tensor, # 用某种初始化方法获得的初始控制顶点
                num_nodes=controls_tensor.shape[0] + points_tensor.shape[0], # graph的node个数
                filename=filename # 往外信息
            )
        except Exception as e:
            print(f"文件 {filename} 加载失败: {str(e)}")
            return None

    def _preprocess(self, points):
        '''
        随机 选取原始数据中的1000个点作为代表性的数据点
        '''
        if len(points) > 1000:
            indices = np.random.choice(len(points), 1000, replace=False)
            return points[indices]
        
        # 将有序点变为无序点
        if self.shufflepoints:
            points = points[np.random.choice(len(points),len(points),replace = False)]
        return points
    
    def _normalizeDataExtent(self,points):
        '''
        这里应该进行数据点的规范化操作，并将规范化中的参数记录下来，以便将来进行控制顶点的反规范化
        '''
        points,_,__ = z_score_normalize(points)
#         points,_,__ = min_max_normalize(points)
#         points,_,__ = range_normalize(points)
        return points






# ================== 评估 ==================
def evaluate_bspline(model, controls, u_params):
    '''
    计算在以controls为控制顶点，在uparams处的B样条曲线的值。
    model的目的是使用其中的calculatebasis函数来计算B样条基函数在数据点处的函数值。
    '''
    num_ctrl = controls.shape[0]

    # knots = torch.linspace(0, 1, num_ctrl + model.k + 1, device=controls.device)

    # 生成clamped节点向量
    prefix = torch.zeros(model.k + 1, device=controls.device)
    suffix = torch.ones(model.k + 1, device=controls.device)
    internal = torch.linspace(0, 1, num_ctrl - model.k + 1, device=controls.device)[1:-1]  # 去掉首尾避免重复
    knots = torch.cat([prefix, internal, suffix])

    basis = torch.stack([
        torch.stack([model.calculate_basis(u, j, knots, num_ctrl) for j in range(num_ctrl)])
        for u in u_params
    ])
    return torch.einsum('ij,jk->ik', basis, controls)

def HighlightPrint(msg):
    print(f'\033[0;33;40m {msg} \033[0m')

# %% [markdown]
# # 数据集和模型配置

# %%
import random
import shutil

randomseed = 42

useWinVoice = True

# numiters不会增加参数
# numgnnlayers会增加模型参数。
# 二者效果类似
config = {
    # train parameters
    'k': 3,
    'epochs': 30,
    'batch_size': 1, # 这个值暂时先不要改
    'numSelectedFiles':30,

    'num_ctrl': 30,
    'hidden_dim': 256,
    'lr': 1e-4,  # 降低学习率

    # BSplineGNN parameters
    'numIters':1,
    'numGnnLayers':5,
    'ctlptUpdateSpeed':10,

    # PointCloudDataset parameters
    'initControlMethod':'random'
}


datasetfolder = './data/dataset/v2/' # this is files provided by Jidong Wang, which are the dataset provided in 2021-Curve Reconstruction Survey and Benchmark (imagedataset): E:\_Papers\_data\curvefitting\2021-Curve Reconstruction Survey and Benchmark\imagedataset/ETU10OrderedVertices_2_20

# './data/manifold/' # this is the whole dataset from E:\_Papers\_data\curvefitting\2021-Curve Reconstruction Survey and Benchmark\curve-benchmark-new\testdata\manifold\image-data\inputs
# './data/Text_FilesETU/' # this is from E:\_Papers\_data\curvefitting\2021-Curve Reconstruction Survey and Benchmark\curve-benchmark-new\Dataset. too many points in each file.
# './data/imagedataset/' # this is from E:\_Papers\_data\curvefitting\2021-Curve Reconstruction Survey and Benchmark\imagedataset

trainsetpath = datasetfolder+'trainset/'
validsetpath = datasetfolder+'validset/'
if False:
    '''
    尚未保存数据集，则划分并保存
    '''
    if os.path.exists(trainsetpath):
        shutil.rmtree(trainsetpath)
    os.makedirs(trainsetpath, exist_ok=True) 
    if os.path.exists(validsetpath):
        shutil.rmtree(validsetpath)
    os.makedirs(validsetpath, exist_ok=True) 
    
    file_list = [f for f in os.listdir(datasetfolder) if f.endswith('.txt')]
    

    trainratio = 0.7
    trainsize = int(trainratio * len(file_list))
    validsize = len(file_list) - trainsize # 训练集和验证集的个数
    
    print(f'''原始数据集大小: {len(file_list)}, 训练集大小: {trainsize}, 测试集大小: {validsize}''')

    random.seed(randomseed)
    random.shuffle(file_list)
    trainset = file_list[:trainsize]
    validset = file_list[trainsize:]    

    print(f'数据集划分完毕：trainset: {len(trainset)},validset: {len(validset)}')
    for f in trainset:
        shutil.copy2(datasetfolder + f,trainsetpath + f)
    for f in validset:
        shutil.copy2(datasetfolder + f,validsetpath + f)
    print(f'''数据集已保存至{trainsetpath}和{validsetpath}''')
else:
    '''
    数据集已经划分和保存完毕，直接载入即可，避免每次训练使用的是不同的数据
    
    注意：在划分数据集的时候已经确定了初始控制顶点的选取方式，后续载入数据集的时候是不会改变的（即便你重新修改了PointCloudDataset的内容），除非重新划分并保存
    '''
    flist1 = [f for f in os.listdir(trainsetpath) if f.endswith('txt')]
    flist2 = [f for f in os.listdir(validsetpath) if f.endswith('txt')]
    print(f'载入：训练集{trainsetpath}:({len(flist1)}), 验证集{validsetpath}:({len(flist2)})')
    
    
trainfolder = trainsetpath
# Out:
# 载入：训练集./data/dataset/v2/trainset/:(441), 验证集./data/dataset/v2/validset/:(190)

# %% [markdown]
# # 训练

# %%
# from torchsummary import summary
import shutil




# ================== 模型保存模块 ==================
def save_checkpoint(model, optimizer, epoch, traintime,trainsetsize,loss, losshistory,config, save_dir="./saved_models",filename='best_model.pth'):
    '''
    把当前模型及一些数据存储进save_dir中
    其中，model数据存进model_state_dict字段
    '''
    os.makedirs(save_dir, exist_ok=True)
    state = {
        'config': config,
        'epoch': epoch + 1,
        'trainsetsize':trainsetsize,
        'train_time':traintime,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': loss,
        'losshistory':losshistory,
        'notes':'''loss is the averate mse loss'''
    }
    checkpointpath = os.path.join(save_dir, filename)
    torch.save(state, checkpointpath)
    print(f'当前最佳模型已保存:{checkpointpath}')

# ================== 训练流程优化 ==================
def train():
    '''
    训练过程中的最佳模型会被savecheckpoint函数保存到saved_model文件夹中
    '''
    
    HighlightPrint(f'Train config:{config}')

    # 创建保存目录
    if os.path.exists('./saved_models'):
        shutil.rmtree('./saved_models')
    os.makedirs('./saved_models', exist_ok=True)  # 新增模型保存目录
    


    model = BSplineGNN(k=config['k'], hidden_dim=config['hidden_dim'], num_iter=config['numIters'],num_GNN_layers=config['numGnnLayers'],ctlptUpdateSpeed=config['ctlptUpdateSpeed'])
    
    # './data/train'
    dataset = PointCloudDataset(root=trainfolder, num_ctrl=config['num_ctrl'],initControlMethod=config['initControlMethod'],numFilesSelected=config['numSelectedFiles'],randomseed=None,shufflepoints = False) # 
    
#     print('dataset:',dataset)
#     for k in range(len(dataset)):
#         print(f'dataset[{k}]:',dataset[k])
    
    trainloader = DataLoader(dataset, batch_size=config['batch_size'], shuffle=True, pin_memory=True) # batch size的作用是：把dasetset中的batchsize个数据cat成 \sum{N} × 2 的向量，然后输入到网络。shuffle=True的繁华性能似乎不错。

    optimizer = torch.optim.AdamW(model.parameters(), lr=config['lr'], weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.5)
    criterion = nn.MSELoss()
#
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    
    print(f'Train with {device}')

    best_loss = float('inf')

    model.train()
    startTime = time.perf_counter()
    losshistory = list()
    lossinepoch1 = list()
    for epoch in range(config['epochs']):
        total_loss = 0.0
        numtrained = 0
        for batch in trainloader:
            batch = batch.to(device)
            optimizer.zero_grad()
            pred_controls = model(batch[0]) # model的主要作用是：构造一个从数据点集到控制点集的映射

            # 添加正则化项
            # 计算loss
            curve_pts = evaluate_bspline(model, pred_controls, batch.u_params)# 计算出预测出的控制顶点在uparams处的B样条曲线的值以便于数据点进行差值比较
            data_points = batch.x[batch.init_controls.shape[0]:] # batch.x中从numctrl后面开始的就是数据点
            loss = criterion(curve_pts, data_points) 
#             +  0.1 * torch.norm(pred_controls - batch.init_controls)  # 控制点偏移惩罚。去掉这个显著提升收敛速度

            loss.backward()
            torch.nn.utils.clip_grad_value_(model.parameters(), 0.1)
            optimizer.step()

            total_loss += loss.item()
            
            numtrained += 1
            print(f'''Epoch:{epoch + 1} /{config['epochs']}, processing {numtrained} / {len(trainloader)} files({batch.filename[0]},{loss.item()}), percent completed: {numtrained / len(trainloader):.2%}''')
            
            if epoch == 0:
                lossinepoch1.append(loss.item())

        # 保存最佳模型
        avg_loss = total_loss / len(trainloader)
        losshistory.append(avg_loss)
        if avg_loss < best_loss:
            best_loss = avg_loss
            save_checkpoint(model, optimizer, epoch,traintime= time.perf_counter() - startTime, trainsetsize=len(trainloader),loss=avg_loss, losshistory=losshistory,config=config,save_dir="./saved_models")
            
        # 保存前5次的model
        if epoch < 5:
            save_checkpoint(model,optimizer,epoch,traintime = time.perf_counter() - startTime, trainsetsize=len(trainloader),loss=avg_loss, losshistory=losshistory,config=config,save_dir='./saved_models',filename=f'model_epoch{epoch + 1}.pth')
            
        if epoch == 0:
            np.savetxt('./loss in epoch 1.txt',lossinepoch1)

        scheduler.step()
        HighlightPrint(f"Epoch {epoch + 1}/{config['epochs']}, Averate MSE Loss: {avg_loss:.6f}, LR: {optimizer.param_groups[0]['lr']:.1e}, time used: {time.perf_counter() - startTime:.1f} seconds")
        
        mode = 'w' if epoch == 0 else 'a'
        with open('trainhistory.txt',mode,encoding='utf-8') as f:
            f.write(f"Epoch {epoch + 1}/{config['epochs']}, Averate MSE Loss: {avg_loss:.6f}, LR: {optimizer.param_groups[0]['lr']:.1e}, time used: {time.perf_counter() - startTime:.1f} seconds\n")
        
    return losshistory



if __name__ == "__main__":
        
    starttime = time.perf_counter()
    losshistory = train()
    endtime = time.perf_counter()
    print(f'训练结束。用时{endtime - starttime}秒')
    
    # 可视化训练过程
    fig,axes = plt.subplots(nrows= 1,ncols=1,figsize=(12,8))
    print
    axes.scatter(range(len(losshistory)),losshistory)
    axes.plot(range(len(losshistory)),losshistory)
    axes.set_xlabel('Epoch')
    axes.set_ylabel('loss')
    axes.set_ylim([0,1])

    if useWinVoice:
        # 用语音提示结束
        import win32com.client as win
        speak=win.Dispatch("SAPI.SpVoice")
        speak.speak(f"训练结束了")
        useWinVoice
# Out:
#  Train config:{'k': 3, 'epochs': 30, 'batch_size': 1, 'numSelectedFiles': 30, 'num_ctrl': 30, 'hidden_dim': 256, 'lr': 0.0001, 'numIters': 1, 'numGnnLayers': 5, 'ctlptUpdateSpeed': 10, 'initControlMethod': 'random'}
#  BSplineGNN key parameters:
# 	num iterations:1
# 	num Gnn layers:5
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  数据集中有441 个文件，我们只使用其中的30个文件。
# Train with cpu
# Epoch:1 /30, processing 1 / 30 files(teddy060.png.txt,37.27593231201172), percent completed: 3.33%
# Epoch:1 /30, processing 2 / 30 files(toilet195.png.txt,13.65483570098877), percent completed: 6.67%
# Epoch:1 /30, processing 3 / 30 files(teddy070.png.txt,2.7430779933929443), percent completed: 10.00%
# Epoch:1 /30, processing 4 / 30 files(bed165.png.txt,1.2299569845199585), percent completed: 13.33%
# Epoch:1 /30, processing 5 / 30 files(teddy345.png.txt,1.3271310329437256), percent completed: 16.67%
# Epoch:1 /30, processing 6 / 30 files(bed015.png.txt,1.4032708406448364), percent completed: 20.00%
# Epoch:1 /30, processing 7 / 30 files(guitar230.png.txt,1.2288988828659058), percent completed: 23.33%
# Epoch:1 /30, processing 8 / 30 files(hammer340.png.txt,1.0137232542037964), percent completed: 26.67%
# Epoch:1 /30, processing 9 / 30 files(television010.png.txt,0.9114871025085449), percent completed: 30.00%
# Epoch:1 /30, processing 10 / 30 files(horse285.png.txt,1.641221523284912), percent completed: 33.33%
# Epoch:1 /30, processing 11 / 30 files(fish190.png.txt,1.13730788230896), percent completed: 36.67%
# Epoch:1 /30, processing 12 / 30 files(teddy285.png.txt,1.435508131980896), percent completed: 40.00%
# Epoch:1 /30, processing 13 / 30 files(horse255.png.txt,1.570816159248352), percent completed: 43.33%
# Epoch:1 /30, processing 14 / 30 files(horse005.png.txt,0.7826662063598633), percent completed: 46.67%
# Epoch:1 /30, processing 15 / 30 files(guitar025.png.txt,0.503805935382843), percent completed: 50.00%
# Epoch:1 /30, processing 16 / 30 files(bed140.png.txt,2.3732824325561523), percent completed: 53.33%
# Epoch:1 /30, processing 17 / 30 files(toilet030.png.txt,0.8153949975967407), percent completed: 56.67%
# Epoch:1 /30, processing 18 / 30 files(sink210.png.txt,1.470737099647522), percent completed: 60.00%
# Epoch:1 /30, processing 19 / 30 files(toilet205.png.txt,0.42415517568588257), percent completed: 63.33%
# Epoch:1 /30, processing 20 / 30 files(sink160.png.txt,0.44751113653182983), percent completed: 66.67%
# Epoch:1 /30, processing 21 / 30 files(bed325.png.txt,0.8645387291908264), percent completed: 70.00%
# Epoch:1 /30, processing 22 / 30 files(hammer015.png.txt,0.8941271305084229), percent completed: 73.33%
# Epoch:1 /30, processing 23 / 30 files(teddy015.png.txt,0.3802308142185211), percent completed: 76.67%
# Epoch:1 /30, processing 24 / 30 files(fish245.png.txt,0.37906691431999207), percent completed: 80.00%
# Epoch:1 /30, processing 25 / 30 files(television295.png.txt,0.6595776677131653), percent completed: 83.33%
# Epoch:1 /30, processing 26 / 30 files(sink195.png.txt,0.32539623975753784), percent completed: 86.67%
# Epoch:1 /30, processing 27 / 30 files(television035.png.txt,1.148423194885254), percent completed: 90.00%
# Epoch:1 /30, processing 28 / 30 files(sink075.png.txt,0.31119590997695923), percent completed: 93.33%
# Epoch:1 /30, processing 29 / 30 files(television015.png.txt,0.3413926362991333), percent completed: 96.67%
# Epoch:1 /30, processing 30 / 30 files(teddy010.png.txt,0.41483184695243835), percent completed: 100.00%
# 当前最佳模型已保存:./saved_models\best_model.pth
# 当前最佳模型已保存:./saved_models\model_epoch1.pth
#  Epoch 1/30, Averate MSE Loss: 2.636983, LR: 1.0e-04, time used: 45.6 seconds
# Epoch:2 /30, processing 1 / 30 files(bed165.png.txt,0.6577744483947754), percent completed: 3.33%
# Epoch:2 /30, processing 2 / 30 files(horse005.png.txt,0.11948276311159134), percent completed: 6.67%
# Epoch:2 /30, processing 3 / 30 files(teddy010.png.txt,0.2515055537223816), percent completed: 10.00%
# Epoch:2 /30, processing 4 / 30 files(teddy285.png.txt,0.2447739988565445), percent completed: 13.33%
# Epoch:2 /30, processing 5 / 30 files(television295.png.txt,0.2602214813232422), percent completed: 16.67%
# Epoch:2 /30, processing 6 / 30 files(horse255.png.txt,0.8874392509460449), percent completed: 20.00%
# Epoch:2 /30, processing 7 / 30 files(horse285.png.txt,0.06859827041625977), percent completed: 23.33%
# Epoch:2 /30, processing 8 / 30 files(teddy015.png.txt,0.1587499976158142), percent completed: 26.67%
# Epoch:2 /30, processing 9 / 30 files(fish190.png.txt,0.31719139218330383), percent completed: 30.00%
# Epoch:2 /30, processing 10 / 30 files(television035.png.txt,0.20052294433116913), percent completed: 33.33%
# Epoch:2 /30, processing 11 / 30 files(teddy060.png.txt,0.2783336639404297), percent completed: 36.67%
# Epoch:2 /30, processing 12 / 30 files(sink075.png.txt,0.35917142033576965), percent completed: 40.00%
# Epoch:2 /30, processing 13 / 30 files(bed140.png.txt,0.6032620072364807), percent completed: 43.33%
# Epoch:2 /30, processing 14 / 30 files(teddy345.png.txt,0.47476381063461304), percent completed: 46.67%
# Epoch:2 /30, processing 15 / 30 files(sink160.png.txt,0.4950522184371948), percent completed: 50.00%
# Epoch:2 /30, processing 16 / 30 files(hammer015.png.txt,0.5449327826499939), percent completed: 53.33%
# Epoch:2 /30, processing 17 / 30 files(bed325.png.txt,0.5347434878349304), percent completed: 56.67%
# Epoch:2 /30, processing 18 / 30 files(television015.png.txt,0.4379464387893677), percent completed: 60.00%
# Epoch:2 /30, processing 19 / 30 files(sink195.png.txt,0.3651793301105499), percent completed: 63.33%
# Epoch:2 /30, processing 20 / 30 files(toilet030.png.txt,0.2336602807044983), percent completed: 66.67%
# Epoch:2 /30, processing 21 / 30 files(sink210.png.txt,0.21075712144374847), percent completed: 70.00%
# Epoch:2 /30, processing 22 / 30 files(television010.png.txt,0.12794750928878784), percent completed: 73.33%
# Epoch:2 /30, processing 23 / 30 files(teddy070.png.txt,0.19771204888820648), percent completed: 76.67%
# Epoch:2 /30, processing 24 / 30 files(guitar230.png.txt,0.27897900342941284), percent completed: 80.00%
# Epoch:2 /30, processing 25 / 30 files(fish245.png.txt,0.3158504366874695), percent completed: 83.33%
# Epoch:2 /30, processing 26 / 30 files(guitar025.png.txt,0.3801571726799011), percent completed: 86.67%
# Epoch:2 /30, processing 27 / 30 files(toilet195.png.txt,0.34026962518692017), percent completed: 90.00%
# Epoch:2 /30, processing 28 / 30 files(toilet205.png.txt,0.22508901357650757), percent completed: 93.33%
# Epoch:2 /30, processing 29 / 30 files(bed015.png.txt,0.18190529942512512), percent completed: 96.67%
# Epoch:2 /30, processing 30 / 30 files(hammer340.png.txt,0.2221032679080963), percent completed: 100.00%
# 当前最佳模型已保存:./saved_models\best_model.pth
# 当前最佳模型已保存:./saved_models\model_epoch2.pth
#  Epoch 2/30, Averate MSE Loss: 0.332469, LR: 1.0e-04, time used: 91.6 seconds
# Epoch:3 /30, processing 1 / 30 files(toilet030.png.txt,0.2620278596878052), percent completed: 3.33%
# Epoch:3 /30, processing 2 / 30 files(teddy015.png.txt,0.2015981674194336), percent completed: 6.67%
# Epoch:3 /30, processing 3 / 30 files(toilet195.png.txt,0.1331842690706253), percent completed: 10.00%
# Epoch:3 /30, processing 4 / 30 files(teddy345.png.txt,0.23027853667736053), percent completed: 13.33%
# Epoch:3 /30, processing 5 / 30 files(bed325.png.txt,0.2293953001499176), percent completed: 16.67%
# Epoch:3 /30, processing 6 / 30 files(sink075.png.txt,0.12826471030712128), percent completed: 20.00%
# Epoch:3 /30, processing 7 / 30 files(teddy060.png.txt,0.411616712808609), percent completed: 23.33%
# Epoch:3 /30, processing 8 / 30 files(horse285.png.txt,0.31321680545806885), percent completed: 26.67%
# Epoch:3 /30, processing 9 / 30 files(sink210.png.txt,0.043931324034929276), percent completed: 30.00%
# Epoch:3 /30, processing 10 / 30 files(sink160.png.txt,0.08959455043077469), percent completed: 33.33%
# Epoch:3 /30, processing 11 / 30 files(bed015.png.txt,0.2518189251422882), percent completed: 36.67%
# Epoch:3 /30, processing 12 / 30 files(bed165.png.txt,0.18698693811893463), percent completed: 40.00%
# Epoch:3 /30, processing 13 / 30 files(teddy070.png.txt,0.10324210673570633), percent completed: 43.33%
# Epoch:3 /30, processing 14 / 30 files(television010.png.txt,0.09368886798620224), percent completed: 46.67%
# Epoch:3 /30, processing 15 / 30 files(guitar230.png.txt,0.15525256097316742), percent completed: 50.00%
# Epoch:3 /30, processing 16 / 30 files(television035.png.txt,0.12977813184261322), percent completed: 53.33%
# Epoch:3 /30, processing 17 / 30 files(television295.png.txt,0.06882462650537491), percent completed: 56.67%
# Epoch:3 /30, processing 18 / 30 files(television015.png.txt,0.06165992096066475), percent completed: 60.00%
# Epoch:3 /30, processing 19 / 30 files(teddy285.png.txt,0.1059383973479271), percent completed: 63.33%
# Epoch:3 /30, processing 20 / 30 files(fish245.png.txt,0.07132934033870697), percent completed: 66.67%
# Epoch:3 /30, processing 21 / 30 files(fish190.png.txt,0.03626113012433052), percent completed: 70.00%
# Epoch:3 /30, processing 22 / 30 files(hammer015.png.txt,0.04109392687678337), percent completed: 73.33%
# Epoch:3 /30, processing 23 / 30 files(hammer340.png.txt,0.0511808916926384), percent completed: 76.67%
# Epoch:3 /30, processing 24 / 30 files(toilet205.png.txt,0.050637178122997284), percent completed: 80.00%
# Epoch:3 /30, processing 25 / 30 files(guitar025.png.txt,0.06084960699081421), percent completed: 83.33%
# Epoch:3 /30, processing 26 / 30 files(horse005.png.txt,0.036660417914390564), percent completed: 86.67%
# Epoch:3 /30, processing 27 / 30 files(teddy010.png.txt,0.019049718976020813), percent completed: 90.00%
# Epoch:3 /30, processing 28 / 30 files(bed140.png.txt,0.015575136058032513), percent completed: 93.33%
# Epoch:3 /30, processing 29 / 30 files(sink195.png.txt,0.022980961948633194), percent completed: 96.67%
# Epoch:3 /30, processing 30 / 30 files(horse255.png.txt,0.01562408171594143), percent completed: 100.00%
# 当前最佳模型已保存:./saved_models\best_model.pth
# 当前最佳模型已保存:./saved_models\model_epoch3.pth
#  Epoch 3/30, Averate MSE Loss: 0.120718, LR: 1.0e-04, time used: 137.7 seconds
# Epoch:4 /30, processing 1 / 30 files(teddy285.png.txt,0.01656235195696354), percent completed: 3.33%
# Epoch:4 /30, processing 2 / 30 files(teddy070.png.txt,0.012572702020406723), percent completed: 6.67%
# Epoch:4 /30, processing 3 / 30 files(bed165.png.txt,0.01630963198840618), percent completed: 10.00%
# Epoch:4 /30, processing 4 / 30 files(sink160.png.txt,0.021822689101099968), percent completed: 13.33%
# Epoch:4 /30, processing 5 / 30 files(sink195.png.txt,0.017902974039316177), percent completed: 16.67%
# Epoch:4 /30, processing 6 / 30 files(bed325.png.txt,0.009596513584256172), percent completed: 20.00%
# Epoch:4 /30, processing 7 / 30 files(toilet030.png.txt,0.004045264795422554), percent completed: 23.33%
# Epoch:4 /30, processing 8 / 30 files(fish245.png.txt,0.021077409386634827), percent completed: 26.67%
# Epoch:4 /30, processing 9 / 30 files(sink075.png.txt,0.0062872967682778835), percent completed: 30.00%
# Epoch:4 /30, processing 10 / 30 files(television015.png.txt,0.009622810408473015), percent completed: 33.33%
# Epoch:4 /30, processing 11 / 30 files(horse255.png.txt,0.007479697000235319), percent completed: 36.67%
# Epoch:4 /30, processing 12 / 30 files(television295.png.txt,0.011442292481660843), percent completed: 40.00%
# Epoch:4 /30, processing 13 / 30 files(teddy060.png.txt,0.008681201376020908), percent completed: 43.33%
# Epoch:4 /30, processing 14 / 30 files(horse285.png.txt,0.00535711832344532), percent completed: 46.67%
# Epoch:4 /30, processing 15 / 30 files(hammer340.png.txt,0.003772085066884756), percent completed: 50.00%
# Epoch:4 /30, processing 16 / 30 files(guitar230.png.txt,0.005069823935627937), percent completed: 53.33%
# Epoch:4 /30, processing 17 / 30 files(sink210.png.txt,0.002942681545391679), percent completed: 56.67%
# Epoch:4 /30, processing 18 / 30 files(hammer015.png.txt,0.0020146591123193502), percent completed: 60.00%
# Epoch:4 /30, processing 19 / 30 files(toilet195.png.txt,0.0028158894274383783), percent completed: 63.33%
# Epoch:4 /30, processing 20 / 30 files(fish190.png.txt,0.0035936469212174416), percent completed: 66.67%
# Epoch:4 /30, processing 21 / 30 files(teddy010.png.txt,0.00264229835011065), percent completed: 70.00%
# Epoch:4 /30, processing 22 / 30 files(teddy015.png.txt,0.0023292936384677887), percent completed: 73.33%
# Epoch:4 /30, processing 23 / 30 files(guitar025.png.txt,0.0036071452777832747), percent completed: 76.67%
# Epoch:4 /30, processing 24 / 30 files(teddy345.png.txt,0.002900104271247983), percent completed: 80.00%
# Epoch:4 /30, processing 25 / 30 files(toilet205.png.txt,0.0023112562485039234), percent completed: 83.33%
# Epoch:4 /30, processing 26 / 30 files(television035.png.txt,0.008561941795051098), percent completed: 86.67%
# Epoch:4 /30, processing 27 / 30 files(television010.png.txt,0.007240757811814547), percent completed: 90.00%
# Epoch:4 /30, processing 28 / 30 files(horse005.png.txt,0.00292638479731977), percent completed: 93.33%
# Epoch:4 /30, processing 29 / 30 files(bed140.png.txt,0.002896062331274152), percent completed: 96.67%
# Epoch:4 /30, processing 30 / 30 files(bed015.png.txt,0.001903821132145822), percent completed: 100.00%
# 当前最佳模型已保存:./saved_models\best_model.pth
# 当前最佳模型已保存:./saved_models\model_epoch4.pth
#  Epoch 4/30, Averate MSE Loss: 0.007543, LR: 1.0e-04, time used: 184.0 seconds
# Epoch:5 /30, processing 1 / 30 files(teddy010.png.txt,0.0013899808982387185), percent completed: 3.33%
# Epoch:5 /30, processing 2 / 30 files(bed325.png.txt,0.003159919288009405), percent completed: 6.67%
# Epoch:5 /30, processing 3 / 30 files(teddy345.png.txt,0.0015454114181920886), percent completed: 10.00%
# Epoch:5 /30, processing 4 / 30 files(horse005.png.txt,0.003240455174818635), percent completed: 13.33%
# Epoch:5 /30, processing 5 / 30 files(teddy015.png.txt,0.002130833687260747), percent completed: 16.67%
# Epoch:5 /30, processing 6 / 30 files(television010.png.txt,0.007335813250392675), percent completed: 20.00%
# Epoch:5 /30, processing 7 / 30 files(guitar230.png.txt,0.0021688323467969894), percent completed: 23.33%
# Epoch:5 /30, processing 8 / 30 files(guitar025.png.txt,0.0021490915678441525), percent completed: 26.67%
# Epoch:5 /30, processing 9 / 30 files(bed165.png.txt,0.00198706635273993), percent completed: 30.00%
# Epoch:5 /30, processing 10 / 30 files(horse255.png.txt,0.002362658968195319), percent completed: 33.33%
# Epoch:5 /30, processing 11 / 30 files(sink075.png.txt,0.0020534361246973276), percent completed: 36.67%
# Epoch:5 /30, processing 12 / 30 files(toilet030.png.txt,0.0021471651270985603), percent completed: 40.00%
# Epoch:5 /30, processing 13 / 30 files(bed140.png.txt,0.004282135050743818), percent completed: 43.33%
# Epoch:5 /30, processing 14 / 30 files(hammer340.png.txt,0.002277177991345525), percent completed: 46.67%
# Epoch:5 /30, processing 15 / 30 files(toilet205.png.txt,0.0010341779561713338), percent completed: 50.00%
# Epoch:5 /30, processing 16 / 30 files(television015.png.txt,0.007038581185042858), percent completed: 53.33%
# Epoch:5 /30, processing 17 / 30 files(hammer015.png.txt,0.0017076382646337152), percent completed: 56.67%
# Epoch:5 /30, processing 18 / 30 files(horse285.png.txt,0.0018984859343618155), percent completed: 60.00%
# Epoch:5 /30, processing 19 / 30 files(bed015.png.txt,0.0019101605284959078), percent completed: 63.33%
# Epoch:5 /30, processing 20 / 30 files(fish245.png.txt,0.002031081821769476), percent completed: 66.67%
# Epoch:5 /30, processing 21 / 30 files(television295.png.txt,0.0059636542573571205), percent completed: 70.00%
# Epoch:5 /30, processing 22 / 30 files(fish190.png.txt,0.0015674553578719497), percent completed: 73.33%
# Epoch:5 /30, processing 23 / 30 files(sink210.png.txt,0.0024856384843587875), percent completed: 76.67%
# Epoch:5 /30, processing 24 / 30 files(toilet195.png.txt,0.0010982479434460402), percent completed: 80.00%
# Epoch:5 /30, processing 25 / 30 files(teddy285.png.txt,0.0014863550895825028), percent completed: 83.33%
# Epoch:5 /30, processing 26 / 30 files(sink195.png.txt,0.0023900887463241816), percent completed: 86.67%
# Epoch:5 /30, processing 27 / 30 files(sink160.png.txt,0.002148278756067157), percent completed: 90.00%
# Epoch:5 /30, processing 28 / 30 files(television035.png.txt,0.007751294411718845), percent completed: 93.33%
# Epoch:5 /30, processing 29 / 30 files(teddy070.png.txt,0.001403466914780438), percent completed: 96.67%
# Epoch:5 /30, processing 30 / 30 files(teddy060.png.txt,0.001090853475034237), percent completed: 100.00%
# 当前最佳模型已保存:./saved_models\best_model.pth
# 当前最佳模型已保存:./saved_models\model_epoch5.pth
#  Epoch 5/30, Averate MSE Loss: 0.002708, LR: 1.0e-04, time used: 230.4 seconds
# Epoch:6 /30, processing 1 / 30 files(television035.png.txt,0.00814305990934372), percent completed: 3.33%
# Epoch:6 /30, processing 2 / 30 files(television010.png.txt,0.007003356236964464), percent completed: 6.67%
# Epoch:6 /30, processing 3 / 30 files(sink075.png.txt,0.0016517559997737408), percent completed: 10.00%
# Epoch:6 /30, processing 4 / 30 files(bed015.png.txt,0.002129998290911317), percent completed: 13.33%
# Epoch:6 /30, processing 5 / 30 files(fish190.png.txt,0.0013447286328300834), percent completed: 16.67%
# Epoch:6 /30, processing 6 / 30 files(teddy015.png.txt,0.0012062544701620936), percent completed: 20.00%
# Epoch:6 /30, processing 7 / 30 files(bed140.png.txt,0.002676263451576233), percent completed: 23.33%
# Epoch:6 /30, processing 8 / 30 files(guitar025.png.txt,0.0015282431850209832), percent completed: 26.67%
# Epoch:6 /30, processing 9 / 30 files(sink160.png.txt,0.002083398401737213), percent completed: 30.00%
# Epoch:6 /30, processing 10 / 30 files(teddy010.png.txt,0.001009407569654286), percent completed: 33.33%
# Epoch:6 /30, processing 11 / 30 files(teddy060.png.txt,0.0009296403732150793), percent completed: 36.67%
# Epoch:6 /30, processing 12 / 30 files(sink210.png.txt,0.0018536521820351481), percent completed: 40.00%
# Epoch:6 /30, processing 13 / 30 files(sink195.png.txt,0.0021777560468763113), percent completed: 43.33%
# Epoch:6 /30, processing 14 / 30 files(toilet195.png.txt,0.0008516298257745802), percent completed: 46.67%
# Epoch:6 /30, processing 15 / 30 files(horse255.png.txt,0.0015456004766747355), percent completed: 50.00%
# Epoch:6 /30, processing 16 / 30 files(teddy345.png.txt,0.0010123890824615955), percent completed: 53.33%
# Epoch:6 /30, processing 17 / 30 files(toilet030.png.txt,0.0008272718405351043), percent completed: 56.67%
# Epoch:6 /30, processing 18 / 30 files(toilet205.png.txt,0.0008281230693683028), percent completed: 60.00%
# Epoch:6 /30, processing 19 / 30 files(television295.png.txt,0.0058724479749798775), percent completed: 63.33%
# Epoch:6 /30, processing 20 / 30 files(bed165.png.txt,0.0014446383574977517), percent completed: 66.67%
# Epoch:6 /30, processing 21 / 30 files(hammer015.png.txt,0.0015206034295260906), percent completed: 70.00%
# Epoch:6 /30, processing 22 / 30 files(television015.png.txt,0.007010963279753923), percent completed: 73.33%
# Epoch:6 /30, processing 23 / 30 files(teddy285.png.txt,0.0014676573919132352), percent completed: 76.67%
# Epoch:6 /30, processing 24 / 30 files(hammer340.png.txt,0.0013394447742030025), percent completed: 80.00%
# Epoch:6 /30, processing 25 / 30 files(guitar230.png.txt,0.0011975415982306004), percent completed: 83.33%
# Epoch:6 /30, processing 26 / 30 files(horse005.png.txt,0.002604192355647683), percent completed: 86.67%
# Epoch:6 /30, processing 27 / 30 files(teddy070.png.txt,0.0010780227603390813), percent completed: 90.00%
# Epoch:6 /30, processing 28 / 30 files(fish245.png.txt,0.0017778603360056877), percent completed: 93.33%
# Epoch:6 /30, processing 29 / 30 files(bed325.png.txt,0.002044276101514697), percent completed: 96.67%
# Epoch:6 /30, processing 30 / 30 files(horse285.png.txt,0.0016831699758768082), percent completed: 100.00%
# 当前最佳模型已保存:./saved_models\best_model.pth
#  Epoch 6/30, Averate MSE Loss: 0.002261, LR: 1.0e-04, time used: 276.8 seconds
# Epoch:7 /30, processing 1 / 30 files(horse005.png.txt,0.0021481243893504143), percent completed: 3.33%
# Epoch:7 /30, processing 2 / 30 files(fish190.png.txt,0.0010126095730811357), percent completed: 6.67%
# Epoch:7 /30, processing 3 / 30 files(hammer340.png.txt,0.0012082430766895413), percent completed: 10.00%
# Epoch:7 /30, processing 4 / 30 files(fish245.png.txt,0.0018917381530627608), percent completed: 13.33%
# Epoch:7 /30, processing 5 / 30 files(toilet030.png.txt,0.000794414896517992), percent completed: 16.67%
# Epoch:7 /30, processing 6 / 30 files(teddy015.png.txt,0.0009101708419620991), percent completed: 20.00%
# Epoch:7 /30, processing 7 / 30 files(sink160.png.txt,0.001819090568460524), percent completed: 23.33%
# Epoch:7 /30, processing 8 / 30 files(television035.png.txt,0.007106209173798561), percent completed: 26.67%
# Epoch:7 /30, processing 9 / 30 files(bed140.png.txt,0.0027391088660806417), percent completed: 30.00%
# Epoch:7 /30, processing 10 / 30 files(television010.png.txt,0.005913178436458111), percent completed: 33.33%
# Epoch:7 /30, processing 11 / 30 files(teddy345.png.txt,0.001579383504576981), percent completed: 36.67%
# Epoch:7 /30, processing 12 / 30 files(teddy010.png.txt,0.001517601776868105), percent completed: 40.00%
# Epoch:7 /30, processing 13 / 30 files(toilet195.png.txt,0.0012542756740003824), percent completed: 43.33%
# Epoch:7 /30, processing 14 / 30 files(television295.png.txt,0.00572159281000495), percent completed: 46.67%
# Epoch:7 /30, processing 15 / 30 files(television015.png.txt,0.006372967269271612), percent completed: 50.00%
# Epoch:7 /30, processing 16 / 30 files(hammer015.png.txt,0.0009582757484167814), percent completed: 53.33%
# Epoch:7 /30, processing 17 / 30 files(teddy070.png.txt,0.0011319384211674333), percent completed: 56.67%
# Epoch:7 /30, processing 18 / 30 files(sink195.png.txt,0.00193048978690058), percent completed: 60.00%
# Epoch:7 /30, processing 19 / 30 files(bed015.png.txt,0.001350971171632409), percent completed: 63.33%
# Epoch:7 /30, processing 20 / 30 files(bed325.png.txt,0.0017291605472564697), percent completed: 66.67%
# Epoch:7 /30, processing 21 / 30 files(guitar230.png.txt,0.0011168884811922908), percent completed: 70.00%
# Epoch:7 /30, processing 22 / 30 files(guitar025.png.txt,0.0013834073906764388), percent completed: 73.33%
# Epoch:7 /30, processing 23 / 30 files(sink075.png.txt,0.001756572281010449), percent completed: 76.67%
# Epoch:7 /30, processing 24 / 30 files(sink210.png.txt,0.0017192717641592026), percent completed: 80.00%
# Epoch:7 /30, processing 25 / 30 files(teddy285.png.txt,0.0009596911841072142), percent completed: 83.33%
# Epoch:7 /30, processing 26 / 30 files(teddy060.png.txt,0.0011360778007656336), percent completed: 86.67%
# Epoch:7 /30, processing 27 / 30 files(bed165.png.txt,0.0014087738236412406), percent completed: 90.00%
# Epoch:7 /30, processing 28 / 30 files(horse285.png.txt,0.001496969605796039), percent completed: 93.33%
# Epoch:7 /30, processing 29 / 30 files(horse255.png.txt,0.001706428942270577), percent completed: 96.67%
# Epoch:7 /30, processing 30 / 30 files(toilet205.png.txt,0.0006953132105991244), percent completed: 100.00%
# 当前最佳模型已保存:./saved_models\best_model.pth
#  Epoch 7/30, Averate MSE Loss: 0.002082, LR: 1.0e-04, time used: 323.4 seconds
# Epoch:8 /30, processing 1 / 30 files(sink160.png.txt,0.0016621514223515987), percent completed: 3.33%
# Epoch:8 /30, processing 2 / 30 files(guitar025.png.txt,0.0013784024631604552), percent completed: 6.67%
# Epoch:8 /30, processing 3 / 30 files(bed015.png.txt,0.001363649615086615), percent completed: 10.00%
# Epoch:8 /30, processing 4 / 30 files(teddy015.png.txt,0.0009733589831739664), percent completed: 13.33%
# Epoch:8 /30, processing 5 / 30 files(television295.png.txt,0.00576833775267005), percent completed: 16.67%
# Epoch:8 /30, processing 6 / 30 files(toilet195.png.txt,0.0006121378974057734), percent completed: 20.00%
# Epoch:8 /30, processing 7 / 30 files(fish245.png.txt,0.0015723670367151499), percent completed: 23.33%
# Epoch:8 /30, processing 8 / 30 files(sink195.png.txt,0.0018318999791517854), percent completed: 26.67%
# Epoch:8 /30, processing 9 / 30 files(television015.png.txt,0.00650883000344038), percent completed: 30.00%
# Epoch:8 /30, processing 10 / 30 files(bed140.png.txt,0.0025705136358737946), percent completed: 33.33%
# Epoch:8 /30, processing 11 / 30 files(horse285.png.txt,0.002566338051110506), percent completed: 36.67%
# Epoch:8 /30, processing 12 / 30 files(sink210.png.txt,0.0017788304248824716), percent completed: 40.00%
# Epoch:8 /30, processing 13 / 30 files(teddy060.png.txt,0.0010158560471609235), percent completed: 43.33%
# Epoch:8 /30, processing 14 / 30 files(horse005.png.txt,0.0021320520900189877), percent completed: 46.67%
# Epoch:8 /30, processing 15 / 30 files(teddy010.png.txt,0.0015507261268794537), percent completed: 50.00%
# Epoch:8 /30, processing 16 / 30 files(sink075.png.txt,0.001876427442766726), percent completed: 53.33%
# Epoch:8 /30, processing 17 / 30 files(guitar230.png.txt,0.0012413058429956436), percent completed: 56.67%
# Epoch:8 /30, processing 18 / 30 files(television035.png.txt,0.007014214526861906), percent completed: 60.00%
# Epoch:8 /30, processing 19 / 30 files(bed325.png.txt,0.002753590699285269), percent completed: 63.33%
# Epoch:8 /30, processing 20 / 30 files(bed165.png.txt,0.0023518099915236235), percent completed: 66.67%
# Epoch:8 /30, processing 21 / 30 files(horse255.png.txt,0.0018490717047825456), percent completed: 70.00%
# Epoch:8 /30, processing 22 / 30 files(fish190.png.txt,0.0009296221542172134), percent completed: 73.33%
# Epoch:8 /30, processing 23 / 30 files(teddy345.png.txt,0.0010980779770761728), percent completed: 76.67%
# Epoch:8 /30, processing 24 / 30 files(television010.png.txt,0.007437420077621937), percent completed: 80.00%
# Epoch:8 /30, processing 25 / 30 files(toilet205.png.txt,0.0009664783137850463), percent completed: 83.33%
# Epoch:8 /30, processing 26 / 30 files(hammer015.png.txt,0.0011129055637866259), percent completed: 86.67%
# Epoch:8 /30, processing 27 / 30 files(teddy285.png.txt,0.0013041794300079346), percent completed: 90.00%
# Epoch:8 /30, processing 28 / 30 files(toilet030.png.txt,0.001018765033222735), percent completed: 93.33%
# Epoch:8 /30, processing 29 / 30 files(teddy070.png.txt,0.0011423429241403937), percent completed: 96.67%
# Epoch:8 /30, processing 30 / 30 files(hammer340.png.txt,0.0010782881872728467), percent completed: 100.00%
#  Epoch 8/30, Averate MSE Loss: 0.002215, LR: 1.0e-04, time used: 369.7 seconds
# Epoch:9 /30, processing 1 / 30 files(horse285.png.txt,0.0017523578135296702), percent completed: 3.33%
# Epoch:9 /30, processing 2 / 30 files(horse005.png.txt,0.0020196090918034315), percent completed: 6.67%
# Epoch:9 /30, processing 3 / 30 files(bed140.png.txt,0.0025749062187969685), percent completed: 10.00%
# Epoch:9 /30, processing 4 / 30 files(teddy010.png.txt,0.0008371784933842719), percent completed: 13.33%
# Epoch:9 /30, processing 5 / 30 files(teddy070.png.txt,0.0009690523147583008), percent completed: 16.67%
# Epoch:9 /30, processing 6 / 30 files(bed325.png.txt,0.002055063145235181), percent completed: 20.00%
# Epoch:9 /30, processing 7 / 30 files(hammer340.png.txt,0.0011115650413557887), percent completed: 23.33%
# Epoch:9 /30, processing 8 / 30 files(sink195.png.txt,0.0018586103105917573), percent completed: 26.67%
# Epoch:9 /30, processing 9 / 30 files(bed165.png.txt,0.0014498193049803376), percent completed: 30.00%
# Epoch:9 /30, processing 10 / 30 files(sink210.png.txt,0.0017814841121435165), percent completed: 33.33%
# Epoch:9 /30, processing 11 / 30 files(television010.png.txt,0.006667868699878454), percent completed: 36.67%
# Epoch:9 /30, processing 12 / 30 files(horse255.png.txt,0.0015348203014582396), percent completed: 40.00%
# Epoch:9 /30, processing 13 / 30 files(bed015.png.txt,0.0017400500364601612), percent completed: 43.33%
# Epoch:9 /30, processing 14 / 30 files(television295.png.txt,0.006351197604089975), percent completed: 46.67%
# Epoch:9 /30, processing 15 / 30 files(television035.png.txt,0.006886634975671768), percent completed: 50.00%
# Epoch:9 /30, processing 16 / 30 files(guitar025.png.txt,0.0014356902102008462), percent completed: 53.33%
# Epoch:9 /30, processing 17 / 30 files(toilet205.png.txt,0.0007425170042552054), percent completed: 56.67%
# Epoch:9 /30, processing 18 / 30 files(teddy015.png.txt,0.0009766961447894573), percent completed: 60.00%
# Epoch:9 /30, processing 19 / 30 files(teddy345.png.txt,0.0011723092757165432), percent completed: 63.33%
# Epoch:9 /30, processing 20 / 30 files(television015.png.txt,0.0068685924634337425), percent completed: 66.67%
# Epoch:9 /30, processing 21 / 30 files(teddy060.png.txt,0.0011969018960371614), percent completed: 70.00%
# Epoch:9 /30, processing 22 / 30 files(guitar230.png.txt,0.00120619498193264), percent completed: 73.33%
# Epoch:9 /30, processing 23 / 30 files(hammer015.png.txt,0.001141236280091107), percent completed: 76.67%
# Epoch:9 /30, processing 24 / 30 files(teddy285.png.txt,0.0019438463496044278), percent completed: 80.00%
# Epoch:9 /30, processing 25 / 30 files(toilet030.png.txt,0.001537451520562172), percent completed: 83.33%
# Epoch:9 /30, processing 26 / 30 files(toilet195.png.txt,0.0004875267331954092), percent completed: 86.67%
# Epoch:9 /30, processing 27 / 30 files(fish190.png.txt,0.001483524334616959), percent completed: 90.00%
# Epoch:9 /30, processing 28 / 30 files(sink075.png.txt,0.002375249285250902), percent completed: 93.33%
# Epoch:9 /30, processing 29 / 30 files(fish245.png.txt,0.001632819650694728), percent completed: 96.67%
# Epoch:9 /30, processing 30 / 30 files(sink160.png.txt,0.0017062199767678976), percent completed: 100.00%
#  Epoch 9/30, Averate MSE Loss: 0.002183, LR: 1.0e-04, time used: 416.0 seconds
# Epoch:10 /30, processing 1 / 30 files(horse255.png.txt,0.0018114781705662608), percent completed: 3.33%
# Epoch:10 /30, processing 2 / 30 files(sink195.png.txt,0.0025624621193856), percent completed: 6.67%
# Epoch:10 /30, processing 3 / 30 files(guitar025.png.txt,0.0016706986352801323), percent completed: 10.00%
# Epoch:10 /30, processing 4 / 30 files(hammer015.png.txt,0.0010424407664686441), percent completed: 13.33%
# Epoch:10 /30, processing 5 / 30 files(television015.png.txt,0.005888356361538172), percent completed: 16.67%
# Epoch:10 /30, processing 6 / 30 files(teddy010.png.txt,0.000797318818513304), percent completed: 20.00%
# Epoch:10 /30, processing 7 / 30 files(sink160.png.txt,0.0016607815632596612), percent completed: 23.33%
# Epoch:10 /30, processing 8 / 30 files(bed165.png.txt,0.0013095843605697155), percent completed: 26.67%
# Epoch:10 /30, processing 9 / 30 files(teddy070.png.txt,0.0010463942307978868), percent completed: 30.00%
# Epoch:10 /30, processing 10 / 30 files(teddy345.png.txt,0.0009371888590976596), percent completed: 33.33%
# Epoch:10 /30, processing 11 / 30 files(sink075.png.txt,0.0017022114479914308), percent completed: 36.67%
# Epoch:10 /30, processing 12 / 30 files(bed140.png.txt,0.0025738966651260853), percent completed: 40.00%
# Epoch:10 /30, processing 13 / 30 files(horse285.png.txt,0.0015004411106929183), percent completed: 43.33%
# Epoch:10 /30, processing 14 / 30 files(television295.png.txt,0.005788123235106468), percent completed: 46.67%
# Epoch:10 /30, processing 15 / 30 files(hammer340.png.txt,0.00107107637450099), percent completed: 50.00%
# Epoch:10 /30, processing 16 / 30 files(guitar230.png.txt,0.0010588598670437932), percent completed: 53.33%
# Epoch:10 /30, processing 17 / 30 files(fish190.png.txt,0.0009793725330382586), percent completed: 56.67%
# Epoch:10 /30, processing 18 / 30 files(teddy015.png.txt,0.0008958263788372278), percent completed: 60.00%
# Epoch:10 /30, processing 19 / 30 files(teddy285.png.txt,0.0009574127616360784), percent completed: 63.33%
# Epoch:10 /30, processing 20 / 30 files(television035.png.txt,0.0074521941132843494), percent completed: 66.67%
# Epoch:10 /30, processing 21 / 30 files(toilet195.png.txt,0.0007071943837217987), percent completed: 70.00%
# Epoch:10 /30, processing 22 / 30 files(bed325.png.txt,0.0019765866454690695), percent completed: 73.33%
# Epoch:10 /30, processing 23 / 30 files(toilet030.png.txt,0.0009240551735274494), percent completed: 76.67%
# Epoch:10 /30, processing 24 / 30 files(horse005.png.txt,0.0018577855080366135), percent completed: 80.00%
# Epoch:10 /30, processing 25 / 30 files(fish245.png.txt,0.0018249682616442442), percent completed: 83.33%
# Epoch:10 /30, processing 26 / 30 files(toilet205.png.txt,0.001170639880001545), percent completed: 86.67%
# Epoch:10 /30, processing 27 / 30 files(teddy060.png.txt,0.0009609299595467746), percent completed: 90.00%
# Epoch:10 /30, processing 28 / 30 files(television010.png.txt,0.005825498141348362), percent completed: 93.33%
# Epoch:10 /30, processing 29 / 30 files(sink210.png.txt,0.0020837944466620684), percent completed: 96.67%
# Epoch:10 /30, processing 30 / 30 files(bed015.png.txt,0.0023614063393324614), percent completed: 100.00%
# 当前最佳模型已保存:./saved_models\best_model.pth
#  Epoch 10/30, Averate MSE Loss: 0.002080, LR: 1.0e-04, time used: 462.3 seconds
# Epoch:11 /30, processing 1 / 30 files(television015.png.txt,0.005637545138597488), percent completed: 3.33%
# Epoch:11 /30, processing 2 / 30 files(television035.png.txt,0.006603876128792763), percent completed: 6.67%
# Epoch:11 /30, processing 3 / 30 files(teddy070.png.txt,0.0012670523719862103), percent completed: 10.00%
# Epoch:11 /30, processing 4 / 30 files(sink160.png.txt,0.0017999336123466492), percent completed: 13.33%
# Epoch:11 /30, processing 5 / 30 files(horse255.png.txt,0.0016391732497140765), percent completed: 16.67%
# Epoch:11 /30, processing 6 / 30 files(teddy060.png.txt,0.001204318949021399), percent completed: 20.00%
# Epoch:11 /30, processing 7 / 30 files(hammer015.png.txt,0.0012180821504443884), percent completed: 23.33%
# Epoch:11 /30, processing 8 / 30 files(horse005.png.txt,0.001944656833074987), percent completed: 26.67%
# Epoch:11 /30, processing 9 / 30 files(sink210.png.txt,0.0017758134054020047), percent completed: 30.00%
# Epoch:11 /30, processing 10 / 30 files(teddy015.png.txt,0.0008689144160598516), percent completed: 33.33%
# Epoch:11 /30, processing 11 / 30 files(toilet030.png.txt,0.000771254301071167), percent completed: 36.67%
# Epoch:11 /30, processing 12 / 30 files(sink195.png.txt,0.0016928137047216296), percent completed: 40.00%
# Epoch:11 /30, processing 13 / 30 files(guitar230.png.txt,0.0010912430007010698), percent completed: 43.33%
# Epoch:11 /30, processing 14 / 30 files(bed325.png.txt,0.0017967241583392024), percent completed: 46.67%
# Epoch:11 /30, processing 15 / 30 files(television010.png.txt,0.006694607902318239), percent completed: 50.00%
# Epoch:11 /30, processing 16 / 30 files(teddy345.png.txt,0.0008590696379542351), percent completed: 53.33%
# Epoch:11 /30, processing 17 / 30 files(sink075.png.txt,0.0018768651643767953), percent completed: 56.67%
# Epoch:11 /30, processing 18 / 30 files(toilet195.png.txt,0.000730363477487117), percent completed: 60.00%
# Epoch:11 /30, processing 19 / 30 files(toilet205.png.txt,0.0006632112781517208), percent completed: 63.33%
# Epoch:11 /30, processing 20 / 30 files(bed140.png.txt,0.0025186846032738686), percent completed: 66.67%
# Epoch:11 /30, processing 21 / 30 files(teddy285.png.txt,0.0011033157352358103), percent completed: 70.00%
# Epoch:11 /30, processing 22 / 30 files(fish245.png.txt,0.0016571760643273592), percent completed: 73.33%
# Epoch:11 /30, processing 23 / 30 files(fish190.png.txt,0.0009420623537153006), percent completed: 76.67%
# Epoch:11 /30, processing 24 / 30 files(horse285.png.txt,0.001751354313455522), percent completed: 80.00%
# Epoch:11 /30, processing 25 / 30 files(television295.png.txt,0.005806955508887768), percent completed: 83.33%
# Epoch:11 /30, processing 26 / 30 files(guitar025.png.txt,0.0013414992718026042), percent completed: 86.67%
# Epoch:11 /30, processing 27 / 30 files(bed015.png.txt,0.0012101088650524616), percent completed: 90.00%
# Epoch:11 /30, processing 28 / 30 files(bed165.png.txt,0.0013268663315102458), percent completed: 93.33%
# Epoch:11 /30, processing 29 / 30 files(teddy010.png.txt,0.0009581357007846236), percent completed: 96.67%
# Epoch:11 /30, processing 30 / 30 files(hammer340.png.txt,0.001324077951721847), percent completed: 100.00%
# 当前最佳模型已保存:./saved_models\best_model.pth
#  Epoch 11/30, Averate MSE Loss: 0.002003, LR: 1.0e-04, time used: 509.4 seconds
# Epoch:12 /30, processing 1 / 30 files(hammer015.png.txt,0.0011269724927842617), percent completed: 3.33%
# Epoch:12 /30, processing 2 / 30 files(horse005.png.txt,0.0021023477893322706), percent completed: 6.67%
# Epoch:12 /30, processing 3 / 30 files(bed325.png.txt,0.0019576330669224262), percent completed: 10.00%
# Epoch:12 /30, processing 4 / 30 files(sink160.png.txt,0.001821924583055079), percent completed: 13.33%
# Epoch:12 /30, processing 5 / 30 files(hammer340.png.txt,0.0011613963870331645), percent completed: 16.67%
# Epoch:12 /30, processing 6 / 30 files(toilet205.png.txt,0.000674988201353699), percent completed: 20.00%
# Epoch:12 /30, processing 7 / 30 files(bed140.png.txt,0.0024840652476996183), percent completed: 23.33%
# Epoch:12 /30, processing 8 / 30 files(television015.png.txt,0.0067088669165968895), percent completed: 26.67%
# Epoch:12 /30, processing 9 / 30 files(toilet030.png.txt,0.0013852744596078992), percent completed: 30.00%
# Epoch:12 /30, processing 10 / 30 files(teddy015.png.txt,0.0012195911258459091), percent completed: 33.33%
# Epoch:12 /30, processing 11 / 30 files(sink210.png.txt,0.0018075285479426384), percent completed: 36.67%
# Epoch:12 /30, processing 12 / 30 files(teddy345.png.txt,0.000944516621530056), percent completed: 40.00%
# Epoch:12 /30, processing 13 / 30 files(sink195.png.txt,0.00201366376131773), percent completed: 43.33%
# Epoch:12 /30, processing 14 / 30 files(sink075.png.txt,0.0016699915286153555), percent completed: 46.67%
# Epoch:12 /30, processing 15 / 30 files(teddy060.png.txt,0.0011706016957759857), percent completed: 50.00%
# Epoch:12 /30, processing 16 / 30 files(television295.png.txt,0.005785015411674976), percent completed: 53.33%
# Epoch:12 /30, processing 17 / 30 files(guitar025.png.txt,0.0012461779406294227), percent completed: 56.67%
# Epoch:12 /30, processing 18 / 30 files(fish245.png.txt,0.0013444756623357534), percent completed: 60.00%
# Epoch:12 /30, processing 19 / 30 files(teddy010.png.txt,0.0009264543186873198), percent completed: 63.33%
# Epoch:12 /30, processing 20 / 30 files(bed165.png.txt,0.0015766614815220237), percent completed: 66.67%
# Epoch:12 /30, processing 21 / 30 files(toilet195.png.txt,0.0006874887039884925), percent completed: 70.00%
# Epoch:12 /30, processing 22 / 30 files(television035.png.txt,0.007134508341550827), percent completed: 73.33%
# Epoch:12 /30, processing 23 / 30 files(horse255.png.txt,0.0014210661174729466), percent completed: 76.67%
# Epoch:12 /30, processing 24 / 30 files(teddy070.png.txt,0.0013605548301711679), percent completed: 80.00%
# Epoch:12 /30, processing 25 / 30 files(bed015.png.txt,0.0014398442581295967), percent completed: 83.33%
# Epoch:12 /30, processing 26 / 30 files(horse285.png.txt,0.0013780365698039532), percent completed: 86.67%
# Epoch:12 /30, processing 27 / 30 files(guitar230.png.txt,0.0011602554004639387), percent completed: 90.00%
# Epoch:12 /30, processing 28 / 30 files(television010.png.txt,0.007259065750986338), percent completed: 93.33%
# Epoch:12 /30, processing 29 / 30 files(teddy285.png.txt,0.0010290259961038828), percent completed: 96.67%
# Epoch:12 /30, processing 30 / 30 files(fish190.png.txt,0.0014141416177153587), percent completed: 100.00%
#  Epoch 12/30, Averate MSE Loss: 0.002114, LR: 1.0e-04, time used: 556.6 seconds
# Epoch:13 /30, processing 1 / 30 files(toilet030.png.txt,0.0011577422264963388), percent completed: 3.33%
# Epoch:13 /30, processing 2 / 30 files(hammer015.png.txt,0.0009418660192750394), percent completed: 6.67%
# Epoch:13 /30, processing 3 / 30 files(bed015.png.txt,0.0012026834301650524), percent completed: 10.00%
# Epoch:13 /30, processing 4 / 30 files(teddy060.png.txt,0.0009899860015138984), percent completed: 13.33%
# Epoch:13 /30, processing 5 / 30 files(teddy070.png.txt,0.0010526396799832582), percent completed: 16.67%
# Epoch:13 /30, processing 6 / 30 files(teddy015.png.txt,0.0012361322296783328), percent completed: 20.00%
# Epoch:13 /30, processing 7 / 30 files(bed140.png.txt,0.0023551133926957846), percent completed: 23.33%
# Epoch:13 /30, processing 8 / 30 files(sink160.png.txt,0.0018634502775967121), percent completed: 26.67%
# Epoch:13 /30, processing 9 / 30 files(television010.png.txt,0.00589247839525342), percent completed: 30.00%
# Epoch:13 /30, processing 10 / 30 files(horse005.png.txt,0.0024866696912795305), percent completed: 33.33%
# Epoch:13 /30, processing 11 / 30 files(television015.png.txt,0.005859259516000748), percent completed: 36.67%
# Epoch:13 /30, processing 12 / 30 files(guitar230.png.txt,0.0010872699785977602), percent completed: 40.00%
# Epoch:13 /30, processing 13 / 30 files(bed325.png.txt,0.0018789643654599786), percent completed: 43.33%
# Epoch:13 /30, processing 14 / 30 files(teddy285.png.txt,0.0010039046173915267), percent completed: 46.67%
# Epoch:13 /30, processing 15 / 30 files(fish245.png.txt,0.0015535367419943213), percent completed: 50.00%
# Epoch:13 /30, processing 16 / 30 files(toilet195.png.txt,0.0005491252522915602), percent completed: 53.33%
# Epoch:13 /30, processing 17 / 30 files(television035.png.txt,0.007024934981018305), percent completed: 56.67%
# Epoch:13 /30, processing 18 / 30 files(bed165.png.txt,0.0019820251036435366), percent completed: 60.00%
# Epoch:13 /30, processing 19 / 30 files(toilet205.png.txt,0.0009759687236510217), percent completed: 63.33%
# Epoch:13 /30, processing 20 / 30 files(teddy345.png.txt,0.0009220473584719002), percent completed: 66.67%
# Epoch:13 /30, processing 21 / 30 files(sink075.png.txt,0.001639875932596624), percent completed: 70.00%
# Epoch:13 /30, processing 22 / 30 files(television295.png.txt,0.005699498113244772), percent completed: 73.33%
# Epoch:13 /30, processing 23 / 30 files(sink195.png.txt,0.001802888815291226), percent completed: 76.67%
# Epoch:13 /30, processing 24 / 30 files(teddy010.png.txt,0.0007871728739701211), percent completed: 80.00%
# Epoch:13 /30, processing 25 / 30 files(hammer340.png.txt,0.0010061105713248253), percent completed: 83.33%
# Epoch:13 /30, processing 26 / 30 files(sink210.png.txt,0.0019398474832996726), percent completed: 86.67%
# Epoch:13 /30, processing 27 / 30 files(guitar025.png.txt,0.0015135891735553741), percent completed: 90.00%
# Epoch:13 /30, processing 28 / 30 files(horse285.png.txt,0.0017332317074760795), percent completed: 93.33%
# Epoch:13 /30, processing 29 / 30 files(fish190.png.txt,0.0008046154398471117), percent completed: 96.67%
# Epoch:13 /30, processing 30 / 30 files(horse255.png.txt,0.0014292685082182288), percent completed: 100.00%
#  Epoch 13/30, Averate MSE Loss: 0.002012, LR: 1.0e-04, time used: 603.6 seconds
# Epoch:14 /30, processing 1 / 30 files(teddy010.png.txt,0.0010324908653274179), percent completed: 3.33%
# Epoch:14 /30, processing 2 / 30 files(fish190.png.txt,0.0009349093888886273), percent completed: 6.67%
# Epoch:14 /30, processing 3 / 30 files(teddy015.png.txt,0.0009050098014995456), percent completed: 10.00%
# Epoch:14 /30, processing 4 / 30 files(bed140.png.txt,0.0024006227031350136), percent completed: 13.33%
# Epoch:14 /30, processing 5 / 30 files(teddy345.png.txt,0.0009487130446359515), percent completed: 16.67%
# Epoch:14 /30, processing 6 / 30 files(sink075.png.txt,0.0017467772122472525), percent completed: 20.00%
# Epoch:14 /30, processing 7 / 30 files(bed325.png.txt,0.0016430673422291875), percent completed: 23.33%
# Epoch:14 /30, processing 8 / 30 files(television295.png.txt,0.005595671012997627), percent completed: 26.67%
# Epoch:14 /30, processing 9 / 30 files(sink160.png.txt,0.0016789737856015563), percent completed: 30.00%
# Epoch:14 /30, processing 10 / 30 files(sink210.png.txt,0.0017564238514751196), percent completed: 33.33%
# Epoch:14 /30, processing 11 / 30 files(teddy070.png.txt,0.001102603622712195), percent completed: 36.67%
# Epoch:14 /30, processing 12 / 30 files(teddy285.png.txt,0.0008838661597110331), percent completed: 40.00%
# Epoch:14 /30, processing 13 / 30 files(horse005.png.txt,0.0017899987287819386), percent completed: 43.33%
# Epoch:14 /30, processing 14 / 30 files(horse285.png.txt,0.0013994926121085882), percent completed: 46.67%
# Epoch:14 /30, processing 15 / 30 files(bed165.png.txt,0.0013541332446038723), percent completed: 50.00%
# Epoch:14 /30, processing 16 / 30 files(horse255.png.txt,0.0014247569488361478), percent completed: 53.33%
# Epoch:14 /30, processing 17 / 30 files(sink195.png.txt,0.0017027505673468113), percent completed: 56.67%
# Epoch:14 /30, processing 18 / 30 files(toilet205.png.txt,0.0005696348380297422), percent completed: 60.00%
# Epoch:14 /30, processing 19 / 30 files(teddy060.png.txt,0.0010031734127551317), percent completed: 63.33%
# Epoch:14 /30, processing 20 / 30 files(hammer340.png.txt,0.0012319742236286402), percent completed: 66.67%
# Epoch:14 /30, processing 21 / 30 files(television015.png.txt,0.006349646486341953), percent completed: 70.00%
# Epoch:14 /30, processing 22 / 30 files(television010.png.txt,0.0059522301889956), percent completed: 73.33%
# Epoch:14 /30, processing 23 / 30 files(fish245.png.txt,0.002047209534794092), percent completed: 76.67%
# Epoch:14 /30, processing 24 / 30 files(bed015.png.txt,0.002266725990921259), percent completed: 80.00%
# Epoch:14 /30, processing 25 / 30 files(guitar025.png.txt,0.0014757011085748672), percent completed: 83.33%
# Epoch:14 /30, processing 26 / 30 files(toilet030.png.txt,0.0008090991177596152), percent completed: 86.67%
# Epoch:14 /30, processing 27 / 30 files(hammer015.png.txt,0.0012738864170387387), percent completed: 90.00%
# Epoch:14 /30, processing 28 / 30 files(toilet195.png.txt,0.0015057012205943465), percent completed: 93.33%
# Epoch:14 /30, processing 29 / 30 files(television035.png.txt,0.0077526080422103405), percent completed: 96.67%
# Epoch:14 /30, processing 30 / 30 files(guitar230.png.txt,0.001024318509735167), percent completed: 100.00%
#  Epoch 14/30, Averate MSE Loss: 0.002052, LR: 1.0e-04, time used: 650.7 seconds
# Epoch:15 /30, processing 1 / 30 files(toilet030.png.txt,0.0017038832884281874), percent completed: 3.33%
# Epoch:15 /30, processing 2 / 30 files(sink195.png.txt,0.0025878138840198517), percent completed: 6.67%
# Epoch:15 /30, processing 3 / 30 files(teddy070.png.txt,0.0015525229973718524), percent completed: 10.00%
# Epoch:15 /30, processing 4 / 30 files(television015.png.txt,0.005986346397548914), percent completed: 13.33%
# Epoch:15 /30, processing 5 / 30 files(teddy010.png.txt,0.000984883401542902), percent completed: 16.67%
# Epoch:15 /30, processing 6 / 30 files(television035.png.txt,0.0070753516629338264), percent completed: 20.00%
# Epoch:15 /30, processing 7 / 30 files(toilet195.png.txt,0.0007257977267727256), percent completed: 23.33%
# Epoch:15 /30, processing 8 / 30 files(sink210.png.txt,0.0017442163079977036), percent completed: 26.67%
# Epoch:15 /30, processing 9 / 30 files(sink160.png.txt,0.0016646025469526649), percent completed: 30.00%
# Epoch:15 /30, processing 10 / 30 files(teddy060.png.txt,0.0010640110122039914), percent completed: 33.33%
# Epoch:15 /30, processing 11 / 30 files(television295.png.txt,0.0054506901651620865), percent completed: 36.67%
# Epoch:15 /30, processing 12 / 30 files(teddy015.png.txt,0.0009335363865830004), percent completed: 40.00%
# Epoch:15 /30, processing 13 / 30 files(fish245.png.txt,0.0014063525013625622), percent completed: 43.33%
# ...
# Epoch:26 /30, processing 5 / 30 files(sink075.png.txt,0.0015412142965942621), percent completed: 16.67%
# Epoch:26 /30, processing 6 / 30 files(horse255.png.txt,0.0014904942363500595), percent completed: 20.00%
# Epoch:26 /30, processing 7 / 30 files(bed165.png.txt,0.0011355472961440682), percent completed: 23.33%
# Epoch:26 /30, processing 8 / 30 files(hammer015.png.txt,0.0008241140749305487), percent completed: 26.67%
# Epoch:26 /30, processing 9 / 30 files(horse285.png.txt,0.0012161487247794867), percent completed: 30.00%
# Epoch:26 /30, processing 10 / 30 files(television295.png.txt,0.00488151703029871), percent completed: 33.33%
# Epoch:26 /30, processing 11 / 30 files(guitar230.png.txt,0.0008033326594159007), percent completed: 36.67%
# Epoch:26 /30, processing 12 / 30 files(bed325.png.txt,0.0015565062640234828), percent completed: 40.00%
# Epoch:26 /30, processing 13 / 30 files(toilet205.png.txt,0.0005854559130966663), percent completed: 43.33%
# Epoch:26 /30, processing 14 / 30 files(toilet195.png.txt,0.0005070982151664793), percent completed: 46.67%
# Epoch:26 /30, processing 15 / 30 files(fish245.png.txt,0.0011663311161100864), percent completed: 50.00%
# Epoch:26 /30, processing 16 / 30 files(horse005.png.txt,0.0015390730695798993), percent completed: 53.33%
# Epoch:26 /30, processing 17 / 30 files(teddy015.png.txt,0.0007325720507651567), percent completed: 56.67%
# Epoch:26 /30, processing 18 / 30 files(sink195.png.txt,0.0014442193787544966), percent completed: 60.00%
# Epoch:26 /30, processing 19 / 30 files(fish190.png.txt,0.0007848252425901592), percent completed: 63.33%
# Epoch:26 /30, processing 20 / 30 files(bed140.png.txt,0.0023683432955294847), percent completed: 66.67%
# Epoch:26 /30, processing 21 / 30 files(teddy070.png.txt,0.0006912622484378517), percent completed: 70.00%
# Epoch:26 /30, processing 22 / 30 files(toilet030.png.txt,0.0006506729987449944), percent completed: 73.33%
# Epoch:26 /30, processing 23 / 30 files(teddy345.png.txt,0.0007828787784092128), percent completed: 76.67%
# Epoch:26 /30, processing 24 / 30 files(sink160.png.txt,0.0013851044932380319), percent completed: 80.00%
# Epoch:26 /30, processing 25 / 30 files(television035.png.txt,0.00632459344342351), percent completed: 83.33%
# Epoch:26 /30, processing 26 / 30 files(television015.png.txt,0.005195042584091425), percent completed: 86.67%
# Epoch:26 /30, processing 27 / 30 files(television010.png.txt,0.0050020222552120686), percent completed: 90.00%
# Epoch:26 /30, processing 28 / 30 files(sink210.png.txt,0.002384164137765765), percent completed: 93.33%
# Epoch:26 /30, processing 29 / 30 files(hammer340.png.txt,0.0013081968063488603), percent completed: 96.67%
# Epoch:26 /30, processing 30 / 30 files(teddy060.png.txt,0.0007786149508319795), percent completed: 100.00%
# 当前最佳模型已保存:./saved_models\best_model.pth
#  Epoch 26/30, Averate MSE Loss: 0.001705, LR: 1.0e-04, time used: 1215.2 seconds
# Epoch:27 /30, processing 1 / 30 files(teddy015.png.txt,0.0007922740769572556), percent completed: 3.33%
# Epoch:27 /30, processing 2 / 30 files(teddy060.png.txt,0.0010529167484492064), percent completed: 6.67%
# Epoch:27 /30, processing 3 / 30 files(horse285.png.txt,0.0011210552183911204), percent completed: 10.00%
# Epoch:27 /30, processing 4 / 30 files(sink160.png.txt,0.001351668150164187), percent completed: 13.33%
# Epoch:27 /30, processing 5 / 30 files(television295.png.txt,0.004784190095961094), percent completed: 16.67%
# Epoch:27 /30, processing 6 / 30 files(fish245.png.txt,0.001158960978500545), percent completed: 20.00%
# Epoch:27 /30, processing 7 / 30 files(sink075.png.txt,0.0015584074426442385), percent completed: 23.33%
# Epoch:27 /30, processing 8 / 30 files(bed325.png.txt,0.0014073746278882027), percent completed: 26.67%
# Epoch:27 /30, processing 9 / 30 files(television035.png.txt,0.006610455457121134), percent completed: 30.00%
# Epoch:27 /30, processing 10 / 30 files(hammer340.png.txt,0.0009804071160033345), percent completed: 33.33%
# Epoch:27 /30, processing 11 / 30 files(teddy285.png.txt,0.0008019101223908365), percent completed: 36.67%
# Epoch:27 /30, processing 12 / 30 files(hammer015.png.txt,0.000821961322799325), percent completed: 40.00%
# Epoch:27 /30, processing 13 / 30 files(guitar025.png.txt,0.0011145833414047956), percent completed: 43.33%
# Epoch:27 /30, processing 14 / 30 files(teddy345.png.txt,0.0008447643485851586), percent completed: 46.67%
# Epoch:27 /30, processing 15 / 30 files(bed140.png.txt,0.0022474173456430435), percent completed: 50.00%
# Epoch:27 /30, processing 16 / 30 files(television015.png.txt,0.005507385358214378), percent completed: 53.33%
# Epoch:27 /30, processing 17 / 30 files(bed015.png.txt,0.0013716388493776321), percent completed: 56.67%
# Epoch:27 /30, processing 18 / 30 files(horse005.png.txt,0.0017005510162562132), percent completed: 60.00%
# Epoch:27 /30, processing 19 / 30 files(toilet195.png.txt,0.0005231459508650005), percent completed: 63.33%
# Epoch:27 /30, processing 20 / 30 files(sink195.png.txt,0.0013152064057067037), percent completed: 66.67%
# Epoch:27 /30, processing 21 / 30 files(sink210.png.txt,0.0015234841266646981), percent completed: 70.00%
# Epoch:27 /30, processing 22 / 30 files(fish190.png.txt,0.0008200753945857286), percent completed: 73.33%
# Epoch:27 /30, processing 23 / 30 files(television010.png.txt,0.005280870944261551), percent completed: 76.67%
# Epoch:27 /30, processing 24 / 30 files(bed165.png.txt,0.0013969136634841561), percent completed: 80.00%
# Epoch:27 /30, processing 25 / 30 files(guitar230.png.txt,0.0009198801126331091), percent completed: 83.33%
# Epoch:27 /30, processing 26 / 30 files(toilet030.png.txt,0.0008344596135430038), percent completed: 86.67%
# Epoch:27 /30, processing 27 / 30 files(toilet205.png.txt,0.000469765393063426), percent completed: 90.00%
# Epoch:27 /30, processing 28 / 30 files(horse255.png.txt,0.0012489526998251677), percent completed: 93.33%
# Epoch:27 /30, processing 29 / 30 files(teddy010.png.txt,0.0007681470597162843), percent completed: 96.67%
# Epoch:27 /30, processing 30 / 30 files(teddy070.png.txt,0.0010168396402150393), percent completed: 100.00%
#  Epoch 27/30, Averate MSE Loss: 0.001712, LR: 1.0e-04, time used: 1262.5 seconds
# Epoch:28 /30, processing 1 / 30 files(fish190.png.txt,0.0007473637233488262), percent completed: 3.33%
# Epoch:28 /30, processing 2 / 30 files(sink160.png.txt,0.001384320785291493), percent completed: 6.67%
# Epoch:28 /30, processing 3 / 30 files(horse005.png.txt,0.0017377781914547086), percent completed: 10.00%
# Epoch:28 /30, processing 4 / 30 files(teddy345.png.txt,0.0009180501801893115), percent completed: 13.33%
# Epoch:28 /30, processing 5 / 30 files(teddy015.png.txt,0.0007426133379340172), percent completed: 16.67%
# Epoch:28 /30, processing 6 / 30 files(teddy070.png.txt,0.0006361466366797686), percent completed: 20.00%
# Epoch:28 /30, processing 7 / 30 files(television035.png.txt,0.006376771256327629), percent completed: 23.33%
# Epoch:28 /30, processing 8 / 30 files(hammer340.png.txt,0.0008693254785612226), percent completed: 26.67%
# Epoch:28 /30, processing 9 / 30 files(bed015.png.txt,0.0013654559152200818), percent completed: 30.00%
# Epoch:28 /30, processing 10 / 30 files(toilet030.png.txt,0.0006137204472906888), percent completed: 33.33%
# Epoch:28 /30, processing 11 / 30 files(bed165.png.txt,0.0011910097673535347), percent completed: 36.67%
# Epoch:28 /30, processing 12 / 30 files(sink210.png.txt,0.0015905540203675628), percent completed: 40.00%
# Epoch:28 /30, processing 13 / 30 files(television015.png.txt,0.005199798848479986), percent completed: 43.33%
# Epoch:28 /30, processing 14 / 30 files(guitar230.png.txt,0.0009202277869917452), percent completed: 46.67%
# Epoch:28 /30, processing 15 / 30 files(guitar025.png.txt,0.001289143692702055), percent completed: 50.00%
# Epoch:28 /30, processing 16 / 30 files(hammer015.png.txt,0.0010391115210950375), percent completed: 53.33%
# Epoch:28 /30, processing 17 / 30 files(teddy060.png.txt,0.0008382564410567284), percent completed: 56.67%
# Epoch:28 /30, processing 18 / 30 files(toilet195.png.txt,0.0004753084504045546), percent completed: 60.00%
# Epoch:28 /30, processing 19 / 30 files(television295.png.txt,0.00504257483407855), percent completed: 63.33%
# Epoch:28 /30, processing 20 / 30 files(toilet205.png.txt,0.0005036047659814358), percent completed: 66.67%
# Epoch:28 /30, processing 21 / 30 files(fish245.png.txt,0.0011427277931943536), percent completed: 70.00%
# Epoch:28 /30, processing 22 / 30 files(bed140.png.txt,0.002288033254444599), percent completed: 73.33%
# Epoch:28 /30, processing 23 / 30 files(sink195.png.txt,0.0013758529676124454), percent completed: 76.67%
# Epoch:28 /30, processing 24 / 30 files(teddy010.png.txt,0.0005793282180093229), percent completed: 80.00%
# Epoch:28 /30, processing 25 / 30 files(teddy285.png.txt,0.0008117289398796856), percent completed: 83.33%
# Epoch:28 /30, processing 26 / 30 files(television010.png.txt,0.005887530744075775), percent completed: 86.67%
# Epoch:28 /30, processing 27 / 30 files(bed325.png.txt,0.0013930154964327812), percent completed: 90.00%
# Epoch:28 /30, processing 28 / 30 files(horse255.png.txt,0.00187812396325171), percent completed: 93.33%
# Epoch:28 /30, processing 29 / 30 files(sink075.png.txt,0.0016092046862468123), percent completed: 96.67%
# Epoch:28 /30, processing 30 / 30 files(horse285.png.txt,0.0012534954585134983), percent completed: 100.00%
#  Epoch 28/30, Averate MSE Loss: 0.001723, LR: 1.0e-04, time used: 1309.6 seconds
# Epoch:29 /30, processing 1 / 30 files(guitar025.png.txt,0.0013008011737838387), percent completed: 3.33%
# Epoch:29 /30, processing 2 / 30 files(bed015.png.txt,0.0012245993129909039), percent completed: 6.67%
# Epoch:29 /30, processing 3 / 30 files(teddy070.png.txt,0.0007390840328298509), percent completed: 10.00%
# Epoch:29 /30, processing 4 / 30 files(toilet030.png.txt,0.0006865278701297939), percent completed: 13.33%
# Epoch:29 /30, processing 5 / 30 files(toilet205.png.txt,0.0005229818052612245), percent completed: 16.67%
# Epoch:29 /30, processing 6 / 30 files(teddy345.png.txt,0.0007712969090789557), percent completed: 20.00%
# Epoch:29 /30, processing 7 / 30 files(fish245.png.txt,0.0011901267571374774), percent completed: 23.33%
# Epoch:29 /30, processing 8 / 30 files(horse005.png.txt,0.0016340413130819798), percent completed: 26.67%
# Epoch:29 /30, processing 9 / 30 files(bed165.png.txt,0.0012628708500415087), percent completed: 30.00%
# Epoch:29 /30, processing 10 / 30 files(television295.png.txt,0.004675505217164755), percent completed: 33.33%
# Epoch:29 /30, processing 11 / 30 files(teddy285.png.txt,0.0007578498334623873), percent completed: 36.67%
# Epoch:29 /30, processing 12 / 30 files(hammer340.png.txt,0.0008905798895284534), percent completed: 40.00%
# Epoch:29 /30, processing 13 / 30 files(bed140.png.txt,0.0023340715561062098), percent completed: 43.33%
# Epoch:29 /30, processing 14 / 30 files(sink075.png.txt,0.001517719472758472), percent completed: 46.67%
# Epoch:29 /30, processing 15 / 30 files(teddy060.png.txt,0.0007682671421207488), percent completed: 50.00%
# Epoch:29 /30, processing 16 / 30 files(sink210.png.txt,0.00147767155431211), percent completed: 53.33%
# Epoch:29 /30, processing 17 / 30 files(bed325.png.txt,0.0015670894645154476), percent completed: 56.67%
# Epoch:29 /30, processing 18 / 30 files(television035.png.txt,0.006180232856422663), percent completed: 60.00%
# Epoch:29 /30, processing 19 / 30 files(sink195.png.txt,0.0015301972161978483), percent completed: 63.33%
# Epoch:29 /30, processing 20 / 30 files(sink160.png.txt,0.0013110814616084099), percent completed: 66.67%
# Epoch:29 /30, processing 21 / 30 files(horse255.png.txt,0.0012926730560138822), percent completed: 70.00%
# Epoch:29 /30, processing 22 / 30 files(horse285.png.txt,0.0011514639481902122), percent completed: 73.33%
# Epoch:29 /30, processing 23 / 30 files(toilet195.png.txt,0.0005419138469733298), percent completed: 76.67%
# Epoch:29 /30, processing 24 / 30 files(teddy015.png.txt,0.0006154205184429884), percent completed: 80.00%
# Epoch:29 /30, processing 25 / 30 files(guitar230.png.txt,0.0008690966060385108), percent completed: 83.33%
# Epoch:29 /30, processing 26 / 30 files(teddy010.png.txt,0.0005394491599872708), percent completed: 86.67%
# Epoch:29 /30, processing 27 / 30 files(fish190.png.txt,0.0009012449881993234), percent completed: 90.00%
# Epoch:29 /30, processing 28 / 30 files(hammer015.png.txt,0.0009277443750761449), percent completed: 93.33%
# Epoch:29 /30, processing 29 / 30 files(television010.png.txt,0.005513160023838282), percent completed: 96.67%
# Epoch:29 /30, processing 30 / 30 files(television015.png.txt,0.005189957562834024), percent completed: 100.00%
# 当前最佳模型已保存:./saved_models\best_model.pth
#  Epoch 29/30, Averate MSE Loss: 0.001663, LR: 1.0e-04, time used: 1356.7 seconds
# Epoch:30 /30, processing 1 / 30 files(bed140.png.txt,0.0024724535178393126), percent completed: 3.33%
# Epoch:30 /30, processing 2 / 30 files(sink195.png.txt,0.0017915003700181842), percent completed: 6.67%
# Epoch:30 /30, processing 3 / 30 files(bed165.png.txt,0.0012318681692704558), percent completed: 10.00%
# Epoch:30 /30, processing 4 / 30 files(teddy010.png.txt,0.0006239429349079728), percent completed: 13.33%
# Epoch:30 /30, processing 5 / 30 files(horse005.png.txt,0.0018194338772445917), percent completed: 16.67%
# Epoch:30 /30, processing 6 / 30 files(fish190.png.txt,0.000901182007510215), percent completed: 20.00%
# Epoch:30 /30, processing 7 / 30 files(toilet205.png.txt,0.0005011817556805909), percent completed: 23.33%
# Epoch:30 /30, processing 8 / 30 files(teddy060.png.txt,0.0008958583930507302), percent completed: 26.67%
# Epoch:30 /30, processing 9 / 30 files(toilet030.png.txt,0.0007007501553744078), percent completed: 30.00%
# Epoch:30 /30, processing 10 / 30 files(toilet195.png.txt,0.0005566827021539211), percent completed: 33.33%
# Epoch:30 /30, processing 11 / 30 files(teddy345.png.txt,0.0008430968737229705), percent completed: 36.67%
# Epoch:30 /30, processing 12 / 30 files(sink160.png.txt,0.001288510044105351), percent completed: 40.00%
# Epoch:30 /30, processing 13 / 30 files(television015.png.txt,0.005298652220517397), percent completed: 43.33%
# Epoch:30 /30, processing 14 / 30 files(teddy285.png.txt,0.0007979226647876203), percent completed: 46.67%
# Epoch:30 /30, processing 15 / 30 files(hammer015.png.txt,0.0008683984051458538), percent completed: 50.00%
# Epoch:30 /30, processing 16 / 30 files(television010.png.txt,0.004966569598764181), percent completed: 53.33%
# Epoch:30 /30, processing 17 / 30 files(television035.png.txt,0.006103184074163437), percent completed: 56.67%
# Epoch:30 /30, processing 18 / 30 files(sink210.png.txt,0.0017868428258225322), percent completed: 60.00%
# Epoch:30 /30, processing 19 / 30 files(sink075.png.txt,0.0020306692458689213), percent completed: 63.33%
# Epoch:30 /30, processing 20 / 30 files(horse255.png.txt,0.0012464291648939252), percent completed: 66.67%
# Epoch:30 /30, processing 21 / 30 files(bed325.png.txt,0.001746154623106122), percent completed: 70.00%
# Epoch:30 /30, processing 22 / 30 files(fish245.png.txt,0.0016620155656710267), percent completed: 73.33%
# Epoch:30 /30, processing 23 / 30 files(teddy015.png.txt,0.0005854888004250824), percent completed: 76.67%
# Epoch:30 /30, processing 24 / 30 files(bed015.png.txt,0.0013435498112812638), percent completed: 80.00%
# Epoch:30 /30, processing 25 / 30 files(horse285.png.txt,0.00142819678876549), percent completed: 83.33%
# Epoch:30 /30, processing 26 / 30 files(guitar230.png.txt,0.000753900851123035), percent completed: 86.67%
# Epoch:30 /30, processing 27 / 30 files(teddy070.png.txt,0.0007072854205034673), percent completed: 90.00%
# Epoch:30 /30, processing 28 / 30 files(guitar025.png.txt,0.001074726926162839), percent completed: 93.33%
# Epoch:30 /30, processing 29 / 30 files(hammer340.png.txt,0.0008336145547218621), percent completed: 96.67%
# Epoch:30 /30, processing 30 / 30 files(television295.png.txt,0.004812449216842651), percent completed: 100.00%
#  Epoch 30/30, Averate MSE Loss: 0.001722, LR: 1.0e-04, time used: 1404.2 seconds
# 训练结束。用时1404.4195715秒

# %% [markdown]
# #  检查saved model

# %%
import torch
checkpoint = torch.load('./_forPaper_20260103_usingV1.2.3-train30-epoch30/best_model.pth',map_location=torch.device('cpu'))
print(checkpoint.keys())
for key in checkpoint.keys():
    print(f'{key}: {checkpoint[key]}') if key != 'model_state_dict' and key != 'optimizer_state_dict' else key
# Out:
# dict_keys(['config', 'epoch', 'trainsetsize', 'train_time', 'model_state_dict', 'optimizer_state_dict', 'loss', 'losshistory', 'notes'])
# config: {'k': 3, 'epochs': 30, 'batch_size': 1, 'numSelectedFiles': 30, 'num_ctrl': 30, 'hidden_dim': 256, 'lr': 0.0001, 'numIters': 1, 'numGnnLayers': 5, 'ctlptUpdateSpeed': 10, 'initControlMethod': 'random'}
# epoch: 27
# trainsetsize: 30
# train_time: 1403.6665890999998
# loss: 0.0013448850571876393
# losshistory: [6.442656144748131, 0.03394456235303854, 0.003085612852980072, 0.0017379682355870803, 0.0016671270054454605, 0.0015634472287880878, 0.0015509119781199842, 0.0014885653858073057, 0.0014647493177714448, 0.0014568603015504777, 0.0014378960370474184, 0.0014427944076790785, 0.0014325146146196251, 0.0014173715006715307, 0.0014044955789965267, 0.0013901232353722055, 0.0014713742440411201, 0.0014179183985106648, 0.001374755435002347, 0.001355140380716572, 0.001357874640962109, 0.0013647994433995335, 0.0013819563377182932, 0.0013511854485841468, 0.0013464521616697311, 0.001383992881164886, 0.0013448850571876393]
# notes: loss is the averate mse loss

# %% [markdown]
# # 预测和可视化
#
# ## <font color='880000'>在可视化代码中，无需考虑数据规范换和控制点反规范化的问题，因为其只是读取数据点和控制顶点数据，然后显示，而已</font>

# %%
import torch
import shutil
import time
import os,random


# ================== 模型应用模块 ==================
def computeFitterError(model,pred_controls,data_points,u_params):
    '''
    
    '''
#     print('model:',model)
#     print('shape of pred_controls:',pred_controls.shape)
#     print('shape of data_points:',data_points.shape)
#     print('shape of u_params:',u_params.shape)
    
   
    curve_pts =  evaluate_bspline(model, pred_controls, u_params)# 计算出预测出的控制顶点在uparams处的B样条曲线的值以便于数据点进行差值比较。注意，evaluatebspline函数中仅考虑准均匀B样条
    
#     print('shape of curve_pts:',curve_pts.shape)

    minr = np.min(data_points.numpy(),axis=0)
    maxr = np.max(data_points.numpy(),axis=0)
    diaglen = ((maxr[0] - minr[0]) ** 2 + (maxr[1] - minr[1]) ** 2) ** 0.5
    
    if False:
        lossvec = curve_pts - data_points
    #     loss = (lossvec[:,0] ** 2 + lossvec[:,1] ** 2) ** (0.5)
    #     print('shape of loss:',loss.shape)
        minloss = min(loss)
        maxloss = max(loss)

        loss =  np.sum(loss.numpy()) / len(loss)

        return loss/diaglen,minloss/diaglen,maxloss/diaglen
    else:
        loss = F.mse_loss(curve_pts,data_points)
        
        return loss.item() / diaglen,-1,-1

def apply_trained_model(model_path, new_data_root, output_dir='./controls',selectFilesNum=9,randomseed=None):
    '''
    用已训练好模型，对newdataroot中的每个数据进行预测，预测出的控制顶点存储到outputdir中
    
    所有预测操作均应通过该函数完成，因其中涉及到控制顶点的 反规范化操作
    
    param model_path: 存储模型参数的路径。例如：saved_models/best_model.pth
    param new_data_root: 用于预测的数据集的路径文件夹。该文件夹中可以有多个数据文件，每个文件代表一个数据集
    param output_dir: 保存从newdataroot中的每个文件预测出来的控制顶点数据的文件夹。其中包含多个文件，每个文件代表一个数据集的控制顶点数据，文件命名方式和数据集文件命名方式有关联（添加_pred）
    
    
    为写论文而进行的改动：
    1、对于每个输入文件夹（new_data_root）,我们先新建一个文件夹（先删除，后创建）:pred_results_{new_data_root}
    2、在上述文件夹中，创建如下文件夹：1. controls: 用来存储预测出来的控制顶点, 2. images: 每个数据的拟合情况（具体代码在visualize函数中）, 3. 文件:pred_loss.txt，记录全部数据的mse（将文件名也放进去，到时候用python提取mse）, 4. 文件overall.txt: 记录运行时间，最大mse信息，最小mse信息等
    '''
    destdir = './pred_results_' + new_data_root.split('/')[-2]
    if os.path.exists(destdir):
        HighlightPrint(f'Deleting old dest dir: {destdir}')
        shutil.rmtree(destdir)
    HighlightPrint(f'Creating new dest dir: {destdir}')
    os.makedirs(destdir)
    ctlptsdir = destdir + '/' + output_dir.split('/')[-1]
    HighlightPrint(f'Creating new Control Points dir:{ctlptsdir}')
    os.makedirs(ctlptsdir)
#     if os.path.exists(output_dir):
#         shutil.rmtree(output_dir)
#     os.makedirs(output_dir, exist_ok=True)  # 新增控制点目录
    
    # 加载模型配置
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    checkpoint = torch.load(model_path, map_location=torch.device(device))
    config = checkpoint['config']
    print(f'Test with {device}')

    # 重建模型
    model = BSplineGNN(
        k=config['k'],
        hidden_dim=config['hidden_dim'], 
        num_iter=config['numIters'], 
        num_GNN_layers=config['numGnnLayers'], 
        ctlptUpdateSpeed=config['ctlptUpdateSpeed']
    )
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()

    # 加载新数据集
    new_dataset = PointCloudDataset(
        root=new_data_root,
        num_ctrl=config['num_ctrl'],
        numFilesSelected = selectFilesNum,
        randomseed = randomseed,
        shufflepoints = False
    )
    new_loader = DataLoader(new_dataset, batch_size=1, shuffle=False)

    if os.path.exists(output_dir):
        shutil.rmtree(output_dir)
    os.makedirs(output_dir, exist_ok=True)

    filelist = list()
    MSElist = list()
    totalloss = 0
    minMSE = 1
    maxMSE = 0
    minMSEfile = ''
    maxMSEfile = ''
    totaltime = 0
    nprocessed= 0
    with torch.no_grad():
        for batch in new_loader:
            filename = batch.filename[0]
            nprocessed += 1
            HighlightPrint(f'数据点文件:{os.path.join(new_data_root, filename)}, {nprocessed}/{len(new_loader)}, 预计耗时{totaltime / nprocessed * (len(new_loader) - nprocessed)}秒')
            filelist.append(filename)
            
            starttime = time.perf_counter()
            pred_controls = model(batch)
            curtime = time.perf_counter() - starttime
            totaltime += curtime
            
            # 这里应加入B样条曲线与数据之间的规范化误差度量
            loss,minloss,maxloss = computeFitterError(model,pred_controls=pred_controls,data_points=batch[0].x[pred_controls.shape[0]:,:],u_params=batch[0].u_params)
            HighlightPrint(f'MSE loss(Relative):{loss}, 耗时:{curtime:.1f}秒({batch[0].x.shape[0] - pred_controls.shape[0]}个数据点)')
            print(f'min loss(Relative): {minloss}') if minloss > 0 else 'nothing'
            print(f'max loss(Relative): {maxloss}',) if maxloss > 0 else 'nothing'
            print('Accumulated Squared Loss(Relative):',loss * (batch[0].x.shape[0]-pred_controls.shape[0]))
            MSElist.append(loss)
            totalloss += loss
            
            if minMSE > loss.item():
                minMSE = loss.item()
                minMSEfile = batch[0].filename
            if maxMSE < loss.item():
                maxMSE = loss.item()
                maxMSEfile = batch[0].filename
            
            
            '''
            这里进行预测控制顶点的反规范化操作
            '''
            # 先读取原始数据文件，获取规范化过程中的参数
            points = np.loadtxt(os.path.join(new_data_root, filename))
#             print('before normalization:',np.std(points,axis=0))
            points,mean,std = z_score_normalize(points) # 将数据规范化，重要的是要获取规范化过程中的参数
#             print('after normalization:',np.std(points,axis=0))
            
            # 随后将预测出来的控制顶点反规范化
            inv_normalized_pred_controls = inverse_z_score(pred_controls.cpu().numpy(),mean,std)

            # 保存预测结果
            filename = batch.filename[0].replace('.txt', '_pred.txt')
            save_path = os.path.join(ctlptsdir, filename)
            np.savetxt(
                save_path,
#                 pred_controls.cpu().numpy(),
                inv_normalized_pred_controls,
                fmt='%.6f',
                header=f'Predicted Controls (Model: {(model_path)})'
            )
            
    HighlightPrint(f"数据集预测结果完成，控制顶点结果已保存至 {ctlptsdir}")
    HighlightPrint(f'平均MSE:{totalloss / len(new_loader):.6f}')
    HighlightPrint(f'耗时（不包括存储控制顶点数据到磁盘）: {totaltime:.1f} 秒')
    MSEfile = destdir + '/loss.txt'
    with open(MSEfile,'w',encoding='utf-8') as f:
        for loss in MSElist:
            f.write(f'{loss:.8f}\n')
            
    overlookfile = destdir + '/overlook.txt'
    with open(overlookfile,'w',encoding='utf-8') as f:
        f.write(f'用时（不包括乱七八糟的操作）: {totaltime:.1f}秒\n')
        f.write(f'平均MSE: {totalloss / len(new_loader):.8f}\n')
        f.write(f'最小MSE: {minMSE:.8f}: {minMSEfile}\n')
        f.write(f'最大MSE: {maxMSE:.8f}: {maxMSEfile}\n')
        
    return filelist,MSElist,destdir,ctlptsdir



# 可视化部分
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# ---------------------- B样条核心算法 ----------------------
def BaseFunction(i, k, u, knot):
    """B样条基函数计算 (优化版)"""
    lastNonDegradeKnot = -2
    for j in range(-2, -len(knot) - 1, -1):
        if knot[j] < knot[j + 1]:
            lastNonDegradeKnot = j
            break
    lastNonDegradeKnot += len(knot)

    if k == 1:
        if knot[i] >= knot[i + 1]:
            return 0.0
        condition = (u >= knot[i]) & (u <= knot[i + 1]) if i == lastNonDegradeKnot else (u >= knot[i]) & (
                u < knot[i + 1])
        return 1.0 if condition else 0.0
    else:
        denom1 = knot[i + k - 1] - knot[i]
        denom2 = knot[i + k] - knot[i + 1]
        term1 = 0.0 if denom1 == 0 else (u - knot[i]) / denom1 * BaseFunction(i, k - 1, u, knot)
        term2 = 0.0 if denom2 == 0 else (knot[i + k] - u) / denom2 * BaseFunction(i + 1, k - 1, u, knot)
        return term1 + term2

def generate_open_uniform_knots(n_ctrl, degree=3):
    """生成开放均匀节点向量"""
    total_knots = n_ctrl + degree + 1
    knots = np.zeros(total_knots)
    knots[-degree - 1:] = 1.0  # 尾部节点

    if n_ctrl > degree:
        internal = np.linspace(0, 1, n_ctrl - degree + 1)[1:-1]
        knots[degree + 1:-degree - 1] = internal
    return knots

def generate_bspline_curve(ctrl_points, degree=3, sample_num=200):
    """生成B样条曲线"""
    '''
    注意：这里并不要求ctrlpoints的范围必须是-1到+1之间，而是全支持。具体是先计算曲线点再变换，还是对控制顶点先变换在输入到本函数计算曲线，由用户决定。前置变换还是后置变换的问题。
    '''
    n = len(ctrl_points)
    if n < 2:
        return np.array([])

    actual_degree = min(degree, n - 1)
    knots = generate_open_uniform_knots(n, actual_degree)
    u_values = np.linspace(0, 1, sample_num)

    curve = []
    for u in u_values:
        point = np.zeros(2)
        for i in range(n):
            Nik = BaseFunction(i, actual_degree + 1, u, knots)
            point += ctrl_points[i] * Nik
        curve.append(point)
    return np.array(curve)

# ---------------------- 数据读取增强 ----------------------
def read_control_files(directory):
    """读取控制点文件（含异常处理）"""
    '''
    从directory中读取全部数据文件(其实是控制顶点数据)，返回一个字典：keys是每个数据文件的路径，values是每个数据文件的控制顶点数据
    '''
    file_pattern = os.path.join(directory, "*.txt")
    control_files = glob.glob(file_pattern)

    control_data = {}
    for file_path in control_files:
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                lines = [line.strip() for line in f if line.strip()]
                if not lines: continue

                # 解析控制点
                points = []
                for line in lines[1:]:  # 跳过标题行
                    parts = line.split()
                    if len(parts) >= 2:
                        try:
                            x, y = map(float, parts[:2])
                            points.append((x, y))
                        except ValueError:
                            continue

                if len(points) >= 2:
                    control_data[os.path.basename(file_path)] = np.array(points)
        except Exception as e:
            print(f"Error reading {file_path}: {str(e)}")
    return control_data

def find_original_points(ctrl_filename, original_dir,shufflepoints=False):
    """根据控制点文件名查找原始数据点"""
    '''
    给定控制顶点数据文件ctrlfilename，从起文件名推测对应的数据点文件名，将该文件载入并返回。
    这里并  未进行数据点的规范化， 也不必进行数据点的规范化。
    
    shufflepoints 的目的是模拟undordered数据。对当前版本用不上。
    '''
    original_name = ctrl_filename.replace("_pred", "")
    original_path = os.path.join(original_dir, original_name)

    if os.path.exists(original_path):
        try:
            with open(original_path, 'r', encoding='utf-8') as f:
                lines = [line.strip() for line in f if line.strip()]
                points = []
                for line in lines[1:]:  # 跳过标题行
                    parts = line.split()
                    if len(parts) >= 2:
                        x, y = map(float, parts[:2])
                        points.append((x, y))
                points = np.array(points)
                if shufflepoints:
                    points = points[np.random.choice(points.shape[0],points.shape[0],replace = False)]
                else:
                    pass
                return points if points.shape[0] >=2 else None
        except Exception as e:
            print(f"读取原始数据错误 {original_path}: {str(e)}")
    return None


# ---------------------- 可视化模块 ----------------------
def visualize_closed_paths(control_data, save_path=None, original_dir=None,randomseed=None):
    """B样条拟合结果可视化"""
    '''
    从controldata中提取控制点数据（多组），用准均匀B样条曲线绘制，图片结果保存在savepath中。控制顶点对应的原始数据所在的路径存储在originaldir中。
    param control_data: 字典。keys是控制点文件对应的文件名，values是控制点数据
    '''
    fig=None
    axes=None
    if len(control_data) == 1:
        fig,axes = plt.subplots(nrows=1,ncols=1,figsize=(12,8),dpi=100)
    elif len(control_data) == 2:
        fig,axes = plt.subplots(nrows=1,ncols=2,figsize=(12,8),dpi=100)
    elif len(control_data) < 5:
        fig,axes = plt.subplots(nrows=2,ncols=2,figsize=(12,8),dpi=100)
    else:
        fig,axes = plt.subplots(nrows=3,ncols=3,figsize=(12,8),dpi=100)
        print(f'可视化最多支持9个数据，随机抽取9个显示')
        
        random.seed(randomseed) if randomseed is not None else 'nothing'
        control_data = {key : control_data[key] for key in random.sample(control_data.keys(),9)}
#     else:
#         raise ValueError('可视化最多支持9个数据')
#         return
#     plt.figure(figsize=(12, 8), dpi=100)
#     ax = plt.gca()

    # 严格配色方案
    input_point_color = '#00ff00'   # 输入点灰色
    curve_color = '#1f77b4'         # 曲线蓝色
    control_point_color = '#d62728' # 控制点红色
    polygon_color = '#2C3E50'        # 控制多边形深灰

    # 收集所有数据点
#     all_points = [] # 目的是当有多个数据文件的时候，显示在一个窗口中。这其实是没必要的。正确的做法应该是开辟多个窗口，每个窗口显示一个数据。

    for idx, (filename, ctrl_points) in enumerate(control_data.items()):
        '''
        从controldata中推测数据点文件名并载入
        '''
        if len(control_data) == 1:
            ax = axes
        elif len(control_data) == 2:
            ax = axes[idx]
        elif len(control_data) < 5:
            ax = axes[idx//2][idx - idx//2*2]
        elif len(control_data) <= 9:
            ax = axes[idx//3][idx - idx//3*3]
        else:
            pass
        
        # ================= 原始数据点 =================
        if original_dir:
            # 对原始顶点进行随机选择，将有序点变为无序点
            shufflepoints = False
            original_points = find_original_points(filename, original_dir,shufflepoints=shufflepoints) # 推测数据点文件名并载入数据。该数据   无需进行规范化
            if original_points is None:
                print(f'{filename} 数据点未找到')
            if original_points is not None:# 显示原始数据点
                
                
                ax.scatter(original_points[:, 0], original_points[:, 1],
                          s=45,                # 增大点尺寸
                          marker='o',
                          edgecolor='white',  # 添加白色边框
                          linewidths=0.8,      # 边框粗细
                          facecolor= input_point_color, # 使用更深灰色
                          alpha=0.9,          # 提高不透明度
                          zorder=0,
                          label='Input Points') # ,                           c=range(original_points.shape[0]), cmap='jet'

                
        # ================= 控制多边形（恢复显示） =================
#         ax.plot(ctrl_points[:, 0], ctrl_points[:, 1],
#                linestyle=(0, (5, 5)),  # 虚线样式
#                linewidth=1.2,
#                color=polygon_color,
#                alpha=0.7,
#                zorder=1,
#                label='Control Polygon')

        # ================= 控制点（改为实心红点） =================
#         ax.scatter(ctrl_points[:, 0], ctrl_points[:, 1],
#                   s=60, marker='o',
#                   edgecolor=control_point_color,
#                   linewidths=1.0,
#                   facecolor=control_point_color,  # 实心填充
#                   zorder=3,
#                   label='Control Points' #,c=range(ctrl_points.shape[0]), cmap='jet'
#                  )

        
        # ================= B样条曲线 =================
        curve = generate_bspline_curve(ctrl_points)
        if curve.size > 0:
            ax.plot(curve[:, 0], curve[:, 1],
                   linewidth=2.5,
                   color=curve_color,
                   alpha=0.9,
                   solid_capstyle='round',
                   zorder=2,
                   label='B-spline Curve')
            
            

#         all_points.append(ctrl_points)

    # ================= 自适应坐标范围 =================
#     combined_points = np.vstack(all_points)
        combined_points = ctrl_points
        x_pad = np.ptp(combined_points[:, 0]) * 0.1
        y_pad = np.ptp(combined_points[:, 1]) * 0.1

        # ax.set_aspect('equal', adjustable='datalim')  # 保证XY轴单位长度一致

        ax.set_xlim(combined_points[:, 0].min()-x_pad,
                   combined_points[:, 0].max()+x_pad)
        ax.set_ylim(combined_points[:, 1].min()-y_pad,
                   combined_points[:, 1].max()+y_pad)
        ax.invert_yaxis()

        # ================= 画布样式 =================
        ax.set_facecolor('white')
        ax.grid(True, linestyle='--', color='#D3D3D3', linewidth=0.5)
        ax.set_xlabel('X', fontsize=12)
        ax.set_ylabel('Y', fontsize=12)
        ax.set_title(filename,
                    fontsize=14, pad=15, weight='bold')
        
        ax.set_aspect('equal')

        # ================= 图例优化 =================
        handles, labels = ax.get_legend_handles_labels()
        legend_order = {
            'Input Points': 0,
            'B-spline Curve': 1,
            'Control Points': 2,
            'Control Polygon': 3
        }
        sorted_handles = [h for _, h in sorted(zip(labels, handles),
                              key=lambda x: legend_order.get(x[0], 4))]
        sorted_labels = sorted(labels, key=lambda x: legend_order.get(x, 4))
        
#         ax.legend(sorted_handles, sorted_labels,
#                  loc='upper right',
#                  frameon=True,
#                  edgecolor='black',
#                  fontsize=10)

    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, bbox_inches='tight', dpi=300)
    plt.show()


    
def savefigs(control_data, save_path=None, original_dir=None):
    
    if os.path.exists(save_path):
        HighlightPrint(f'Deleting old dest dir: {save_path}')
        shutil.rmtree(save_path)
    HighlightPrint(f'Creating new dest dir: {save_path}')
    os.makedirs(save_path)
    fig=None
    axes=None
    fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(12,8),dpi=300)

    # 严格配色方案
    input_point_color = '#00ff00'   # 输入点灰色
    curve_color = '#1f77b4'         # 曲线蓝色
    control_point_color = '#d62728' # 控制点红色
    polygon_color = '#2C3E50'        # 控制多边形深灰
    
    nfiles = len(control_data.keys())


    for idx, (filename, ctrl_points) in enumerate(control_data.items()):
        '''
        从controldata中推测数据点文件名并载入
        '''
        ax = axis
        ax.clear()
               
        # ================= 原始数据点 =================
        if original_dir:
            # 对原始顶点进行随机选择，将有序点变为无序点
            shufflepoints = False
            original_points = find_original_points(filename, original_dir,shufflepoints=shufflepoints) # 推测数据点文件名并载入数据。该数据   无需进行规范化
            
            if original_points is None:
                print(f'{filename} 数据点未找到')
            if original_points is not None:# 显示原始数据点
                ax.scatter(original_points[:, 0], original_points[:, 1],
                          s=45,                # 增大点尺寸
                          marker='o',
                          edgecolor='white',  # 添加白色边框
                          linewidths=0.8,      # 边框粗细
                          facecolor= input_point_color, # 使用更深灰色
                          alpha=0.9,          # 提高不透明度
                          zorder=0,
                          label='Input Points') # ,                           c=range(original_points.shape[0]), cmap='jet'

                
        # ================= 控制多边形 =================
#         ax.plot(ctrl_points[:, 0], ctrl_points[:, 1],
#                linestyle=(0, (5, 5)),  # 虚线样式
#                linewidth=1.2,
#                color=polygon_color,
#                alpha=0.7,
#                zorder=1,
#                label='Control Polygon')

        # ================= 控制点（改为实心红点） =================
#         ax.scatter(ctrl_points[:, 0], ctrl_points[:, 1],
#                   s=60, marker='o',
#                   edgecolor=control_point_color,
#                   linewidths=1.0,
#                   facecolor=control_point_color,  # 实心填充
#                   zorder=3,
#                   label='Control Points' #,c=range(ctrl_points.shape[0]), cmap='jet'
#                  )

        
        # ================= B样条曲线 =================
        curve = generate_bspline_curve(ctrl_points)
        if curve.size > 0:
            ax.plot(curve[:, 0], curve[:, 1],
                   linewidth=2.5,
                   color=curve_color,
                   alpha=0.9,
                   solid_capstyle='round',
                   zorder=2,
                   label='B-spline Curve')

    # ================= 自适应坐标范围 =================
#     combined_points = np.vstack(all_points)
        combined_points = ctrl_points
        x_pad = np.ptp(combined_points[:, 0]) * 0.1
        y_pad = np.ptp(combined_points[:, 1]) * 0.1

        # ax.set_aspect('equal', adjustable='datalim')  # 保证XY轴单位长度一致

        ax.set_xlim(combined_points[:, 0].min()-x_pad,
                   combined_points[:, 0].max()+x_pad)
        ax.set_ylim(combined_points[:, 1].min()-y_pad,
                   combined_points[:, 1].max()+y_pad)
        ax.invert_yaxis()

        # ================= 画布样式 =================
        ax.set_facecolor('white')
        ax.grid(True, linestyle='--', color='#D3D3D3', linewidth=0.5)
        ax.set_xlabel('X', fontsize=12)
        ax.set_ylabel('Y', fontsize=12)
#         ax.set_title(filename,fontsize=14, pad=15, weight='bold')
        ax.set_aspect('equal')

        # ================= 图例优化 =================
        handles, labels = ax.get_legend_handles_labels()
        legend_order = {
            'Input Points': 0,
            'B-spline Curve': 1,
            'Control Points': 2,
            'Control Polygon': 3
        }
        sorted_handles = [h for _, h in sorted(zip(labels, handles),
                              key=lambda x: legend_order.get(x[0], 4))]
        sorted_labels = sorted(labels, key=lambda x: legend_order.get(x, 4))
        
#         ax.legend(sorted_handles, sorted_labels,
#                  loc='upper right',
#                  frameon=True,
#                  edgecolor='black',
#                  fontsize=10)

#         plt.tight_layout()
        if save_path:
            imagepath = save_path + os.path.basename(filename) + '.jpeg'
            HighlightPrint(f'Saving image in {imagepath}, {idx + 1} / {nfiles}')
            plt.savefig(imagepath, bbox_inches='tight', dpi=300)

# %% [markdown]
# #  执行预测和可视化

# %%
import os
import shutil

useWinVoice = True

validfolder = validsetpath

# './data/imagedataset-from-curve-benchmark/Flipped1070OrderedVertices_5_20/'
# './data/coord_seligFmt-from-UIUC-airfoil-paper-2025/'
# './data/pred/noisyset/'


# 下面的这些不行主要原因应该是数据点过多，在构建pointclouddataset的时候采样1000个，导致采样率不够。
# 解决办法很简单：修改pointclouddataset，不采样，或按照百分比采样。
# 因为我们的网络架构对于数据点个数没有任何限制
#  'E:/_Papers/_data/curvefitting/2021-Curve Reconstruction Survey and Benchmark/curve-benchmark-new/Dataset/Text_Files_1070png/' 
#  'E:/_Papers/_data/curvefitting/2021-Curve Reconstruction Survey and Benchmark/curve-benchmark-new/Dataset/Text_Files_HS-SOD/'
#  'E:/_Papers/_data/curvefitting/2021-Curve Reconstruction Survey and Benchmark/curve-benchmark-new/Dataset/Text_FilesETU/'
#  'E:/_Papers/_data/curvefitting/2021-Curve Reconstruction Survey and Benchmark/curve-benchmark-new/Dataset/Text_FilesMPEG/'
datasets = [
    validfolder,
            './data/imagedataset-from-curve-benchmark/Flipped1070OrderedVertices_5_20/',
            './data/coord_seligFmt-from-UIUC-airfoil-paper-2025/',
           './data/imagedataset-from-curve-benchmark/kitchenOrderedVertices_1_20/',
#            './data/manifold-from-curve-benchmark-testdata/', # 不是ordered points
           './data/pred/LSPIAset/',
           './data/pred/noisyset/']
for folder in datasets:
    # 预测
    #应用模式
    startTime = time.perf_counter()
    filelist,MSEs,destdir,ctlptsdir = apply_trained_model(
        model_path='./_forPaper_20260103_usingV1.2.3-train30-epoch30/best_model.pth',
        new_data_root= folder,
        output_dir='./controls',
        selectFilesNum = None,
        randomseed=43
    )
    HighlightPrint(f'预测用时{time.perf_counter() - startTime:.1f} 秒')

    if useWinVoice:
        import win32com.client as win
        speak=win.Dispatch("SAPI.SpVoice")
        speak.speak(f"预测结束了")

    # 可视化
    # 控制点目录
    destdir = './pred_results_' + folder.split('/')[-2]
    ctlptsdir = destdir + '/controls'
    CTRL_DIR = ctlptsdir # 存储的是在main中用mode=1获得的对于已保存到savedmodel中的bestmodel作用到数据文件夹pred中每个数据预测出来并保存到controls中的控制顶点

    # 原始数据目录（根据实际情况修改）
    ORIGINAL_DIR = folder  # 对应与controls中的控制顶点数据的原始数据点数据文件

    control_data = read_control_files(CTRL_DIR) # 从控制顶点文件夹中读取全部文件名和响应的数据
    if control_data:
        HighlightPrint(f"可视化：成功加载 {len(control_data)} 个控制点文件")
        HighlightPrint('显示其中若干结果')
        visualize_closed_paths(
            control_data,
            save_path=destdir + "./enhanced_visualization.jpg",
            original_dir=ORIGINAL_DIR
        )

        if useWinVoice:
            import win32com.client as win
            speak=win.Dispatch("SAPI.SpVoice")
            speak.speak('可视化结束了')

        savedpath = destdir + '/images/'
        HighlightPrint(f'将全部结果保存到{savedpath}')    
        savefigs(control_data,
                 save_path=savedpath,
                 original_dir=ORIGINAL_DIR)
        if useWinVoice:
            speak.speak(f'全部预测结果以图片形式保存到{savedpath}')
    else:
        print(f"目录 {CTRL_DIR} 中未找到有效控制点文件")
# Out:
#  Creating new dest dir: ./pred_results_validset
#  Creating new Control Points dir:./pred_results_validset/controls
# Test with cpu
#  BSplineGNN key parameters:
# 	num iterations:1
# 	num Gnn layers:5
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  数据集中有190 个文件，我们只使用其中的190个文件。
#  数据点文件:./data/dataset/v2/validset/bed320.png.txt, 1/190, 预计耗时0.0秒
#  MSE loss(Relative):0.0004639114580985614, 耗时:1.1秒(174个数据点)
# Accumulated Squared Loss(Relative): 0.08072059370914968
#  数据点文件:./data/dataset/v2/validset/fish020.png.txt, 2/190, 预计耗时101.14926400001013秒
#  MSE loss(Relative):0.00027879563024964363, 耗时:0.5秒(87个数据点)
# Accumulated Squared Loss(Relative): 0.024255219831718997
#  数据点文件:./data/dataset/v2/validset/bird205.png.txt, 3/190, 预计耗时100.62963056667778秒
#  MSE loss(Relative):0.00023842596295758111, 耗时:0.6秒(97个数据点)
# Accumulated Squared Loss(Relative): 0.023127318406885367
#  数据点文件:./data/dataset/v2/validset/bird185.png.txt, 4/190, 预计耗时102.95953740000323秒
#  MSE loss(Relative):0.00024439655921162424, 耗时:0.6秒(103个数据点)
# Accumulated Squared Loss(Relative): 0.025172845598797296
#  数据点文件:./data/dataset/v2/validset/sink000.png.txt, 5/190, 预计耗时105.43027529999723秒
#  MSE loss(Relative):0.00032157265457188135, 耗时:0.4秒(65个数据点)
# Accumulated Squared Loss(Relative): 0.020902222547172288
#  数据点文件:./data/dataset/v2/validset/sink190.png.txt, 6/190, 预计耗时99.7678083999981秒
#  MSE loss(Relative):0.0002979998448853495, 耗时:0.4秒(65个数据点)
# Accumulated Squared Loss(Relative): 0.01936998991754772
#  数据点文件:./data/dataset/v2/validset/horse265.png.txt, 7/190, 预计耗时96.057847671427秒
#  MSE loss(Relative):0.00019628824969638233, 耗时:0.5秒(66个数据点)
# Accumulated Squared Loss(Relative): 0.012955024479961235
#  数据点文件:./data/dataset/v2/validset/sink010.png.txt, 8/190, 预计耗时94.37219382499546秒
#  MSE loss(Relative):0.00031916000597961966, 耗时:0.4秒(64个数据点)
# Accumulated Squared Loss(Relative): 0.020426240382695658
#  数据点文件:./data/dataset/v2/validset/sink230.png.txt, 9/190, 预计耗时91.27050694444138秒
#  MSE loss(Relative):0.000288356955683013, 耗时:0.4秒(62个数据点)
# Accumulated Squared Loss(Relative): 0.017878131252346805
#  数据点文件:./data/dataset/v2/validset/hammer185.png.txt, 10/190, 预计耗时88.6142339999974秒
#  MSE loss(Relative):0.00023785254858248783, 耗时:0.6秒(93个数据点)
# Accumulated Squared Loss(Relative): 0.022120287018171366
#  数据点文件:./data/dataset/v2/validset/horse175.png.txt, 11/190, 预计耗时89.43453644545276秒
#  MSE loss(Relative):0.00039745967619832185, 耗时:0.7秒(116个数据点)
# Accumulated Squared Loss(Relative): 0.046105322439005336
#  数据点文件:./data/dataset/v2/validset/sink355.png.txt, 12/190, 预计耗时92.12364338333381秒
#  MSE loss(Relative):0.000378060514169428, 耗时:0.5秒(66个数据点)
# Accumulated Squared Loss(Relative): 0.02495199393518225
#  数据点文件:./data/dataset/v2/validset/bird280.png.txt, 13/190, 预计耗时91.16811433846223秒
#  MSE loss(Relative):0.0003484184929199276, 耗时:0.5秒(83个数据点)
# Accumulated Squared Loss(Relative): 0.028918734912353992
#  数据点文件:./data/dataset/v2/validset/bird145.png.txt, 14/190, 预计耗时91.00150022857088秒
#  MSE loss(Relative):0.0002199908051638844, 耗时:0.6秒(92个数据点)
# Accumulated Squared Loss(Relative): 0.020239154075077363
#  数据点文件:./data/dataset/v2/validset/hammer125.png.txt, 15/190, 预计耗时91.20509649999879秒
#  MSE loss(Relative):0.0002521396954465742, 耗时:0.5秒(84个数据点)
# Accumulated Squared Loss(Relative): 0.021179734417512232
#  数据点文件:./data/dataset/v2/validset/bird335.png.txt, 16/190, 预计耗时90.58644558749847秒
#  MSE loss(Relative):0.00027971260451998485, 耗时:0.6秒(100个数据点)
# Accumulated Squared Loss(Relative): 0.027971260451998485
#  数据点文件:./data/dataset/v2/validset/television355.png.txt, 17/190, 预计耗时91.09864631176139秒
#  MSE loss(Relative):0.001114806212385401, 耗时:1.3秒(215个数据点)
# Accumulated Squared Loss(Relative): 0.2396833356628612
#  数据点文件:./data/dataset/v2/validset/hammer045.png.txt, 18/190, 预计耗时98.31305095555231秒
#  MSE loss(Relative):0.000238369350294076, 耗时:0.5秒(86个数据点)
# Accumulated Squared Loss(Relative): 0.020499764125290535
#  数据点文件:./data/dataset/v2/validset/bird030.png.txt, 19/190, 预计耗时97.30111409999631秒
#  MSE loss(Relative):0.0003122066819329828, 耗时:0.6秒(98个数据点)
# Accumulated Squared Loss(Relative): 0.03059625482943231
#  数据点文件:./data/dataset/v2/validset/teddy140.png.txt, 20/190, 预计耗时97.15103219999548秒
#  MSE loss(Relative):0.00015000618575032942, 耗时:0.6秒(99个数据点)
# Accumulated Squared Loss(Relative): 0.014850612389282612
#  数据点文件:./data/dataset/v2/validset/sink215.png.txt, 21/190, 预计耗时96.88749398094927秒
#  MSE loss(Relative):0.0003586867391852479, 耗时:0.3秒(57个数据点)
# Accumulated Squared Loss(Relative): 0.02044514413355913
#  数据点文件:./data/dataset/v2/validset/television270.png.txt, 22/190, 预计耗时94.60246167272314秒
#  MSE loss(Relative):0.0008084621069960766, 耗时:0.5秒(87个数据点)
# Accumulated Squared Loss(Relative): 0.07033620330865867
#  数据点文件:./data/dataset/v2/validset/sink155.png.txt, 23/190, 预计耗时93.81413056521272秒
#  MSE loss(Relative):0.00031165459235136975, 耗时:0.4秒(67个数据点)
# Accumulated Squared Loss(Relative): 0.020880857687541773
#  数据点文件:./data/dataset/v2/validset/toilet005.png.txt, 24/190, 预计耗时92.21802634166173秒
#  MSE loss(Relative):0.00015397694028740713, 耗时:0.8秒(105个数据点)
# Accumulated Squared Loss(Relative): 0.01616757873017775
#  数据点文件:./data/dataset/v2/validset/hammer250.png.txt, 25/190, 预计耗时93.09317159999519秒
#  MSE loss(Relative):0.00022538417565667158, 耗时:0.5秒(77个数据点)
# Accumulated Squared Loss(Relative): 0.01735458152556371
#  数据点文件:./data/dataset/v2/validset/guitar305.png.txt, 26/190, 预计耗时91.95969981538009秒
#  MSE loss(Relative):0.00026529802176890544, 耗时:0.4秒(59个数据点)
# Accumulated Squared Loss(Relative): 0.01565258328436542
#  数据点文件:./data/dataset/v2/validset/guitar355.png.txt, 27/190, 预计耗时90.21487106666287秒
#  MSE loss(Relative):0.0002958647651540707, 耗时:0.4秒(68个数据点)
# Accumulated Squared Loss(Relative): 0.02011880403047681
#  数据点文件:./data/dataset/v2/validset/television265.png.txt, 28/190, 预计耗时88.92925257856808秒
#  MSE loss(Relative):0.0006823826797687672, 耗时:0.6秒(96个数据点)
# Accumulated Squared Loss(Relative): 0.06550873725780165
#  数据点文件:./data/dataset/v2/validset/bed150.png.txt, 29/190, 预计耗时88.64107992068584秒
#  MSE loss(Relative):0.0005688233659210329, 耗时:1.1秒(167个数据点)
# Accumulated Squared Loss(Relative): 0.0949935021088125
#  数据点文件:./data/dataset/v2/validset/hammer080.png.txt, 30/190, 预计耗时90.7578975999968秒
#  MSE loss(Relative):0.00024118252894388522, 耗时:0.5秒(73个数据点)
# Accumulated Squared Loss(Relative): 0.01760632461290362
#  数据点文件:./data/dataset/v2/validset/hammer210.png.txt, 31/190, 预计耗时89.65650813870596秒
#  MSE loss(Relative):0.00023306585831886395, 耗时:0.6秒(92个数据点)
# Accumulated Squared Loss(Relative): 0.02144205896533548
#  数据点文件:./data/dataset/v2/validset/bed145.png.txt, 32/190, 预计耗时89.10150781249675秒
#  MSE loss(Relative):0.00038713260184005776, 耗时:1.0秒(167个数据点)
# Accumulated Squared Loss(Relative): 0.06465114450728965
#  数据点文件:./data/dataset/v2/validset/guitar300.png.txt, 33/190, 预计耗时90.83702812423851秒
#  MSE loss(Relative):0.00027319089421956204, 耗时:0.4秒(58个数据点)
# Accumulated Squared Loss(Relative): 0.0158450718647346
#  数据点文件:./data/dataset/v2/validset/toilet035.png.txt, 34/190, 预计耗时89.31989911764387秒
#  MSE loss(Relative):0.00017784622305773643, 耗时:0.8秒(119个数据点)
# Accumulated Squared Loss(Relative): 0.021163700543870637
#  数据点文件:./data/dataset/v2/validset/guitar035.png.txt, 35/190, 预计耗时89.5430792857115秒
#  MSE loss(Relative):0.0002362368369329527, 耗时:0.4秒(67个数据点)
# Accumulated Squared Loss(Relative): 0.015827868074507832
#  数据点文件:./data/dataset/v2/validset/toilet325.png.txt, 36/190, 预计耗时88.22706798888632秒
#  MSE loss(Relative):0.00014342095724789825, 耗时:0.8秒(122个数据点)
# Accumulated Squared Loss(Relative): 0.017497356784243585
#  数据点文件:./data/dataset/v2/validset/bed005.png.txt, 37/190, 预计耗时88.48007284864624秒
#  MSE loss(Relative):0.0005371797559435301, 耗时:0.9秒(138个数据点)
# Accumulated Squared Loss(Relative): 0.07413080632020716
#  数据点文件:./data/dataset/v2/validset/bed135.png.txt, 38/190, 预计耗时89.074963199997秒
#  MSE loss(Relative):0.0005644980526583112, 耗时:1.1秒(178个数据点)
# Accumulated Squared Loss(Relative): 0.1004806533731794
#  数据点文件:./data/dataset/v2/validset/guitar270.png.txt, 39/190, 预计耗时90.45205949230451秒
#  MSE loss(Relative):0.00017906471092377546, 耗时:0.3秒(50个数据点)
# Accumulated Squared Loss(Relative): 0.008953235546188773
#  数据点文件:./data/dataset/v2/validset/toilet300.png.txt, 40/190, 预计耗时88.81231574999703秒
#  MSE loss(Relative):0.0002023500961611796, 耗时:0.8秒(130个数据点)
# Accumulated Squared Loss(Relative): 0.026305512500953348
#  数据点文件:./data/dataset/v2/validset/bird195.png.txt, 41/190, 预计耗时89.0382476243868秒
#  MSE loss(Relative):0.0002520882335923259, 耗时:0.6秒(101个数据点)
# Accumulated Squared Loss(Relative): 0.025460911592824917
#  数据点文件:./data/dataset/v2/validset/hammer280.png.txt, 42/190, 预计耗时88.52773849523427秒
#  MSE loss(Relative):0.0002102686363931993, 耗时:0.5秒(74个数据点)
# Accumulated Squared Loss(Relative): 0.015559879093096748
#  数据点文件:./data/dataset/v2/validset/fish165.png.txt, 43/190, 预计耗时87.45380714650787秒
#  MSE loss(Relative):0.00020878096079590496, 耗时:0.5秒(85个数据点)
# Accumulated Squared Loss(Relative): 0.017746381667651922
#  数据点文件:./data/dataset/v2/validset/fish105.png.txt, 44/190, 预计耗时86.61549080908719秒
#  MSE loss(Relative):0.00022078943872730128, 耗时:0.3秒(48个数据点)
# Accumulated Squared Loss(Relative): 0.01059789305891046
#  数据点文件:./data/dataset/v2/validset/hammer115.png.txt, 45/190, 预计耗时85.0515151333296秒
#  MSE loss(Relative):0.00023795105578090325, 耗时:0.5秒(80个数据点)
# Accumulated Squared Loss(Relative): 0.01903608446247226
#  数据点文件:./data/dataset/v2/validset/horse335.png.txt, 46/190, 预计耗时84.15899373912703秒
#  MSE loss(Relative):0.0003330336143032178, 耗时:0.7秒(103个数据点)
# Accumulated Squared Loss(Relative): 0.034302462273231436
#  数据点文件:./data/dataset/v2/validset/toilet140.png.txt, 47/190, 预计耗时83.80174173191163秒
#  MSE loss(Relative):0.0001790413591848539, 耗时:0.8秒(123个数据点)
# Accumulated Squared Loss(Relative): 0.02202208717973703
#  数据点文件:./data/dataset/v2/validset/guitar255.png.txt, 48/190, 预计耗时83.76032885832973秒
#  MSE loss(Relative):0.0002819318127485766, 耗时:0.3秒(56个数据点)
# Accumulated Squared Loss(Relative): 0.015788181513920287
#  数据点文件:./data/dataset/v2/validset/fish315.png.txt, 49/190, 预计耗时82.47223288162958秒
#  MSE loss(Relative):0.0003887632811233218, 耗时:0.5秒(74个数据点)
# Accumulated Squared Loss(Relative): 0.028768482803125814
#  数据点文件:./data/dataset/v2/validset/horse095.png.txt, 50/190, 预计耗时81.60168743999702秒
#  MSE loss(Relative):0.00017027244776249428, 耗时:0.4秒(64个数据点)
# Accumulated Squared Loss(Relative): 0.010897436656799634
#  数据点文件:./data/dataset/v2/validset/toilet320.png.txt, 51/190, 预计耗时80.56800146274226秒
#  MSE loss(Relative):0.00015199077660885455, 耗时:0.8秒(124个数据点)
# Accumulated Squared Loss(Relative): 0.018846856299497963
#  数据点文件:./data/dataset/v2/validset/teddy045.png.txt, 52/190, 预计耗时80.51645136922849秒
#  MSE loss(Relative):0.00019931521066345975, 耗时:0.9秒(139个数据点)
# Accumulated Squared Loss(Relative): 0.027704814282220904
#  数据点文件:./data/dataset/v2/validset/guitar195.png.txt, 53/190, 预计耗时80.74870316603601秒
#  MSE loss(Relative):0.0002257820492172375, 耗时:0.5秒(67个数据点)
# Accumulated Squared Loss(Relative): 0.015127397297554912
#  数据点文件:./data/dataset/v2/validset/television210.png.txt, 54/190, 预计耗时79.90629503703538秒
#  MSE loss(Relative):0.0012254733975681372, 耗时:1.3秒(203个数据点)
# Accumulated Squared Loss(Relative): 0.24877109970633185
#  数据点文件:./data/dataset/v2/validset/horse245.png.txt, 55/190, 预计耗时80.97225872727077秒
#  MSE loss(Relative):0.000624201918153596, 耗时:0.7秒(111个数据点)
# Accumulated Squared Loss(Relative): 0.06928641291504915
#  数据点文件:./data/dataset/v2/validset/sink315.png.txt, 56/190, 预计耗时80.5697220071413秒
#  MSE loss(Relative):0.0002874194960106782, 耗时:0.4秒(66个数据点)
# Accumulated Squared Loss(Relative): 0.01896968673670476
#  数据点文件:./data/dataset/v2/validset/guitar285.png.txt, 57/190, 预计耗时79.55200049999848秒
#  MSE loss(Relative):0.00025179109611541626, 耗时:0.3秒(55个数据点)
# Accumulated Squared Loss(Relative): 0.013848510286347895
#  数据点文件:./data/dataset/v2/validset/hammer110.png.txt, 58/190, 预计耗时78.35619773792955秒
#  MSE loss(Relative):0.00023499256061501486, 耗时:0.5秒(77个数据点)
# Accumulated Squared Loss(Relative): 0.018094427167356146
#  数据点文件:./data/dataset/v2/validset/sink005.png.txt, 59/190, 预计耗时77.49589403220199秒
#  MSE loss(Relative):0.00029756171753055906, 耗时:0.4秒(64个数据点)
# Accumulated Squared Loss(Relative): 0.01904394992195578
#  数据点文件:./data/dataset/v2/validset/bird270.png.txt, 60/190, 预计耗时76.4599326833322秒
#  MSE loss(Relative):0.00033703059837891835, 耗时:0.5秒(84个数据点)
# Accumulated Squared Loss(Relative): 0.02831057026382914
#  数据点文件:./data/dataset/v2/validset/guitar350.png.txt, 61/190, 预计耗时75.74772464753978秒
#  MSE loss(Relative):0.00021988414157511635, 耗时:0.4秒(68个数据点)
# Accumulated Squared Loss(Relative): 0.014952121627107911
#  数据点文件:./data/dataset/v2/validset/bed045.png.txt, 62/190, 预计耗时74.84049878709558秒
#  MSE loss(Relative):0.0005608398599554882, 耗时:1.1秒(180个数据点)
# Accumulated Squared Loss(Relative): 0.10095117479198787
#  数据点文件:./data/dataset/v2/validset/bird075.png.txt, 63/190, 预计耗时75.30291977618963秒
#  MSE loss(Relative):0.0003687997769337063, 耗时:0.5秒(85个数据点)
# Accumulated Squared Loss(Relative): 0.031347981039365036
#  数据点文件:./data/dataset/v2/validset/fish215.png.txt, 64/190, 预计耗时74.61466897499919秒
#  MSE loss(Relative):0.0002269346794876831, 耗时:0.5秒(78个数据点)
# Accumulated Squared Loss(Relative): 0.017700905000039284
#  数据点文件:./data/dataset/v2/validset/television225.png.txt, 65/190, 预计耗时73.83871903846065秒
#  MSE loss(Relative):0.0014984440649381528, 耗时:1.2秒(183个数据点)
# Accumulated Squared Loss(Relative): 0.27421526388368195
#  数据点文件:./data/dataset/v2/validset/fish230.png.txt, 66/190, 预计耗时74.30297713939302秒
#  MSE loss(Relative):0.00033501030386342206, 耗时:0.4秒(70个数据点)
# Accumulated Squared Loss(Relative): 0.023450721270439543
#  数据点文件:./data/dataset/v2/validset/horse355.png.txt, 67/190, 预计耗时73.37855757313334秒
#  MSE loss(Relative):0.00042701653785955, 耗时:0.8秒(122个数据点)
# Accumulated Squared Loss(Relative): 0.0520960176188651
#  数据点文件:./data/dataset/v2/validset/toilet165.png.txt, 68/190, 预计耗时73.06715186764634秒
#  MSE loss(Relative):0.0001505796735060696, 耗时:0.7秒(109个数据点)
# Accumulated Squared Loss(Relative): 0.016413184412161587
#  数据点文件:./data/dataset/v2/validset/teddy150.png.txt, 69/190, 预计耗时72.6155155318833秒
#  MSE loss(Relative):0.00020602400125734632, 耗时:0.7秒(107个数据点)
# Accumulated Squared Loss(Relative): 0.022044568134536056
#  数据点文件:./data/dataset/v2/validset/fish220.png.txt, 70/190, 预计耗时72.12807257142816秒
#  MSE loss(Relative):0.00024756078583151897, 耗时:0.5秒(74个数据点)
# Accumulated Squared Loss(Relative): 0.018319498151532405
#  数据点文件:./data/dataset/v2/validset/teddy160.png.txt, 71/190, 预计耗时71.31263271408412秒
#  MSE loss(Relative):0.00021720655490759186, 耗时:0.7秒(113个数据点)
# Accumulated Squared Loss(Relative): 0.024544340704557882
#  数据点文件:./data/dataset/v2/validset/television030.png.txt, 72/190, 预计耗时70.93685082777729秒
#  MSE loss(Relative):0.0011581546124492092, 耗时:1.3秒(207个数据点)
# Accumulated Squared Loss(Relative): 0.2397380047769863
#  数据点文件:./data/dataset/v2/validset/horse100.png.txt, 73/190, 预计耗时71.5026328027391秒
#  MSE loss(Relative):0.00018489042275414042, 耗时:0.5秒(68个数据点)
# Accumulated Squared Loss(Relative): 0.012572548747281549
#  数据点文件:./data/dataset/v2/validset/television350.png.txt, 74/190, 预计耗时70.65717368108054秒
#  MSE loss(Relative):0.0011085539788238071, 耗时:1.3秒(216个数据点)
# Accumulated Squared Loss(Relative): 0.23944765942594234
#  数据点文件:./data/dataset/v2/validset/fish195.png.txt, 75/190, 预计耗时71.17921059333291秒
#  MSE loss(Relative):0.00020625148076398552, 耗时:0.6秒(87个数据点)
# Accumulated Squared Loss(Relative): 0.01794387882646674
#  数据点文件:./data/dataset/v2/validset/television140.png.txt, 76/190, 预计耗时70.5174353999995秒
#  MSE loss(Relative):0.0013472940953079982, 耗时:1.2秒(190个数据点)
# Accumulated Squared Loss(Relative): 0.25598587810851964
#  数据点文件:./data/dataset/v2/validset/guitar005.png.txt, 77/190, 预计耗时70.75325103766188秒
#  MSE loss(Relative):0.00025029076885355565, 耗时:0.4秒(67个数据点)
# Accumulated Squared Loss(Relative): 0.016769481513188227
#  数据点文件:./data/dataset/v2/validset/bird260.png.txt, 78/190, 预计耗时69.81549105641002秒
#  MSE loss(Relative):0.00036013639583584706, 耗时:0.5秒(82个数据点)
# Accumulated Squared Loss(Relative): 0.02953118445853946
#  数据点文件:./data/dataset/v2/validset/toilet170.png.txt, 79/190, 预计耗时69.0503188177212秒
#  MSE loss(Relative):0.00019548494318990826, 耗时:0.7秒(107个数据点)
# Accumulated Squared Loss(Relative): 0.020916888921320185
#  数据点文件:./data/dataset/v2/validset/hammer330.png.txt, 80/190, 预计耗时68.48125734999971秒
#  MSE loss(Relative):0.00017305434983988182, 耗时:0.5秒(89个数据点)
# Accumulated Squared Loss(Relative): 0.015401837135749483
#  数据点文件:./data/dataset/v2/validset/sink130.png.txt, 81/190, 预计耗时67.73220531234526秒
#  MSE loss(Relative):0.0003509070329428111, 耗时:0.4秒(64个数据点)
# Accumulated Squared Loss(Relative): 0.02245805010833991
#  数据点文件:./data/dataset/v2/validset/fish070.png.txt, 82/190, 预计耗时66.85259834634093秒
#  MSE loss(Relative):0.00034708461813463034, 耗时:0.4秒(56个数据点)
# Accumulated Squared Loss(Relative): 0.0194367386155393
#  数据点文件:./data/dataset/v2/validset/bed030.png.txt, 83/190, 预计耗时65.89183423855371秒
#  MSE loss(Relative):0.0005589478666439708, 耗时:1.0秒(168个数据点)
# Accumulated Squared Loss(Relative): 0.0939032415961871
#  数据点文件:./data/dataset/v2/validset/horse210.png.txt, 84/190, 预计耗时65.81384079047572秒
#  MSE loss(Relative):0.00024371193771974663, 耗时:0.6秒(101个数据点)
# Accumulated Squared Loss(Relative): 0.02461490570969441
#  数据点文件:./data/dataset/v2/validset/teddy155.png.txt, 85/190, 预计耗时65.2213132941173秒
#  MSE loss(Relative):0.00021486430570149225, 耗时:0.7秒(112个数据点)
# Accumulated Squared Loss(Relative): 0.02406480223856713
#  数据点文件:./data/dataset/v2/validset/toilet315.png.txt, 86/190, 预计耗时64.68286179534824秒
#  MSE loss(Relative):0.00014174844263748374, 耗时:0.8秒(126个数据点)
# Accumulated Squared Loss(Relative): 0.01786030377232295
#  数据点文件:./data/dataset/v2/validset/bed000.png.txt, 87/190, 预计耗时64.24281773218334秒
#  MSE loss(Relative):0.00033281451890832, 耗时:0.8秒(131个数据点)
# Accumulated Squared Loss(Relative): 0.043598701976989916
#  数据点文件:./data/dataset/v2/validset/bed355.png.txt, 88/190, 预计耗时63.863393979544945秒
#  MSE loss(Relative):0.00043308426687797765, 耗时:0.9秒(140个数据点)
# Accumulated Squared Loss(Relative): 0.06063179736291687
#  数据点文件:./data/dataset/v2/validset/toilet150.png.txt, 89/190, 预计耗时63.5315496258423秒
#  MSE loss(Relative):0.00015335128026085408, 耗时:0.8秒(119个数据点)
# Accumulated Squared Loss(Relative): 0.018248802351041635
#  数据点文件:./data/dataset/v2/validset/teddy220.png.txt, 90/190, 预计耗时63.0513687777774秒
#  MSE loss(Relative):0.0001826548288282128, 耗时:0.9秒(141个数据点)
# Accumulated Squared Loss(Relative): 0.025754330864778005
#  数据点文件:./data/dataset/v2/validset/fish270.png.txt, 91/190, 预计耗时62.679607486812706秒
#  MSE loss(Relative):0.00025399057842756154, 耗时:0.3秒(45个数据点)
# Accumulated Squared Loss(Relative): 0.01142957602924027
#  数据点文件:./data/dataset/v2/validset/fish260.png.txt, 92/190, 预计耗时61.67150630869527秒
#  MSE loss(Relative):0.00027364375353529065, 耗时:0.3秒(47个数据点)
# Accumulated Squared Loss(Relative): 0.012861256416158661
#  数据点文件:./data/dataset/v2/validset/toilet240.png.txt, 93/190, 预计耗时60.693539156988805秒
#  MSE loss(Relative):0.00018675441573436487, 耗时:0.8秒(127个数据点)
# Accumulated Squared Loss(Relative): 0.02371781079826434
#  数据点文件:./data/dataset/v2/validset/hammer235.png.txt, 94/190, 预计耗时60.22084483404197秒
#  MSE loss(Relative):0.00023690659458483173, 耗时:0.5秒(83个数据点)
# Accumulated Squared Loss(Relative): 0.019663247350541032
#  数据点文件:./data/dataset/v2/validset/bed220.png.txt, 95/190, 预计耗时59.4875865999993秒
#  MSE loss(Relative):0.0005062842348482939, 耗时:1.1秒(174个数据点)
# Accumulated Squared Loss(Relative): 0.08809345686360313
#  数据点文件:./data/dataset/v2/validset/television245.png.txt, 96/190, 预计耗时59.316547008332755秒
#  MSE loss(Relative):0.0009820927777654783, 耗时:0.9秒(139个数据点)
# Accumulated Squared Loss(Relative): 0.13651089610940148
#  数据点文件:./data/dataset/v2/validset/toilet340.png.txt, 97/190, 预计耗时58.909890853607656秒
#  MSE loss(Relative):0.00013307863338318522, 耗时:0.7秒(115个数据点)
# Accumulated Squared Loss(Relative): 0.0153040428390663
#  数据点文件:./data/dataset/v2/validset/teddy170.png.txt, 98/190, 预计耗时58.356923016326036秒
#  MSE loss(Relative):0.0002121646487573676, 耗时:0.7秒(118个数据点)
# Accumulated Squared Loss(Relative): 0.025035428553369377
#  数据点文件:./data/dataset/v2/validset/sink090.png.txt, 99/190, 预计耗时57.819762735353095秒
#  MSE loss(Relative):0.00036191489260068555, 耗时:0.4秒(67个数据点)
# Accumulated Squared Loss(Relative): 0.024248297804245932
#  数据点文件:./data/dataset/v2/validset/hammer195.png.txt, 100/190, 预计耗时56.99874779999962秒
#  MSE loss(Relative):0.00022556998821720182, 耗时:0.6秒(93个数据点)
# Accumulated Squared Loss(Relative): 0.02097800890419977
#  数据点文件:./data/dataset/v2/validset/bed200.png.txt, 101/190, 预计耗时56.32656867128675秒
#  MSE loss(Relative):0.0003210583882015593, 耗时:1.0秒(154个数据点)
# Accumulated Squared Loss(Relative): 0.04944299178304014
#  数据点文件:./data/dataset/v2/validset/hammer180.png.txt, 102/190, 预计耗时55.9761307686272秒
#  MSE loss(Relative):0.0002673990048927328, 耗时:0.6秒(88个数据点)
# Accumulated Squared Loss(Relative): 0.023531112430560486
#  数据点文件:./data/dataset/v2/validset/television000.png.txt, 103/190, 预计耗时55.27327010097057秒
#  MSE loss(Relative):0.0011166722018146307, 耗时:1.3秒(214个数据点)
# Accumulated Squared Loss(Relative): 0.23896785118833097
#  数据点文件:./data/dataset/v2/validset/television315.png.txt, 104/190, 预计耗时55.22330610576886秒
#  MSE loss(Relative):0.0014650909018866644, 耗时:1.2秒(186个数据点)
# Accumulated Squared Loss(Relative): 0.27250690775091957
#  数据点文件:./data/dataset/v2/validset/bed175.png.txt, 105/190, 预计耗时55.01162017142813秒
#  MSE loss(Relative):0.0005257788770894169, 耗时:0.9秒(137个数据点)
# Accumulated Squared Loss(Relative): 0.07203170616125011
#  数据点文件:./data/dataset/v2/validset/sink095.png.txt, 106/190, 预计耗时54.53617133207508秒
#  MSE loss(Relative):0.0002872372689121644, 耗时:0.4秒(66个数据点)
# Accumulated Squared Loss(Relative): 0.01895765974820285
#  数据点文件:./data/dataset/v2/validset/sink205.png.txt, 107/190, 预计耗时53.693290928971585秒
#  MSE loss(Relative):0.0003874073907058298, 耗时:0.4秒(59个数据点)
# Accumulated Squared Loss(Relative): 0.02285703605164396
#  数据点文件:./data/dataset/v2/validset/fish250.png.txt, 108/190, 预计耗时52.83031462962916秒
#  MSE loss(Relative):0.00026178709111730297, 耗时:0.3秒(53个数据点)
# Accumulated Squared Loss(Relative): 0.013874715829217057
#  数据点文件:./data/dataset/v2/validset/guitar145.png.txt, 109/190, 预计耗时51.946015549540775秒
#  MSE loss(Relative):0.00027846380642378, 耗时:0.4秒(66个数据点)
# Accumulated Squared Loss(Relative): 0.018378611223969478
#  数据点文件:./data/dataset/v2/validset/bed125.png.txt, 110/190, 预计耗时51.13397454545405秒
#  MSE loss(Relative):0.0005468520120752771, 耗时:1.1秒(183个数据点)
# Accumulated Squared Loss(Relative): 0.10007391820977571
#  数据点文件:./data/dataset/v2/validset/fish265.png.txt, 111/190, 预计耗时50.85264859639595秒
#  MSE loss(Relative):0.00024708775493443306, 耗时:0.3秒(47个数据点)
# Accumulated Squared Loss(Relative): 0.011613124481918353
#  数据点文件:./data/dataset/v2/validset/hammer310.png.txt, 112/190, 预计耗时49.95609665892819秒
#  MSE loss(Relative):0.00017126475367126943, 耗时:0.5秒(83个数据点)
# Accumulated Squared Loss(Relative): 0.014214974554715362
#  数据点文件:./data/dataset/v2/validset/television045.png.txt, 113/190, 预计耗时49.236045061061546秒
#  MSE loss(Relative):0.0015916390371533767, 耗时:1.2秒(186个数据点)
# Accumulated Squared Loss(Relative): 0.29604486091052806
#  数据点文件:./data/dataset/v2/validset/sink250.png.txt, 114/190, 预计耗时48.952870266666345秒
#  MSE loss(Relative):0.0002871270942112344, 耗时:0.4秒(67个数据点)
# Accumulated Squared Loss(Relative): 0.019237515312152703
#  数据点文件:./data/dataset/v2/validset/television175.png.txt, 115/190, 预计耗时48.16409126086925秒
#  MSE loss(Relative):0.0011344756992898485, 耗时:1.3秒(214个数据点)
# Accumulated Squared Loss(Relative): 0.24277779964802756
#  数据点文件:./data/dataset/v2/validset/sink100.png.txt, 116/190, 预计耗时47.959131813792816秒
#  MSE loss(Relative):0.0003196554745461773, 耗时:0.5秒(65个数据点)
# Accumulated Squared Loss(Relative): 0.020777605845501528
#  数据点文件:./data/dataset/v2/validset/guitar265.png.txt, 117/190, 预计耗时47.203218945298914秒
#  MSE loss(Relative):0.00020613048276643952, 耗时:0.3秒(53个数据点)
# Accumulated Squared Loss(Relative): 0.010924915586621294
#  数据点文件:./data/dataset/v2/validset/bird355.png.txt, 118/190, 预计耗时46.37046551186419秒
#  MSE loss(Relative):0.0003466386320032949, 耗时:0.8秒(104个数据点)
# Accumulated Squared Loss(Relative): 0.036050417728342665
#  数据点文件:./data/dataset/v2/validset/television305.png.txt, 119/190, 预计耗时45.80302216470572秒
#  MSE loss(Relative):0.001393331929057339, 耗时:1.1秒(168个数据点)
# Accumulated Squared Loss(Relative): 0.23407976408163295
#  数据点文件:./data/dataset/v2/validset/teddy100.png.txt, 120/190, 预计耗时45.394813449999866秒
#  MSE loss(Relative):0.00021417012902467846, 耗时:0.7秒(112个数据点)
# Accumulated Squared Loss(Relative): 0.02398705445076399
#  数据点文件:./data/dataset/v2/validset/teddy200.png.txt, 121/190, 预计耗时44.77833500330565秒
#  MSE loss(Relative):0.00019811708604326492, 耗时:0.9秒(135个数据点)
# Accumulated Squared Loss(Relative): 0.026745806615840764
#  数据点文件:./data/dataset/v2/validset/toilet355.png.txt, 122/190, 预计耗时44.24349971147526秒
#  MSE loss(Relative):0.0001616936825898301, 耗时:0.7秒(107个数据点)
# Accumulated Squared Loss(Relative): 0.01730122403711182
#  数据点文件:./data/dataset/v2/validset/hammer090.png.txt, 123/190, 预计耗时43.61056756422749秒
#  MSE loss(Relative):0.0002801752696565965, 耗时:0.5秒(73个数据点)
# Accumulated Squared Loss(Relative): 0.020452794684931545
#  数据点文件:./data/dataset/v2/validset/hammer200.png.txt, 124/190, 预计耗时42.86535697258054秒
#  MSE loss(Relative):0.00022004695620963792, 耗时:0.6秒(92个数据点)
# Accumulated Squared Loss(Relative): 0.02024431997128669
#  数据点文件:./data/dataset/v2/validset/bird100.png.txt, 125/190, 预计耗时42.195870027999945秒
#  MSE loss(Relative):0.00039217442921664483, 耗时:0.5秒(84个数据点)
# Accumulated Squared Loss(Relative): 0.03294265205419816
#  数据点文件:./data/dataset/v2/validset/horse000.png.txt, 126/190, 预计耗时41.477959060317346秒
#  MSE loss(Relative):0.00040167352016196977, 耗时:0.7秒(120个数据点)
# Accumulated Squared Loss(Relative): 0.04820082241943637
#  数据点文件:./data/dataset/v2/validset/teddy295.png.txt, 127/190, 预计耗时40.87935085748023秒
#  MSE loss(Relative):0.00021538630127542168, 耗时:0.6秒(106个数据点)
# Accumulated Squared Loss(Relative): 0.0228309479351947
#  数据点文件:./data/dataset/v2/validset/guitar310.png.txt, 128/190, 预计耗时40.22651469374991秒
#  MSE loss(Relative):0.00023412396625977806, 耗时:0.4秒(61个数据点)
# Accumulated Squared Loss(Relative): 0.014281561941846462
#  数据点文件:./data/dataset/v2/validset/teddy330.png.txt, 129/190, 预计耗时39.458599732557964秒
#  MSE loss(Relative):0.00015230334494717682, 耗时:0.7秒(102个数据点)
# Accumulated Squared Loss(Relative): 0.015534941184612036
#  数据点文件:./data/dataset/v2/validset/hammer175.png.txt, 130/190, 预计耗时38.819102999999885秒
#  MSE loss(Relative):0.0002559673448562005, 耗时:0.6秒(92个数据点)
# Accumulated Squared Loss(Relative): 0.02354899572677045
#  数据点文件:./data/dataset/v2/validset/bird010.png.txt, 131/190, 预计耗时38.131750983206054秒
#  MSE loss(Relative):0.0003182684129067478, 耗时:0.6秒(104个数据点)
# Accumulated Squared Loss(Relative): 0.03309991494230177
#  数据点文件:./data/dataset/v2/validset/television190.png.txt, 132/190, 预计耗时37.48452626515145秒
#  MSE loss(Relative):0.0011109005791519549, 耗时:1.4秒(216个数据点)
# Accumulated Squared Loss(Relative): 0.23995452509682225
#  数据点文件:./data/dataset/v2/validset/teddy245.png.txt, 133/190, 预计耗时37.14027359999997秒
#  MSE loss(Relative):0.00017898506098944065, 耗时:0.8秒(131个数据点)
# Accumulated Squared Loss(Relative): 0.023447042989616727
#  数据点文件:./data/dataset/v2/validset/sink055.png.txt, 134/190, 预计耗时36.56261635223869秒
#  MSE loss(Relative):0.00034346997828258835, 耗时:0.4秒(65个数据点)
# Accumulated Squared Loss(Relative): 0.022325548588368244
#  数据点文件:./data/dataset/v2/validset/teddy125.png.txt, 135/190, 预计耗时35.806674281481385秒
#  MSE loss(Relative):0.00016587665882755186, 耗时:0.6秒(97个数据点)
# Accumulated Squared Loss(Relative): 0.016090035906272532
#  数据点文件:./data/dataset/v2/validset/hammer190.png.txt, 136/190, 预计耗时35.13603952058808秒
#  MSE loss(Relative):0.00022390939394733382, 耗时:0.6秒(92个数据点)
# Accumulated Squared Loss(Relative): 0.020599664243154712
#  数据点文件:./data/dataset/v2/validset/sink110.png.txt, 137/190, 预计耗时34.458692232116654秒
#  MSE loss(Relative):0.00035359874067608004, 耗时:0.4秒(63个数据点)
# Accumulated Squared Loss(Relative): 0.022276720662593043
#  数据点文件:./data/dataset/v2/validset/television235.png.txt, 138/190, 预计耗时33.71018043768103秒
#  MSE loss(Relative):0.0013108275072275647, 耗时:1.0秒(163个数据点)
# Accumulated Squared Loss(Relative): 0.21366488367809305
#  数据点文件:./data/dataset/v2/validset/teddy290.png.txt, 139/190, 预计耗时33.19569123021569秒
#  MSE loss(Relative):0.00021277553577324373, 耗时:0.7秒(107个数据点)
# Accumulated Squared Loss(Relative): 0.02276698232773708
#  数据点文件:./data/dataset/v2/validset/bird150.png.txt, 140/190, 预计耗时32.54818767857127秒
#  MSE loss(Relative):0.00022931633478058335, 耗时:0.6秒(95个数据点)
# Accumulated Squared Loss(Relative): 0.02178505180415542
#  数据点文件:./data/dataset/v2/validset/teddy050.png.txt, 141/190, 预计耗时31.8794773226949秒
#  MSE loss(Relative):0.00021669126680904933, 耗时:0.9秒(139个数据点)
# Accumulated Squared Loss(Relative): 0.030120086086457856
#  数据点文件:./data/dataset/v2/validset/bird000.png.txt, 142/190, 预计耗时31.30571428732383秒
#  MSE loss(Relative):0.0003431473316685191, 耗时:0.7秒(105个数据点)
# Accumulated Squared Loss(Relative): 0.036030469825194505
#  数据点文件:./data/dataset/v2/validset/guitar345.png.txt, 143/190, 预计耗时30.6552463440558秒
#  MSE loss(Relative):0.0002268279667113145, 耗时:0.4秒(67个数据点)
# Accumulated Squared Loss(Relative): 0.015197473769658071
#  数据点文件:./data/dataset/v2/validset/hammer070.png.txt, 144/190, 预计耗时29.928945404166548秒
#  MSE loss(Relative):0.0001631393045330554, 耗时:0.5秒(76个数据点)
# Accumulated Squared Loss(Relative): 0.01239858714451221
#  数据点文件:./data/dataset/v2/validset/fish050.png.txt, 145/190, 预计耗时29.222343620689514秒
#  MSE loss(Relative):0.00029820656695997953, 耗时:0.5秒(72个数据点)
# Accumulated Squared Loss(Relative): 0.021470872821118526
#  数据点文件:./data/dataset/v2/validset/toilet155.png.txt, 146/190, 预计耗时28.518293506849204秒
#  MSE loss(Relative):0.00014801800363305504, 耗时:0.7秒(115个数据点)
# Accumulated Squared Loss(Relative): 0.01702207041780133
#  数据点文件:./data/dataset/v2/validset/fish145.png.txt, 147/190, 预计耗时27.890980832652925秒
#  MSE loss(Relative):0.0002235563179456333, 耗时:0.5秒(77个数据点)
# Accumulated Squared Loss(Relative): 0.017213836481813766
#  数据点文件:./data/dataset/v2/validset/bed240.png.txt, 148/190, 预计耗时27.1994190527026秒
#  MSE loss(Relative):0.00047623378272347404, 耗时:1.1秒(178个数据点)
# Accumulated Squared Loss(Relative): 0.08476961332477838
#  数据点文件:./data/dataset/v2/validset/bed215.png.txt, 149/190, 预计耗时26.68624576107372秒
#  MSE loss(Relative):0.00034394788698613807, 耗时:1.0秒(163个数据点)
# Accumulated Squared Loss(Relative): 0.056063505578740506
#  数据点文件:./data/dataset/v2/validset/bed290.png.txt, 150/190, 预计耗时26.13123487999989秒
#  MSE loss(Relative):0.00058245023250274, 耗时:1.1秒(173个数据点)
# Accumulated Squared Loss(Relative): 0.10076389022297402
#  数据点文件:./data/dataset/v2/validset/television250.png.txt, 151/190, 预计耗时25.58714587947012秒
#  MSE loss(Relative):0.0009584146850778443, 耗时:0.8秒(127个数据点)
# Accumulated Squared Loss(Relative): 0.12171866500488622
#  数据点文件:./data/dataset/v2/validset/fish140.png.txt, 152/190, 预计耗时24.96550549999995秒
#  MSE loss(Relative):0.00023656607337654107, 耗时:0.5秒(75个数据点)
# Accumulated Squared Loss(Relative): 0.017742455503240582
#  数据点文件:./data/dataset/v2/validset/toilet055.png.txt, 153/190, 预计耗时24.262490854901948秒
#  MSE loss(Relative):0.0001983861535940229, 耗时:0.8秒(126个数据点)
# Accumulated Squared Loss(Relative): 0.024996655352846887
#  数据点文件:./data/dataset/v2/validset/guitar325.png.txt, 154/190, 预计耗时23.64041019740259秒
#  MSE loss(Relative):0.0002197694522019006, 耗时:0.4秒(65个数据点)
# Accumulated Squared Loss(Relative): 0.01428501439312354
#  数据点文件:./data/dataset/v2/validset/sink325.png.txt, 155/190, 预计耗时22.92632248064515秒
#  MSE loss(Relative):0.00028911844085067296, 耗时:0.4秒(64个数据点)
# Accumulated Squared Loss(Relative): 0.01850358021444307
#  数据点文件:./data/dataset/v2/validset/television050.png.txt, 156/190, 预计耗时22.213145679487198秒
#  MSE loss(Relative):0.001635159912837193, 耗时:1.1秒(178个数据点)
# Accumulated Squared Loss(Relative): 0.2910584644850203
#  数据点文件:./data/dataset/v2/validset/horse120.png.txt, 157/190, 预计耗时21.658593000000035秒
#  MSE loss(Relative):0.0006197761819044725, 耗时:0.7秒(117个数据点)
# Accumulated Squared Loss(Relative): 0.07251381328282329
#  数据点文件:./data/dataset/v2/validset/bird215.png.txt, 158/190, 预计耗时21.01749032911396秒
#  MSE loss(Relative):0.00023611702420457244, 耗时:0.6秒(92个数据点)
# Accumulated Squared Loss(Relative): 0.021722766226820664
#  数据点文件:./data/dataset/v2/validset/sink290.png.txt, 159/190, 预计耗时20.345686505660428秒
#  MSE loss(Relative):0.000301442024222768, 耗时:0.4秒(62个数据点)
# Accumulated Squared Loss(Relative): 0.018689405501811616
#  数据点文件:./data/dataset/v2/validset/toilet145.png.txt, 160/190, 预计耗时19.638233606250054秒
#  MSE loss(Relative):0.00017950132413784828, 耗时:0.7秒(118个数据点)
# Accumulated Squared Loss(Relative): 0.021181156248266098
#  数据点文件:./data/dataset/v2/validset/fish045.png.txt, 161/190, 预计耗时18.998722735403803秒
#  MSE loss(Relative):0.00032318416572645807, 耗时:0.5秒(75个数据点)
# Accumulated Squared Loss(Relative): 0.024238812429484356
#  数据点文件:./data/dataset/v2/validset/toilet215.png.txt, 162/190, 预计耗时18.316059671605018秒
#  MSE loss(Relative):0.00012901871805869213, 耗时:0.8秒(122个数据点)
# Accumulated Squared Loss(Relative): 0.01574028360316044
#  数据点文件:./data/dataset/v2/validset/fish005.png.txt, 163/190, 预计耗时17.678322684662646秒
#  MSE loss(Relative):0.0002665497860266806, 耗时:0.6秒(89个数据点)
# Accumulated Squared Loss(Relative): 0.023722930956374573
#  数据点文件:./data/dataset/v2/validset/horse085.png.txt, 164/190, 预计耗时17.01139812560983秒
#  MSE loss(Relative):0.0001617421710915924, 耗时:0.4秒(63个数据点)
# Accumulated Squared Loss(Relative): 0.010189756778770322
#  数据点文件:./data/dataset/v2/validset/bird210.png.txt, 165/190, 预计耗时16.317359651515233秒
#  MSE loss(Relative):0.00025950938769656056, 耗时:0.6秒(96个数据点)
# Accumulated Squared Loss(Relative): 0.024912901218869812
#  数据点文件:./data/dataset/v2/validset/bird160.png.txt, 166/190, 预计耗时15.65614805783139秒
#  MSE loss(Relative):0.0002544635323273386, 耗时:0.6秒(99个数据点)
# Accumulated Squared Loss(Relative): 0.02519188970040652
#  数据点文件:./data/dataset/v2/validset/bed230.png.txt, 167/190, 预计耗时15.000077831137768秒
#  MSE loss(Relative):0.0005138775023117562, 耗时:1.1秒(182个数据点)
# Accumulated Squared Loss(Relative): 0.09352570542073964
#  数据点文件:./data/dataset/v2/validset/fish110.png.txt, 168/190, 预计耗时14.412781245238158秒
#  MSE loss(Relative):0.0002882088568325381, 耗时:0.3秒(55个数据点)
# Accumulated Squared Loss(Relative): 0.015851487125789595
#  数据点文件:./data/dataset/v2/validset/horse150.png.txt, 169/190, 预计耗时13.719261653254502秒
#  MSE loss(Relative):0.0002414980867912592, 耗时:0.7秒(102个数据点)
# Accumulated Squared Loss(Relative): 0.024632804852708436
#  数据点文件:./data/dataset/v2/validset/sink030.png.txt, 170/190, 预计耗时13.066890035294175秒
#  MSE loss(Relative):0.0002715700230078128, 耗时:0.3秒(55个数据点)
# Accumulated Squared Loss(Relative): 0.014936351265429703
#  数据点文件:./data/dataset/v2/validset/teddy165.png.txt, 171/190, 预计耗时12.378087166666724秒
#  MSE loss(Relative):0.00022620870781756353, 耗时:0.7秒(116个数据点)
# Accumulated Squared Loss(Relative): 0.02624021010683737
#  数据点文件:./data/dataset/v2/validset/television220.png.txt, 172/190, 预计耗时11.736329368604691秒
#  MSE loss(Relative):0.0012196356466678934, 耗时:1.2秒(192个数据点)
# Accumulated Squared Loss(Relative): 0.23417004416023554
#  数据点文件:./data/dataset/v2/validset/horse025.png.txt, 173/190, 预计耗时11.138010415028944秒
#  MSE loss(Relative):0.00025656480484865374, 耗时:0.7秒(103个数据点)
# Accumulated Squared Loss(Relative): 0.026426174899411334
#  数据点文件:./data/dataset/v2/validset/teddy305.png.txt, 174/190, 预计耗时10.49026608735635秒
#  MSE loss(Relative):0.0001407243091391604, 耗时:0.6秒(100个数据点)
# Accumulated Squared Loss(Relative): 0.01407243091391604
#  数据点文件:./data/dataset/v2/validset/sink025.png.txt, 175/190, 预计耗时9.829821514285731秒
#  MSE loss(Relative):0.00026594270004999055, 耗时:0.4秒(58个数据点)
# Accumulated Squared Loss(Relative): 0.01542467660289945
#  数据点文件:./data/dataset/v2/validset/teddy030.png.txt, 176/190, 预计耗时9.15196718863639秒
#  MSE loss(Relative):0.00020168440701489882, 耗时:0.9秒(137个数据点)
# Accumulated Squared Loss(Relative): 0.02763076376104114
#  数据点文件:./data/dataset/v2/validset/bed055.png.txt, 177/190, 预计耗时8.515515659322066秒
#  MSE loss(Relative):0.0006359575612542171, 耗时:1.1秒(185个数据点)
# Accumulated Squared Loss(Relative): 0.11765214883203017
#  数据点文件:./data/dataset/v2/validset/television160.png.txt, 178/190, 预计耗时7.893041629213508秒
#  MSE loss(Relative):0.0010549884380586549, 耗时:1.3秒(211个数据点)
# Accumulated Squared Loss(Relative): 0.22260256043037618
#  数据点文件:./data/dataset/v2/validset/sink310.png.txt, 179/190, 预计耗时7.275742917318457秒
#  MSE loss(Relative):0.0003012898698557547, 耗时:0.4秒(63个数据点)
# Accumulated Squared Loss(Relative): 0.018981261800912547
#  数据点文件:./data/dataset/v2/validset/television055.png.txt, 180/190, 预计耗时6.599830527777789秒
#  MSE loss(Relative):0.0013124298438358603, 耗时:1.0秒(166个数据点)
# Accumulated Squared Loss(Relative): 0.2178633540767528
#  数据点文件:./data/dataset/v2/validset/sink105.png.txt, 181/190, 预计耗时5.9590566198895125秒
#  MSE loss(Relative):0.0002945984825133831, 耗时:0.4秒(65个数据点)
# Accumulated Squared Loss(Relative): 0.019148901363369903
#  数据点文件:./data/dataset/v2/validset/bird110.png.txt, 182/190, 预计耗时5.285571098901108秒
#  MSE loss(Relative):0.0004522739728208551, 耗时:0.6秒(90个数据点)
# Accumulated Squared Loss(Relative): 0.04070465755387696
#  数据点文件:./data/dataset/v2/validset/toilet335.png.txt, 183/190, 预计耗时4.62095524754099秒
#  MSE loss(Relative):0.00014046260842720675, 耗时:0.8秒(118个数据点)
# Accumulated Squared Loss(Relative): 0.016574587794410397
#  数据点文件:./data/dataset/v2/validset/toilet025.png.txt, 184/190, 预计耗时3.9639534130434857秒
#  MSE loss(Relative):0.0001571214374780135, 耗时:0.7秒(115个数据点)
# Accumulated Squared Loss(Relative): 0.018068965309971555
#  数据点文件:./data/dataset/v2/validset/horse020.png.txt, 185/190, 预计耗时3.3055259540540622秒
#  MSE loss(Relative):0.00034757967979068423, 耗时:0.7秒(107个数据点)
# Accumulated Squared Loss(Relative): 0.03719102573760321
#  数据点文件:./data/dataset/v2/validset/sink120.png.txt, 186/190, 预计耗时2.6447633526881824秒
#  MSE loss(Relative):0.00028260499326207095, 耗时:0.4秒(60个数据点)
# Accumulated Squared Loss(Relative): 0.016956299595724256
#  数据点文件:./data/dataset/v2/validset/bird285.png.txt, 187/190, 预计耗时1.9792342877005438秒
#  MSE loss(Relative):0.00030731198022123616, 耗时:0.5秒(83个数据点)
# Accumulated Squared Loss(Relative): 0.025506894358362602
#  数据点文件:./data/dataset/v2/validset/toilet160.png.txt, 188/190, 预计耗时1.3181846914893665秒
#  MSE loss(Relative):0.00014007922045037105, 耗时:0.7秒(114个数据点)
# Accumulated Squared Loss(Relative): 0.0159690311313423
#  数据点文件:./data/dataset/v2/validset/hammer020.png.txt, 189/190, 预计耗时0.6594744000000032秒
#  MSE loss(Relative):0.00018271567741048495, 耗时:0.5秒(92个数据点)
# Accumulated Squared Loss(Relative): 0.016809842321764617
#  数据点文件:./data/dataset/v2/validset/bed160.png.txt, 190/190, 预计耗时0.0秒
#  MSE loss(Relative):0.00032095846245638345, 耗时:1.0秒(155个数据点)
# Accumulated Squared Loss(Relative): 0.049748561680739434
#  数据集预测结果完成，控制顶点结果已保存至 ./pred_results_validset/controls
#  平均MSE:0.000383
#  耗时（不包括存储控制顶点数据到磁盘）: 126.2 秒
#  预测用时262.0 秒
#  可视化：成功加载 190 个控制点文件
#  显示其中若干结果
# 可视化最多支持9个数据，随机抽取9个显示
#  将全部结果保存到./pred_results_validset/images/
#  Creating new dest dir: ./pred_results_validset/images/
#  Saving image in ./pred_results_validset/images/bed000.png_pred.txt.jpeg, 1 / 190
#  Saving image in ./pred_results_validset/images/bed005.png_pred.txt.jpeg, 2 / 190
#  Saving image in ./pred_results_validset/images/bed030.png_pred.txt.jpeg, 3 / 190
#  Saving image in ./pred_results_validset/images/bed045.png_pred.txt.jpeg, 4 / 190
#  Saving image in ./pred_results_validset/images/bed055.png_pred.txt.jpeg, 5 / 190
#  Saving image in ./pred_results_validset/images/bed125.png_pred.txt.jpeg, 6 / 190
#  Saving image in ./pred_results_validset/images/bed135.png_pred.txt.jpeg, 7 / 190
#  Saving image in ./pred_results_validset/images/bed145.png_pred.txt.jpeg, 8 / 190
#  Saving image in ./pred_results_validset/images/bed150.png_pred.txt.jpeg, 9 / 190
#  Saving image in ./pred_results_validset/images/bed160.png_pred.txt.jpeg, 10 / 190
#  Saving image in ./pred_results_validset/images/bed175.png_pred.txt.jpeg, 11 / 190
#  Saving image in ./pred_results_validset/images/bed200.png_pred.txt.jpeg, 12 / 190
#  Saving image in ./pred_results_validset/images/bed215.png_pred.txt.jpeg, 13 / 190
#  Saving image in ./pred_results_validset/images/bed220.png_pred.txt.jpeg, 14 / 190
#  Saving image in ./pred_results_validset/images/bed230.png_pred.txt.jpeg, 15 / 190
#  Saving image in ./pred_results_validset/images/bed240.png_pred.txt.jpeg, 16 / 190
#  Saving image in ./pred_results_validset/images/bed290.png_pred.txt.jpeg, 17 / 190
#  Saving image in ./pred_results_validset/images/bed320.png_pred.txt.jpeg, 18 / 190
#  Saving image in ./pred_results_validset/images/bed355.png_pred.txt.jpeg, 19 / 190
#  Saving image in ./pred_results_validset/images/bird000.png_pred.txt.jpeg, 20 / 190
#  Saving image in ./pred_results_validset/images/bird010.png_pred.txt.jpeg, 21 / 190
#  Saving image in ./pred_results_validset/images/bird030.png_pred.txt.jpeg, 22 / 190
#  Saving image in ./pred_results_validset/images/bird075.png_pred.txt.jpeg, 23 / 190
#  Saving image in ./pred_results_validset/images/bird100.png_pred.txt.jpeg, 24 / 190
#  Saving image in ./pred_results_validset/images/bird110.png_pred.txt.jpeg, 25 / 190
#  Saving image in ./pred_results_validset/images/bird145.png_pred.txt.jpeg, 26 / 190
#  Saving image in ./pred_results_validset/images/bird150.png_pred.txt.jpeg, 27 / 190
#  Saving image in ./pred_results_validset/images/bird160.png_pred.txt.jpeg, 28 / 190
#  Saving image in ./pred_results_validset/images/bird185.png_pred.txt.jpeg, 29 / 190
#  Saving image in ./pred_results_validset/images/bird195.png_pred.txt.jpeg, 30 / 190
#  Saving image in ./pred_results_validset/images/bird205.png_pred.txt.jpeg, 31 / 190
#  Saving image in ./pred_results_validset/images/bird210.png_pred.txt.jpeg, 32 / 190
#  Saving image in ./pred_results_validset/images/bird215.png_pred.txt.jpeg, 33 / 190
#  Saving image in ./pred_results_validset/images/bird260.png_pred.txt.jpeg, 34 / 190
#  Saving image in ./pred_results_validset/images/bird270.png_pred.txt.jpeg, 35 / 190
#  Saving image in ./pred_results_validset/images/bird280.png_pred.txt.jpeg, 36 / 190
#  Saving image in ./pred_results_validset/images/bird285.png_pred.txt.jpeg, 37 / 190
#  Saving image in ./pred_results_validset/images/bird335.png_pred.txt.jpeg, 38 / 190
#  Saving image in ./pred_results_validset/images/bird355.png_pred.txt.jpeg, 39 / 190
#  Saving image in ./pred_results_validset/images/fish005.png_pred.txt.jpeg, 40 / 190
#  Saving image in ./pred_results_validset/images/fish020.png_pred.txt.jpeg, 41 / 190
#  Saving image in ./pred_results_validset/images/fish045.png_pred.txt.jpeg, 42 / 190
#  Saving image in ./pred_results_validset/images/fish050.png_pred.txt.jpeg, 43 / 190
#  Saving image in ./pred_results_validset/images/fish070.png_pred.txt.jpeg, 44 / 190
#  Saving image in ./pred_results_validset/images/fish105.png_pred.txt.jpeg, 45 / 190
#  Saving image in ./pred_results_validset/images/fish110.png_pred.txt.jpeg, 46 / 190
#  Saving image in ./pred_results_validset/images/fish140.png_pred.txt.jpeg, 47 / 190
#  Saving image in ./pred_results_validset/images/fish145.png_pred.txt.jpeg, 48 / 190
#  Saving image in ./pred_results_validset/images/fish165.png_pred.txt.jpeg, 49 / 190
#  Saving image in ./pred_results_validset/images/fish195.png_pred.txt.jpeg, 50 / 190
#  Saving image in ./pred_results_validset/images/fish215.png_pred.txt.jpeg, 51 / 190
#  Saving image in ./pred_results_validset/images/fish220.png_pred.txt.jpeg, 52 / 190
#  Saving image in ./pred_results_validset/images/fish230.png_pred.txt.jpeg, 53 / 190
#  Saving image in ./pred_results_validset/images/fish250.png_pred.txt.jpeg, 54 / 190
#  Saving image in ./pred_results_validset/images/fish260.png_pred.txt.jpeg, 55 / 190
#  Saving image in ./pred_results_validset/images/fish265.png_pred.txt.jpeg, 56 / 190
#  Saving image in ./pred_results_validset/images/fish270.png_pred.txt.jpeg, 57 / 190
#  Saving image in ./pred_results_validset/images/fish315.png_pred.txt.jpeg, 58 / 190
#  Saving image in ./pred_results_validset/images/guitar005.png_pred.txt.jpeg, 59 / 190
#  Saving image in ./pred_results_validset/images/guitar035.png_pred.txt.jpeg, 60 / 190
#  Saving image in ./pred_results_validset/images/guitar145.png_pred.txt.jpeg, 61 / 190
#  Saving image in ./pred_results_validset/images/guitar195.png_pred.txt.jpeg, 62 / 190
#  Saving image in ./pred_results_validset/images/guitar255.png_pred.txt.jpeg, 63 / 190
#  Saving image in ./pred_results_validset/images/guitar265.png_pred.txt.jpeg, 64 / 190
#  Saving image in ./pred_results_validset/images/guitar270.png_pred.txt.jpeg, 65 / 190
#  Saving image in ./pred_results_validset/images/guitar285.png_pred.txt.jpeg, 66 / 190
#  Saving image in ./pred_results_validset/images/guitar300.png_pred.txt.jpeg, 67 / 190
#  Saving image in ./pred_results_validset/images/guitar305.png_pred.txt.jpeg, 68 / 190
#  Saving image in ./pred_results_validset/images/guitar310.png_pred.txt.jpeg, 69 / 190
#  Saving image in ./pred_results_validset/images/guitar325.png_pred.txt.jpeg, 70 / 190
#  Saving image in ./pred_results_validset/images/guitar345.png_pred.txt.jpeg, 71 / 190
#  Saving image in ./pred_results_validset/images/guitar350.png_pred.txt.jpeg, 72 / 190
#  Saving image in ./pred_results_validset/images/guitar355.png_pred.txt.jpeg, 73 / 190
#  Saving image in ./pred_results_validset/images/hammer020.png_pred.txt.jpeg, 74 / 190
#  Saving image in ./pred_results_validset/images/hammer045.png_pred.txt.jpeg, 75 / 190
#  Saving image in ./pred_results_validset/images/hammer070.png_pred.txt.jpeg, 76 / 190
#  Saving image in ./pred_results_validset/images/hammer080.png_pred.txt.jpeg, 77 / 190
#  Saving image in ./pred_results_validset/images/hammer090.png_pred.txt.jpeg, 78 / 190
#  Saving image in ./pred_results_validset/images/hammer110.png_pred.txt.jpeg, 79 / 190
#  Saving image in ./pred_results_validset/images/hammer115.png_pred.txt.jpeg, 80 / 190
#  Saving image in ./pred_results_validset/images/hammer125.png_pred.txt.jpeg, 81 / 190
#  Saving image in ./pred_results_validset/images/hammer175.png_pred.txt.jpeg, 82 / 190
#  Saving image in ./pred_results_validset/images/hammer180.png_pred.txt.jpeg, 83 / 190
#  Saving image in ./pred_results_validset/images/hammer185.png_pred.txt.jpeg, 84 / 190
#  Saving image in ./pred_results_validset/images/hammer190.png_pred.txt.jpeg, 85 / 190
#  Saving image in ./pred_results_validset/images/hammer195.png_pred.txt.jpeg, 86 / 190
#  Saving image in ./pred_results_validset/images/hammer200.png_pred.txt.jpeg, 87 / 190
#  Saving image in ./pred_results_validset/images/hammer210.png_pred.txt.jpeg, 88 / 190
#  Saving image in ./pred_results_validset/images/hammer235.png_pred.txt.jpeg, 89 / 190
#  Saving image in ./pred_results_validset/images/hammer250.png_pred.txt.jpeg, 90 / 190
#  Saving image in ./pred_results_validset/images/hammer280.png_pred.txt.jpeg, 91 / 190
#  Saving image in ./pred_results_validset/images/hammer310.png_pred.txt.jpeg, 92 / 190
#  Saving image in ./pred_results_validset/images/hammer330.png_pred.txt.jpeg, 93 / 190
#  Saving image in ./pred_results_validset/images/horse000.png_pred.txt.jpeg, 94 / 190
#  Saving image in ./pred_results_validset/images/horse020.png_pred.txt.jpeg, 95 / 190
#  Saving image in ./pred_results_validset/images/horse025.png_pred.txt.jpeg, 96 / 190
#  Saving image in ./pred_results_validset/images/horse085.png_pred.txt.jpeg, 97 / 190
#  Saving image in ./pred_results_validset/images/horse095.png_pred.txt.jpeg, 98 / 190
#  Saving image in ./pred_results_validset/images/horse100.png_pred.txt.jpeg, 99 / 190
# ...
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/servingspoonbinary65.png_pred.txt.jpeg, 165 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/servingspoonbinary7.png_pred.txt.jpeg, 166 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/servingspoonbinary8.png_pred.txt.jpeg, 167 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/servingspoonbinary81.png_pred.txt.jpeg, 168 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/servingspoonbinary84.png_pred.txt.jpeg, 169 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/servingspoonbinary9.png_pred.txt.jpeg, 170 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/spatulabinary1.png_pred.txt.jpeg, 171 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/spatulabinary11.png_pred.txt.jpeg, 172 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/spatulabinary12.png_pred.txt.jpeg, 173 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/spatulabinary16.png_pred.txt.jpeg, 174 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/spatulabinary19.png_pred.txt.jpeg, 175 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/spatulabinary28.png_pred.txt.jpeg, 176 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/spatulabinary3.png_pred.txt.jpeg, 177 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/spatulabinary37.png_pred.txt.jpeg, 178 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/spatulabinary38.png_pred.txt.jpeg, 179 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/spatulabinary43.png_pred.txt.jpeg, 180 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/spatulabinary44.png_pred.txt.jpeg, 181 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/spatulabinary49.png_pred.txt.jpeg, 182 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/spatulabinary50.png_pred.txt.jpeg, 183 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/spatulabinary51.png_pred.txt.jpeg, 184 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/spatulabinary52.png_pred.txt.jpeg, 185 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/spatulabinary6.png_pred.txt.jpeg, 186 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/spatulabinary8.png_pred.txt.jpeg, 187 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/spatulabinary9.png_pred.txt.jpeg, 188 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/tongsbinary12.png_pred.txt.jpeg, 189 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/tongsbinary13.png_pred.txt.jpeg, 190 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/tongsbinary14.png_pred.txt.jpeg, 191 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/tongsbinary15.png_pred.txt.jpeg, 192 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/tongsbinary18.png_pred.txt.jpeg, 193 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/tongsbinary24.png_pred.txt.jpeg, 194 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/tongsbinary27.png_pred.txt.jpeg, 195 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/tongsbinary28.png_pred.txt.jpeg, 196 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/tongsbinary30.png_pred.txt.jpeg, 197 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/tongsbinary32.png_pred.txt.jpeg, 198 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/tongsbinary34.png_pred.txt.jpeg, 199 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/tongsbinary35.png_pred.txt.jpeg, 200 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/tongsbinary36.png_pred.txt.jpeg, 201 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/tongsbinary5.png_pred.txt.jpeg, 202 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/tongsbinary8.png_pred.txt.jpeg, 203 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/tongsbinary9.png_pred.txt.jpeg, 204 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary1.png_pred.txt.jpeg, 205 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary10.png_pred.txt.jpeg, 206 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary11.png_pred.txt.jpeg, 207 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary12.png_pred.txt.jpeg, 208 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary13.png_pred.txt.jpeg, 209 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary14.png_pred.txt.jpeg, 210 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary16.png_pred.txt.jpeg, 211 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary17.png_pred.txt.jpeg, 212 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary18.png_pred.txt.jpeg, 213 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary19.png_pred.txt.jpeg, 214 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary2.png_pred.txt.jpeg, 215 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary20.png_pred.txt.jpeg, 216 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary21.png_pred.txt.jpeg, 217 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary22.png_pred.txt.jpeg, 218 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary23.png_pred.txt.jpeg, 219 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary24.png_pred.txt.jpeg, 220 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary25.png_pred.txt.jpeg, 221 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary26.png_pred.txt.jpeg, 222 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary27.png_pred.txt.jpeg, 223 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary28.png_pred.txt.jpeg, 224 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary29.png_pred.txt.jpeg, 225 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary3.png_pred.txt.jpeg, 226 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary30.png_pred.txt.jpeg, 227 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary31.png_pred.txt.jpeg, 228 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary32.png_pred.txt.jpeg, 229 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary33.png_pred.txt.jpeg, 230 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary34.png_pred.txt.jpeg, 231 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary35.png_pred.txt.jpeg, 232 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary36.png_pred.txt.jpeg, 233 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary37.png_pred.txt.jpeg, 234 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary38.png_pred.txt.jpeg, 235 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary4.png_pred.txt.jpeg, 236 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary42.png_pred.txt.jpeg, 237 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary43.png_pred.txt.jpeg, 238 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary44.png_pred.txt.jpeg, 239 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary47.png_pred.txt.jpeg, 240 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary49.png_pred.txt.jpeg, 241 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary5.png_pred.txt.jpeg, 242 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary50.png_pred.txt.jpeg, 243 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary53.png_pred.txt.jpeg, 244 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary54.png_pred.txt.jpeg, 245 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary55.png_pred.txt.jpeg, 246 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary56.png_pred.txt.jpeg, 247 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary57.png_pred.txt.jpeg, 248 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary58.png_pred.txt.jpeg, 249 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary59.png_pred.txt.jpeg, 250 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary6.png_pred.txt.jpeg, 251 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary60.png_pred.txt.jpeg, 252 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary62.png_pred.txt.jpeg, 253 / 254
#  Saving image in ./pred_results_kitchenOrderedVertices_1_20/images/woodenspoonbinary7.png_pred.txt.jpeg, 254 / 254
#  Creating new dest dir: ./pred_results_LSPIAset
#  Creating new Control Points dir:./pred_results_LSPIAset/controls
# Test with cpu
#  BSplineGNN key parameters:
# 	num iterations:1
# 	num Gnn layers:5
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  数据集中有9 个文件，我们只使用其中的9个文件。
#  数据点文件:./data/pred/LSPIAset/Monitor0.txt.pcd.txt, 1/9, 预计耗时0.0秒
#  MSE loss(Relative):0.0030494483603408446, 耗时:5.3秒(915个数据点)
# Accumulated Squared Loss(Relative): 2.7902452497118726
#  数据点文件:./data/pred/LSPIAset/tulip.p2d.pcd.txt, 2/9, 预计耗时18.434936099996776秒
#  MSE loss(Relative):0.00030991132714577126, 耗时:0.5秒(79个数据点)
# Accumulated Squared Loss(Relative): 0.02448299484451593
#  数据点文件:./data/pred/LSPIAset/Mouse0.txt.pcd.txt, 3/9, 预计耗时11.531436399996892秒
#  MSE loss(Relative):0.0010680819408389031, 耗时:1.0秒(157个数据点)
# Accumulated Squared Loss(Relative): 0.1676888647117078
#  数据点文件:./data/pred/LSPIAset/Fig12b.txt.pcd.txt, 4/9, 预计耗时8.449874874997931秒
#  MSE loss(Relative):0.08757467891299096, 耗时:0.8秒(120个数据点)
# Accumulated Squared Loss(Relative): 10.508961469558916
#  数据点文件:./data/pred/LSPIAset/invheart.p2d.pcd.txt, 5/9, 预计耗时6.0247076799991195秒
#  MSE loss(Relative):0.00012436896992471213, 耗时:0.2秒(34个数据点)
# Accumulated Squared Loss(Relative): 0.004228544977440213
#  数据点文件:./data/pred/LSPIAset/family.p2d.pcd.txt, 6/9, 预计耗时3.8731686499995703秒
#  MSE loss(Relative):0.18560261078230533, 耗时:5.7秒(1000个数据点)
# Accumulated Squared Loss(Relative): 185.60261078230533
#  数据点文件:./data/pred/LSPIAset/mc5.txt.pcd.txt, 7/9, 预计耗时3.8464879714286195秒
#  MSE loss(Relative):0.0002480501412400045, 耗时:0.6秒(91个数据点)
# Accumulated Squared Loss(Relative): 0.022572562852840407
#  数据点文件:./data/pred/LSPIAset/mc10.txt.pcd.txt, 8/9, 预计耗时1.753606125000033秒
#  MSE loss(Relative):0.012431151421660321, 耗时:1.8秒(300个数据点)
# Accumulated Squared Loss(Relative): 3.7293454264980963
#  数据点文件:./data/pred/LSPIAset/cur_data.txt, 9/9, 预计耗时0.0秒
#  MSE loss(Relative):0.00033388292183137076, 耗时:1.6秒(269个数据点)
# Accumulated Squared Loss(Relative): 0.08981450597263874
#  数据集预测结果完成，控制顶点结果已保存至 ./pred_results_LSPIAset/controls
#  平均MSE:0.032305
#  耗时（不包括存储控制顶点数据到磁盘）: 17.4 秒
#  预测用时36.5 秒
#  可视化：成功加载 9 个控制点文件
#  显示其中若干结果
# 可视化最多支持9个数据，随机抽取9个显示
#  将全部结果保存到./pred_results_LSPIAset/images/
#  Creating new dest dir: ./pred_results_LSPIAset/images/
#  Saving image in ./pred_results_LSPIAset/images/cur_data_pred.txt.jpeg, 1 / 9
#  Saving image in ./pred_results_LSPIAset/images/family.p2d.pcd_pred.txt.jpeg, 2 / 9
#  Saving image in ./pred_results_LSPIAset/images/Fig12b_pred.txt.pcd_pred.txt.jpeg, 3 / 9
#  Saving image in ./pred_results_LSPIAset/images/invheart.p2d.pcd_pred.txt.jpeg, 4 / 9
#  Saving image in ./pred_results_LSPIAset/images/mc10_pred.txt.pcd_pred.txt.jpeg, 5 / 9
#  Saving image in ./pred_results_LSPIAset/images/mc5_pred.txt.pcd_pred.txt.jpeg, 6 / 9
#  Saving image in ./pred_results_LSPIAset/images/Monitor0_pred.txt.pcd_pred.txt.jpeg, 7 / 9
#  Saving image in ./pred_results_LSPIAset/images/Mouse0_pred.txt.pcd_pred.txt.jpeg, 8 / 9
#  Saving image in ./pred_results_LSPIAset/images/tulip.p2d.pcd_pred.txt.jpeg, 9 / 9
#  Creating new dest dir: ./pred_results_noisyset
#  Creating new Control Points dir:./pred_results_noisyset/controls
# Test with cpu
#  BSplineGNN key parameters:
# 	num iterations:1
# 	num Gnn layers:5
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  ControlUpdateLayer key parameters:
# 	Not using Gru in ControlUpdateLayer
# 	Not using attention in ControlUpdateLayerr.message
#  数据集中有3 个文件，我们只使用其中的3个文件。
#  数据点文件:./data/pred/noisyset/dolphin_2percent_noise.txt.pcd.txt, 1/3, 预计耗时0.0秒
#  MSE loss(Relative):0.000708774462982085, 耗时:1.2秒(179个数据点)
# Accumulated Squared Loss(Relative): 0.12687062887379322
#  数据点文件:./data/pred/noisyset/butterfly_2percent_noise.txt.pcd.txt, 2/3, 预计耗时0.583241000000271秒
#  MSE loss(Relative):0.0004239587574769874, 耗时:1.0秒(164个数据点)
# Accumulated Squared Loss(Relative): 0.06952923622622594
#  数据点文件:./data/pred/noisyset/apple_2percent_noise.txt.pcd.txt, 3/3, 预计耗时0.0秒
#  MSE loss(Relative):0.0003680619285375494, 耗时:1.1秒(170个数据点)
# Accumulated Squared Loss(Relative): 0.0625705278513834
#  数据集预测结果完成，控制顶点结果已保存至 ./pred_results_noisyset/controls
#  平均MSE:0.000500
#  耗时（不包括存储控制顶点数据到磁盘）: 3.3 秒
#  预测用时6.8 秒
#  可视化：成功加载 3 个控制点文件
#  显示其中若干结果
#  将全部结果保存到./pred_results_noisyset/images/
#  Creating new dest dir: ./pred_results_noisyset/images/
#  Saving image in ./pred_results_noisyset/images/apple_2percent_noise_pred.txt.pcd_pred.txt.jpeg, 1 / 3
#  Saving image in ./pred_results_noisyset/images/butterfly_2percent_noise_pred.txt.pcd_pred.txt.jpeg, 2 / 3
#  Saving image in ./pred_results_noisyset/images/dolphin_2percent_noise_pred.txt.pcd_pred.txt.jpeg, 3 / 3

# %% [markdown]
# # 与其他算法的比较

# %% [markdown]
# ## LSPIA

# %%
import sys,os
sys.path.append('E:/_Papers/_code/curve_fitting/_MyExperiments')
from LSPIA_master import LSPIA
import time


datafolder = validfolder + '/' #'./data/dataset/v2/'

nCtlPts = 30
totaltime = 0

# 数据规范化和反规范化应该是外部做，不应在拟合函数内部做。
# 有些不公平：lspia中的数据读取、数据规范化、数据可视化的时间都被算进去了
# 将来可以在LSPIA函数内部精确记录工作时间，然后返回来，并返回迭代了多少次这样的参数
# filelist = os.listdir(datafolder)
print(filelist)
for file in filelist:
    print(file)
    if not file[-3:] == 'txt':
        continue
    print(file)
    file = datafolder + file
    starttime = time.perf_counter()
    data_parameters,knot_vector,ctlPts = LSPIA.LSPIA_curve(file=file,degree=3,nCtlPts=nCtlPts,vis=True,normdata=True)
    endtime = time.perf_counter()
    totaltime += endtime - starttime

print(f'LSPIA 总用时{totaltime:.1f} 秒')
# Out:
# ['horse095.png.txt', 'teddy160.png.txt', 'fish105.png.txt', 'bird210.png.txt', 'teddy155.png.txt', 'teddy330.png.txt', 'television225.png.txt', 'guitar005.png.txt', 'toilet140.png.txt']
# horse095.png.txt
# horse095.png.txt
# ******************************
# LSPIA方法处理文件./data/dataset/v2/validset//horse095.png.txt中......
# number of data points: 64
# init number of control points: 30
# parameters of original data(64): [0.         0.02215006 0.03538725 0.04951766 0.06275485 0.07599204
#  0.08922923 0.10335964 0.11749005 0.13072724 0.14396444 0.16211959
#  0.17535679 0.19540888 0.21728701 0.23846069 0.25169788 0.26493507
#  0.27817226 0.29140946 0.30763689 0.32756407 0.3426155  0.35674591
#  0.37200254 0.38548005 0.4011991  0.41812872 0.44000685 0.46188497
#  0.48376309 0.50531413 0.51944454 0.53357495 0.54705246 0.56052997
#  0.57376716 0.58700435 0.60024154 0.61347873 0.62671593 0.64084634
#  0.65497675 0.66821394 0.68145113 0.69756134 0.71543803 0.73449579
#  0.75355355 0.77348073 0.78959094 0.80282813 0.81630564 0.82978315
#  0.84574003 0.86768382 0.88959121 0.911535   0.92929456 0.94253175
#  0.95666216 0.96989935 0.98313654 1.        ]
# init knot vector(34): [0.         0.         0.         0.         0.02705272 0.05932299
#  0.09079928 0.12386352 0.15942994 0.20027069 0.24630495 0.277682
#  0.31427929 0.35255912 0.38664442 0.42785233 0.47971159 0.52206129
#  0.55453997 0.58602382 0.61740086 0.65026661 0.6820478  0.72320231
#  0.76905247 0.8048248  0.83805709 0.88715705 0.93272642 0.96499669
#  1.         1.         1.         1.        ]
# Finish iterating 135 times. 误差值(全部数据点误差之和)(以规范化后的数据计算): 0.062333147883697544
# MSE error: 0.0020777715961232514
# LSPIA 处理文件./data/dataset/v2/validset//horse095.png.txt完毕。返回结果包括：数据点参数、节点向量、控制顶点。使用GenerateBSplineCurveData来获取数据
# ##############################
# 前100次迭代的MSE误差(规范化数据):[4.10193093e+00 1.57923034e+00 6.84761176e-01 3.08160599e-01
#  1.41750888e-01 6.66485474e-02 3.23228775e-02 1.64756093e-02
#  9.08672888e-03 5.60283956e-03 3.93691428e-03 3.12506275e-03
#  2.71877286e-03 2.50768274e-03 2.39223506e-03 2.32479830e-03
#  2.28226897e-03 2.25323793e-03 2.23193536e-03 2.21535040e-03
#  2.20184744e-03 2.19049324e-03 2.18072469e-03 2.17218148e-03
#  2.16461958e-03 2.15786520e-03 2.15178917e-03 2.14629219e-03
#  2.14129578e-03 2.13673664e-03 2.13256277e-03 2.12873085e-03
#  2.12520435e-03 2.12195215e-03 2.11894748e-03 2.11616713e-03
#  2.11359082e-03 2.11120069e-03 2.10898097e-03 2.10691758e-03
#  2.10499797e-03 2.10321083e-03 2.10154597e-03 2.09999415e-03
#  2.09854698e-03 2.09719682e-03 2.09593667e-03 2.09476013e-03
#  2.09366130e-03 2.09263479e-03 2.09167559e-03 2.09077909e-03
#  2.08994104e-03 2.08915750e-03 2.08842479e-03 2.08773953e-03
#  2.08709857e-03 2.08649898e-03 2.08593803e-03 2.08541318e-03
#  2.08492208e-03 2.08446251e-03 2.08403243e-03 2.08362992e-03
#  2.08325320e-03 2.08290059e-03 2.08257054e-03 2.08226160e-03
#  2.08197239e-03 2.08170166e-03 2.08144822e-03 2.08121096e-03
#  2.08098883e-03 2.08078087e-03 2.08058618e-03 2.08040390e-03
#  2.08023323e-03 2.08007345e-03 2.07992384e-03 2.07978376e-03
#  2.07965261e-03 2.07952981e-03 2.07941483e-03 2.07930717e-03
#  2.07920637e-03 2.07911198e-03 2.07902361e-03 2.07894085e-03
#  2.07886337e-03 2.07879081e-03 2.07872288e-03 2.07865926e-03
#  2.07859970e-03 2.07854392e-03 2.07849170e-03 2.07844279e-03
#  2.07839700e-03 2.07835412e-03 2.07831397e-03 2.07827638e-03]
# teddy160.png.txt
# teddy160.png.txt
# ******************************
# LSPIA方法处理文件./data/dataset/v2/validset//teddy160.png.txt中......
# number of data points: 113
# init number of control points: 30
# parameters of original data(113): [0.         0.00827084 0.01861111 0.02716201 0.03689014 0.04726348
#  0.05574198 0.0642435  0.07274502 0.08083844 0.08878104 0.09672363
#  0.10647563 0.11497715 0.12347867 0.13142126 0.13936385 0.14791475
#  0.1568622  0.16630029 0.17573838 0.18531538 0.19443817 0.20384055
#  0.21315385 0.22273085 0.23216894 0.24160703 0.25084825 0.25939915
#  0.26790067 0.27623093 0.28417352 0.29265203 0.30120293 0.31044414
#  0.31968536 0.32863281 0.33699649 0.34536018 0.35345361 0.36193211
#  0.37117333 0.37965183 0.38859928 0.39715018 0.40658827 0.41602636
#  0.42541675 0.43485484 0.44443184 0.45367306 0.46215156 0.47009416
#  0.47803675 0.48768613 0.49623703 0.50547825 0.5151556  0.52465232
#  0.53422932 0.54232274 0.55030385 0.55880537 0.56819576 0.57763385
#  0.58707194 0.59646234 0.60585273 0.61542973 0.62398063 0.63225147
#  0.64019407 0.64828749 0.65900729 0.66849741 0.67757122 0.68724858
#  0.69682558 0.70626367 0.71565406 0.72509215 0.73453024 0.74410724
#  0.75354533 0.76298342 0.77237381 0.7817762  0.79072364 0.80012603
#  0.80951642 0.81890681 0.82829721 0.83769959 0.84710198 0.85649237
#  0.86593046 0.87550746 0.88474868 0.89301952 0.90129036 0.90938379
#  0.91732639 0.92526898 0.93321157 0.94171309 0.94965569 0.95881456
#  0.96675716 0.97469975 0.9829706  0.9914491  1.        ]
# init knot vector(34): [0.         0.         0.         0.         0.02896351 0.06739221
#  0.10214141 0.13730466 0.17503926 0.21421796 0.25338185 0.28825577
#  0.32565032 0.36067604 0.39749974 0.43698306 0.47333003 0.51121298
#  0.54853027 0.58672238 0.62520594 0.66217066 0.7017194  0.74126961
#  0.78073149 0.8196024  0.85893928 0.89669545 0.93026987 0.96528631
#  1.         1.         1.         1.        ]
# Finish iterating 120 times. 误差值(全部数据点误差之和)(以规范化后的数据计算): 0.08652458877215001
# MSE error: 0.002884152959071667
# LSPIA 处理文件./data/dataset/v2/validset//teddy160.png.txt完毕。返回结果包括：数据点参数、节点向量、控制顶点。使用GenerateBSplineCurveData来获取数据
# ##############################
# 前100次迭代的MSE误差(规范化数据):[7.31134503e+00 5.34989356e+00 4.11943267e+00 3.22464551e+00
#  2.55120069e+00 2.03420414e+00 1.63178219e+00 1.31530633e+00
#  1.06445241e+00 8.64380342e-01 7.04015218e-01 5.74949591e-01
#  4.70715030e-01 3.86282358e-01 3.17708792e-01 2.61882646e-01
#  2.16334835e-01 1.79097380e-01 1.48595754e-01 1.23566102e-01
#  1.02991017e-01 8.60493719e-02 7.20769027e-02 6.05350773e-02
#  5.09864186e-02 4.30748674e-02 3.65101081e-02 3.10550221e-02
#  2.65156201e-02 2.27329430e-02 1.95765347e-02 1.69391688e-02
#  1.47325821e-02 1.28840158e-02 1.13334060e-02 1.00310997e-02
#  8.93599290e-03 8.01401272e-03 7.23687609e-03 6.58107469e-03
#  6.02704302e-03 5.55847575e-03 5.16176692e-03 4.82554846e-03
#  4.54031012e-03 4.29808587e-03 4.09219494e-03 3.91702761e-03
#  3.76786788e-03 3.64074643e-03 3.53231848e-03 3.43976238e-03
#  3.36069511e-03 3.29310195e-03 3.23527771e-03 3.18577770e-03
#  3.14337673e-03 3.10703470e-03 3.07586783e-03 3.04912449e-03
#  3.02616484e-03 3.00644376e-03 2.98949643e-03 2.97492619e-03
#  2.96239432e-03 2.95161130e-03 2.94232954e-03 2.93433715e-03
#  2.92745267e-03 2.92152060e-03 2.91640765e-03 2.91199943e-03
#  2.90819779e-03 2.90491842e-03 2.90208889e-03 2.89964694e-03
#  2.89753903e-03 2.89571911e-03 2.89414753e-03 2.89279016e-03
#  2.89161761e-03 2.89060456e-03 2.88972918e-03 2.88897266e-03
#  2.88831877e-03 2.88775352e-03 2.88726484e-03 2.88684232e-03
#  2.88647695e-03 2.88616098e-03 2.88588771e-03 2.88565134e-03
#  2.88544688e-03 2.88527000e-03 2.88511698e-03 2.88498459e-03
#  2.88487004e-03 2.88477091e-03 2.88468514e-03 2.88461091e-03]
# fish105.png.txt
# fish105.png.txt
# ******************************
# LSPIA方法处理文件./data/dataset/v2/validset//fish105.png.txt中......
# number of data points: 48
# init number of control points: 30
# parameters of original data(48): [0.         0.01927383 0.04179789 0.06227377 0.08492913 0.10705533
#  0.12855153 0.15206513 0.17396833 0.19637723 0.21787342 0.23749527
#  0.25685788 0.2774693  0.30043317 0.32193537 0.34411189 0.36472331
#  0.38399714 0.40361899 0.42289282 0.44424704 0.46615024 0.48676166
#  0.50972554 0.52934739 0.54937976 0.56900161 0.59151818 0.61199405
#  0.63260548 0.6531733  0.67534982 0.69725303 0.71786445 0.73993375
#  0.76143594 0.78191181 0.80247964 0.82823143 0.8507555  0.87136692
#  0.89389099 0.91582513 0.93509896 0.95437279 0.98037815 1.        ]
# init knot vector(34): [0.         0.         0.         0.         0.01499076 0.05317338
#  0.09230453 0.13116415 0.17153464 0.21070803 0.24610087 0.28257238
#  0.32193537 0.36014299 0.39489817 0.43001089 0.4684404  0.507174
#  0.5427023  0.57900897 0.61657437 0.6531733  0.69238565 0.73012517
#  0.76826123 0.80534095 0.84825283 0.88638297 0.92439128 0.96015176
#  1.         1.         1.         1.        ]
# Finish iterating 267 times. 误差值(全部数据点误差之和)(以规范化后的数据计算): 0.06541389278992515
# MSE error: 0.002180463092997505
# LSPIA 处理文件./data/dataset/v2/validset//fish105.png.txt完毕。返回结果包括：数据点参数、节点向量、控制顶点。使用GenerateBSplineCurveData来获取数据
# ##############################
# 前100次迭代的MSE误差(规范化数据):[3.00992519e+00 1.98482901e+00 1.41583234e+00 1.02847254e+00
#  7.54358883e-01 5.57068792e-01 4.13598948e-01 3.08505492e-01
#  2.31090900e-01 1.73803260e-01 1.31243050e-01 9.95141625e-02
#  7.57855534e-02 5.79884654e-02 4.46040077e-02 3.45124113e-02
#  2.68851208e-02 2.11070132e-02 1.67200146e-02 1.33820264e-02
#  1.08368762e-02 8.89224982e-03 7.40342629e-03 6.26125171e-03
#  5.38321927e-03 4.70683459e-03 4.18466748e-03 3.78065202e-03
#  3.46731321e-03 3.22368350e-03 3.03373401e-03 2.88519091e-03
#  2.76864056e-03 2.67685157e-03 2.60426045e-03 2.54658040e-03
#  2.50050353e-03 2.46347355e-03 2.43351221e-03 2.40908637e-03
#  2.38900617e-03 2.37234687e-03 2.35838872e-03 2.34657070e-03
#  2.33645488e-03 2.32769884e-03 2.32003444e-03 2.31325132e-03
#  2.30718416e-03 2.30170276e-03 2.29670434e-03 2.29210761e-03
#  2.28784804e-03 2.28387430e-03 2.28014538e-03 2.27662840e-03
#  2.27329687e-03 2.27012934e-03 2.26710836e-03 2.26421961e-03
#  2.26145126e-03 2.25879348e-03 2.25623801e-03 2.25377783e-03
#  2.25140697e-03 2.24912024e-03 2.24691311e-03 2.24478159e-03
#  2.24272211e-03 2.24073147e-03 2.23880675e-03 2.23694528e-03
#  2.23514461e-03 2.23340242e-03 2.23171659e-03 2.23008509e-03
#  2.22850603e-03 2.22697758e-03 2.22549804e-03 2.22406576e-03
#  2.22267917e-03 2.22133677e-03 2.22003710e-03 2.21877877e-03
#  2.21756045e-03 2.21638085e-03 2.21523872e-03 2.21413285e-03
#  2.21306209e-03 2.21202531e-03 2.21102142e-03 2.21004939e-03
#  2.20910819e-03 2.20819685e-03 2.20731441e-03 2.20645996e-03
#  2.20563260e-03 2.20483148e-03 2.20405576e-03 2.20330463e-03]
# bird210.png.txt
# bird210.png.txt
# ******************************
# LSPIA方法处理文件./data/dataset/v2/validset//bird210.png.txt中......
# number of data points: 96
# init number of control points: 30
# parameters of original data(96): [0.         0.0100923  0.02069757 0.03105498 0.04192619 0.05255425
#  0.06318232 0.07353972 0.08361775 0.09329849 0.10297923 0.11280061
#  0.12287864 0.1338419  0.14459948 0.1554707  0.1656813  0.1767432
#  0.1875879  0.19768021 0.20789081 0.21771219 0.22753358 0.23725005
#  0.24723916 0.25706055 0.26688193 0.27670332 0.28652471 0.29634609
#  0.30602683 0.31584821 0.32738842 0.33892863 0.35046884 0.36281186
#  0.37356944 0.38580199 0.39640726 0.40716484 0.41785117 0.4285375
#  0.43922383 0.45184894 0.46152967 0.47306988 0.48538557 0.49692578
#  0.50997297 0.5196537  0.52933444 0.53901518 0.54869591 0.55837665
#  0.56805739 0.58030266 0.59100693 0.60136434 0.6123276  0.62329085
#  0.63397718 0.64468145 0.65552616 0.66628374 0.67649434 0.68670494
#  0.69691554 0.70699357 0.71708587 0.72755465 0.73763268 0.74823795
#  0.75831598 0.76878476 0.77914217 0.78949957 0.80012763 0.81109089
#  0.82184847 0.8325348  0.84322113 0.85406583 0.86502909 0.87565715
#  0.88652836 0.89673896 0.90683127 0.9169093  0.92698733 0.93761539
#  0.94830172 0.9590593  0.97002255 0.98010058 0.98992197 1.        ]
# init knot vector(34): [0.         0.         0.         0.         0.02645168 0.06433314
#  0.09975231 0.13623247 0.174285   0.2111646  0.24612926 0.28106838
#  0.31584821 0.35732607 0.39760255 0.43566172 0.4758067  0.51750243
#  0.55192283 0.58981757 0.62804033 0.66628374 0.70251445 0.73881105
#  0.7756897  0.81348146 0.8516559  0.8899319  0.92586755 0.96393186
#  1.         1.         1.         1.        ]
# Finish iterating 74 times. 误差值(全部数据点误差之和)(以规范化后的数据计算): 0.1369579036087571
# MSE error: 0.004565263453625236
# LSPIA 处理文件./data/dataset/v2/validset//bird210.png.txt完毕。返回结果包括：数据点参数、节点向量、控制顶点。使用GenerateBSplineCurveData来获取数据
# ##############################
# 前74次迭代的MSE误差(规范化数据):[5.98620503e+00 3.44139746e+00 2.25802514e+00 1.54139530e+00
#  1.07863458e+00 7.68178843e-01 5.54366384e-01 4.04281413e-01
#  2.97412996e-01 2.20472876e-01 1.64592709e-01 1.23717210e-01
#  9.36380906e-02 7.13899275e-02 5.48599671e-02 4.25294275e-02
#  3.32983597e-02 2.63650840e-02 2.11420812e-02 1.71966737e-02
#  1.42088150e-02 1.19408244e-02 1.02155427e-02 8.90047613e-03
#  7.89622641e-03 7.12800795e-03 6.53940249e-03 6.08774183e-03
#  5.74068188e-03 5.47365162e-03 5.26794752e-03 5.10930569e-03
#  4.98682907e-03 4.89217911e-03 4.81896537e-03 4.76228340e-03
#  4.71836418e-03 4.68430765e-03 4.65787975e-03 4.63735760e-03
#  4.62141114e-03 4.60901259e-03 4.59936703e-03 4.59185909e-03
#  4.58601203e-03 4.58145622e-03 4.57790488e-03 4.57513533e-03
#  4.57297457e-03 4.57128814e-03 4.56997142e-03 4.56894300e-03
#  4.56813949e-03 4.56751150e-03 4.56702056e-03 4.56663663e-03
#  4.56633632e-03 4.56610136e-03 4.56591747e-03 4.56577353e-03
#  4.56566083e-03 4.56557258e-03 4.56550345e-03 4.56544929e-03
#  4.56540686e-03 4.56537360e-03 4.56534754e-03 4.56532710e-03
#  4.56531108e-03 4.56529852e-03 4.56528867e-03 4.56528094e-03
#  4.56527487e-03 4.56527012e-03]
# teddy155.png.txt
# teddy155.png.txt
# ******************************
# LSPIA方法处理文件./data/dataset/v2/validset//teddy155.png.txt中......
# number of data points: 112
# init number of control points: 30
# parameters of original data(112): [0.         0.00803613 0.01764226 0.02626746 0.03488285 0.04420602
#  0.05224215 0.06027828 0.06898174 0.07877339 0.08842894 0.0981419
#  0.10727485 0.11671681 0.12581312 0.13560476 0.14526031 0.15497327
#  0.16410622 0.17280968 0.18119235 0.18922848 0.19742407 0.20612753
#  0.214831   0.22454395 0.23433559 0.24346854 0.25335103 0.26227655
#  0.27047214 0.27967651 0.28946815 0.29896232 0.30766579 0.31697169
#  0.32659231 0.33621293 0.34586849 0.35552405 0.36496601 0.37409896
#  0.38229455 0.39033068 0.39889796 0.40751335 0.41700752 0.42644949
#  0.43589145 0.44554701 0.4536239  0.46181948 0.47001507 0.47972803
#  0.48944098 0.4990616  0.50867049 0.51827938 0.52772135 0.53633674
#  0.54453233 0.55256846 0.5613716  0.56940773 0.57744386 0.58606906
#  0.59468445 0.60447609 0.61426773 0.62392329 0.63353218 0.64318774
#  0.65297938 0.66263493 0.67229049 0.68194605 0.691079   0.70073456
#  0.71034345 0.71995234 0.72956123 0.73921678 0.74882567 0.75848123
#  0.76809012 0.77771074 0.7874237  0.79686566 0.80549087 0.81368646
#  0.82188204 0.82995893 0.83799506 0.84726653 0.85546211 0.86349824
#  0.87153437 0.8795705  0.88760663 0.89564276 0.90426797 0.91234485
#  0.92096024 0.92958545 0.93946794 0.94808333 0.95787154 0.96594842
#  0.97456382 0.98318902 0.99180441 1.        ]
# init knot vector(34): [0.         0.         0.         0.         0.02754382 0.06285708
#  0.10220099 0.14132657 0.17901906 0.21386394 0.2536816  0.29122633
#  0.32979918 0.36936336 0.40432246 0.44340133 0.47900855 0.51897879
#  0.55452471 0.58925995 0.62890568 0.66907197 0.70856402 0.74846979
#  0.7884728  0.82397605 0.85873609 0.89207115 0.92702983 0.96475185
#  1.         1.         1.         1.        ]
# Finish iterating 71 times. 误差值(全部数据点误差之和)(以规范化后的数据计算): 0.05785054447243797
# MSE error: 0.001928351482414599
# LSPIA 处理文件./data/dataset/v2/validset//teddy155.png.txt完毕。返回结果包括：数据点参数、节点向量、控制顶点。使用GenerateBSplineCurveData来获取数据
# ##############################
# 前71次迭代的MSE误差(规范化数据):[7.14589337e+00 4.34880733e+00 2.90562620e+00 1.99024294e+00
#  1.38051059e+00 9.65405411e-01 6.79212129e-01 4.80232808e-01
#  3.41035416e-01 2.43182908e-01 1.74112161e-01 1.25181073e-01
#  9.04032196e-02 6.56090909e-02 4.78815098e-02 3.51714790e-02
#  2.60347268e-02 1.94499186e-02 1.46925959e-02 1.12473871e-02
#  8.74664054e-03 6.92738001e-03 5.60101494e-03 4.63196076e-03
#  3.92250438e-03 3.40206053e-03 3.01952423e-03 2.73781293e-03
#  2.52996137e-03 2.37632053e-03 2.26254367e-03 2.17813498e-03
#  2.11540127e-03 2.06869309e-03 2.03385429e-03 2.00782185e-03
#  1.98833443e-03 1.97371973e-03 1.96273893e-03 1.95447282e-03
#  1.94823821e-03 1.94352651e-03 1.93995845e-03 1.93725079e-03
#  1.93519161e-03 1.93362211e-03 1.93242310e-03 1.93150493e-03
#  1.93080012e-03 1.93025771e-03 1.92983919e-03 1.92951542e-03
#  1.92926424e-03 1.92906885e-03 1.92891641e-03 1.92879714e-03
#  1.92870355e-03 1.92862989e-03 1.92857175e-03 1.92852571e-03
#  1.92848916e-03 1.92846005e-03 1.92843680e-03 1.92841818e-03
#  1.92840322e-03 1.92839118e-03 1.92838145e-03 1.92837358e-03
#  1.92836720e-03 1.92836200e-03 1.92835777e-03]
# teddy330.png.txt
# teddy330.png.txt
# ******************************
# LSPIA方法处理文件./data/dataset/v2/validset//teddy330.png.txt中......
# number of data points: 102
# init number of control points: 30
# parameters of original data(102): [0.         0.00861354 0.02025172 0.02957289 0.04038331 0.05101506
#  0.0616468  0.07232406 0.08272439 0.09133792 0.09995146 0.11027244
#  0.12067836 0.13017179 0.13920369 0.14801055 0.15662409 0.16597721
#  0.17601666 0.18675    0.19748335 0.20812653 0.21880379 0.2292568
#  0.23946856 0.25027898 0.26049074 0.2692976  0.27810446 0.28742563
#  0.2967468  0.30715273 0.31755866 0.32823592 0.33904633 0.34853976
#  0.35856572 0.36805915 0.37845947 0.38726633 0.39729228 0.40733173
#  0.41800899 0.42868625 0.43936351 0.45017393 0.46085119 0.47125711
#  0.48272342 0.49221685 0.5022563  0.51160942 0.52093059 0.53025177
#  0.53905863 0.54767216 0.55892532 0.56827844 0.5783044  0.58765752
#  0.59697869 0.60601059 0.61481745 0.62343098 0.63204452 0.64199765
#  0.65061119 0.65941805 0.66803158 0.67664512 0.68525866 0.69387219
#  0.70248573 0.71365793 0.72232102 0.73093455 0.74088769 0.74969455
#  0.76112289 0.77116234 0.78197276 0.79265002 0.8032932  0.81393638
#  0.82457956 0.83522274 0.8459     0.85671042 0.86738768 0.87801942
#  0.88865117 0.89929435 0.90970028 0.92043363 0.93116697 0.94179872
#  0.95247598 0.96328639 0.97349816 0.98253005 0.99133691 1.        ]
# init knot vector(34): [0.         0.         0.         0.         0.02750152 0.06757862
#  0.10339179 0.14018223 0.17490117 0.2152447  0.25481754 0.289497
#  0.32823592 0.3659495  0.40286975 0.44296698 0.48377824 0.51989491
#  0.55517427 0.59180026 0.6253451  0.65941805 0.69195807 0.72710632
#  0.76446938 0.80447577 0.84471364 0.88510726 0.925204   0.96555567
#  1.         1.         1.         1.        ]
# Finish iterating 90 times. 误差值(全部数据点误差之和)(以规范化后的数据计算): 0.04441306335416023
# MSE error: 0.0014804354451386744
# LSPIA 处理文件./data/dataset/v2/validset//teddy330.png.txt完毕。返回结果包括：数据点参数、节点向量、控制顶点。使用GenerateBSplineCurveData来获取数据
# ##############################
# 前90次迭代的MSE误差(规范化数据):[6.42002837e+00 4.20920004e+00 3.05808345e+00 2.27383947e+00
#  1.70967662e+00 1.29519866e+00 9.87135132e-01 7.56298515e-01
#  5.82192577e-01 4.50125190e-01 3.49430617e-01 2.72294528e-01
#  2.12948444e-01 1.67105921e-01 1.31562598e-01 1.03909662e-01
#  8.23268888e-02 6.54320928e-02 5.21708897e-02 4.17354898e-02
#  3.35045289e-02 2.69982422e-02 2.18448930e-02 1.77555054e-02
#  1.45047543e-02 1.19164487e-02 9.85245531e-03 8.20421375e-03
#  6.88621163e-03 5.83094926e-03 4.98504067e-03 4.30618507e-03
#  3.76080766e-03 3.32221678e-03 2.96916075e-03 2.68469520e-03
#  2.45529189e-03 2.27013631e-03 2.12057292e-03 1.99966621e-03
#  1.90185287e-03 1.82266562e-03 1.75851377e-03 1.70650842e-03
#  1.66432322e-03 1.63008314e-03 1.60227570e-03 1.57967985e-03
#  1.56130903e-03 1.54636561e-03 1.53420417e-03 1.52430214e-03
#  1.51623613e-03 1.50966287e-03 1.50430389e-03 1.49993315e-03
#  1.49636707e-03 1.49345644e-03 1.49107999e-03 1.48913903e-03
#  1.48755326e-03 1.48625729e-03 1.48519785e-03 1.48433155e-03
#  1.48362298e-03 1.48304328e-03 1.48256891e-03 1.48218063e-03
#  1.48186276e-03 1.48160247e-03 1.48138929e-03 1.48121467e-03
#  1.48107160e-03 1.48095436e-03 1.48085828e-03 1.48077952e-03
#  1.48071495e-03 1.48066202e-03 1.48061860e-03 1.48058300e-03
#  1.48055380e-03 1.48052984e-03 1.48051019e-03 1.48049406e-03
#  1.48048083e-03 1.48046997e-03 1.48046106e-03 1.48045375e-03
#  1.48044774e-03 1.48044281e-03]
# television225.png.txt
# television225.png.txt
# ******************************
# LSPIA方法处理文件./data/dataset/v2/validset//television225.png.txt中......
# number of data points: 183
# init number of control points: 30
# parameters of original data(183): [0.         0.00531728 0.01078979 0.0176495  0.0245092  0.0313689
#  0.03679198 0.04221505 0.04763812 0.0540234  0.05955375 0.06497682
#  0.07039989 0.07582297 0.08124604 0.08666911 0.09209031 0.09751338
#  0.10293645 0.10835953 0.1137826  0.11920567 0.12462874 0.13072982
#  0.13626364 0.14168672 0.14710979 0.15253286 0.15795593 0.163379
#  0.16892382 0.17514062 0.18056369 0.18598676 0.19140983 0.1968329
#  0.20373343 0.20905071 0.21447191 0.21989498 0.22531805 0.23074112
#  0.23617668 0.24161894 0.24693622 0.2522535  0.25757078 0.26288807
#  0.26820535 0.27352263 0.27883991 0.2841572  0.28947448 0.29479176
#  0.30010904 0.30542633 0.31089884 0.31632191 0.32174498 0.32716805
#  0.33259112 0.3380142  0.34343727 0.34886034 0.35428341 0.35970648
#  0.36512955 0.37055263 0.3759757  0.38139877 0.38682184 0.39224491
#  0.39766798 0.40308919 0.40840647 0.41372375 0.41904103 0.42435831
#  0.4296756  0.43499288 0.44031016 0.44562744 0.45094473 0.45626201
#  0.46157929 0.46800533 0.4734284  0.47885147 0.48427455 0.48969762
#  0.49512069 0.50054376 0.50597932 0.5112966  0.51661388 0.52193117
#  0.52740368 0.53282675 0.53824982 0.54367289 0.54909596 0.55451904
#  0.55994211 0.56536518 0.57078825 0.57621132 0.58163439 0.5870556
#  0.59247867 0.59790174 0.60332481 0.60874788 0.61417095 0.61959403
#  0.6250171  0.63044017 0.63586324 0.64251193 0.64782921 0.65314649
#  0.65861901 0.66404208 0.66946515 0.67488822 0.68031129 0.68573437
#  0.69115744 0.69658051 0.70200358 0.70742665 0.71284972 0.71827093
#  0.723694   0.72911707 0.73454014 0.73996321 0.74538628 0.75080936
#  0.75623243 0.7616555  0.76707857 0.77372726 0.77904454 0.78437615
#  0.78979922 0.79522229 0.80064536 0.80606844 0.81149151 0.81691458
#  0.82377428 0.83063399 0.83605706 0.84148013 0.84691569 0.85224729
#  0.85802035 0.86363366 0.86924697 0.87467004 0.88009311 0.88551618
#  0.89104867 0.89658116 0.90200423 0.9074273  0.91285038 0.91827345
#  0.92369652 0.92911959 0.93454266 0.93996573 0.94538881 0.95081188
#  0.95623495 0.96165802 0.96727133 0.97288464 0.97830771 0.98373079
#  0.98915386 0.99457693 1.        ]
# init knot vector(34): [0.         0.         0.         0.         0.03558685 0.07341271
#  0.11016722 0.14771235 0.1853842  0.22351036 0.25993402 0.29597338
#  0.33259112 0.3693475  0.40604323 0.44208259 0.47945404 0.51602307
#  0.55271135 0.58946585 0.62622222 0.66404208 0.70079845 0.73755296
#  0.77549969 0.81209407 0.85165489 0.88920451 0.92610677 0.96290542
#  1.         1.         1.         1.        ]
# Finish iterating 205 times. 误差值(全部数据点误差之和)(以规范化后的数据计算): 2.15191826224893
# MSE error: 0.071730608741631
# LSPIA 处理文件./data/dataset/v2/validset//television225.png.txt完毕。返回结果包括：数据点参数、节点向量、控制顶点。使用GenerateBSplineCurveData来获取数据
# ##############################
# 前100次迭代的MSE误差(规范化数据):[11.39829401  7.86714085  6.35318695  5.27658254  4.44506631  3.78127327
#   3.24054173  2.79356367  2.41994038  2.10491197  1.83746304  1.60915698
#   1.41339046  1.24490109  1.09943253  0.9735002   0.86422298  0.76919928
#   0.68641377  0.61416585  0.5510137   0.49573007  0.44726677  0.40472582
#   0.36733599  0.33443329  0.30544492  0.27987579  0.25729725  0.23733758
#   0.21967395  0.20402561  0.19014811  0.17782829  0.16688013  0.15714105
#   0.14846884  0.14073898  0.13384228  0.12768297  0.12217692  0.11725016
#   0.11283759  0.10888189  0.10533251  0.10214484  0.09927947  0.09670157
#   0.09438031  0.09228838  0.09040157  0.0886984   0.08715978  0.08576874
#   0.08451019  0.08337067  0.0823382   0.08140207  0.08055273  0.07978163
#   0.07908112  0.07844435  0.07786519  0.07733813  0.07685822  0.076421
#   0.0760225   0.07565909  0.07532753  0.07502491  0.07474856  0.07449612
#   0.07426542  0.07405451  0.07386163  0.07368517  0.07352368  0.07337585
#   0.07324048  0.07311648  0.07300288  0.07289877  0.07280333  0.07271583
#   0.07263558  0.07256197  0.07249444  0.07243247  0.0723756   0.07232339
#   0.07227546  0.07223145  0.07219104  0.07215392  0.07211982  0.07208849
#   0.0720597   0.07203325  0.07200894  0.0719866 ]
# guitar005.png.txt
# guitar005.png.txt
# ******************************
# LSPIA方法处理文件./data/dataset/v2/validset//guitar005.png.txt中......
# number of data points: 67
# init number of control points: 30
# parameters of original data(67): [0.         0.01187942 0.02713326 0.04380234 0.06007018 0.0760063
#  0.08960901 0.10321173 0.11509114 0.13135898 0.14952982 0.16952782
#  0.1896001  0.20419703 0.21607644 0.22795586 0.23983528 0.25171469
#  0.26359411 0.27991134 0.29179076 0.30390069 0.32125592 0.33313534
#  0.34501475 0.36318559 0.38316489 0.39906296 0.41094238 0.42553931
#  0.43741872 0.44929814 0.46117755 0.47305697 0.48493639 0.49704632
#  0.50915626 0.52103568 0.53291509 0.54479451 0.55667393 0.56940628
#  0.58676151 0.6067595  0.62302734 0.64119818 0.65623871 0.67161614
#  0.68349556 0.69887299 0.71514083 0.73051827 0.74325062 0.75827703
#  0.77473911 0.79100695 0.80917779 0.82925008 0.84924807 0.86924606
#  0.88921911 0.90919215 0.9292212  0.94929348 0.96746432 0.98373216
#  1.        ]
# init knot vector(34): [0.         0.         0.         0.         0.01922386 0.05946766
#  0.09565466 0.13015396 0.17770541 0.21475651 0.24423506 0.27749397
#  0.30968577 0.34281486 0.38787543 0.42229554 0.45237799 0.48185654
#  0.51179613 0.54127468 0.57262021 0.61760473 0.65851684 0.69317765
#  0.73193297 0.76803234 0.81066463 0.86035806 0.90993397 0.9587154
#  1.         1.         1.         1.        ]
# Finish iterating 53 times. 误差值(全部数据点误差之和)(以规范化后的数据计算): 0.05800765945759401
# MSE error: 0.0019335886485864668
# LSPIA 处理文件./data/dataset/v2/validset//guitar005.png.txt完毕。返回结果包括：数据点参数、节点向量、控制顶点。使用GenerateBSplineCurveData来获取数据
# ##############################
# 前53次迭代的MSE误差(规范化数据):[4.08827910e+00 1.79512174e+00 9.31779713e-01 5.09122677e-01
#  2.86013547e-01 1.63576875e-01 9.48586164e-02 5.57447434e-02
#  3.32704838e-02 2.02686407e-02 1.27066692e-02 8.28899627e-03
#  5.69802736e-03 4.17281961e-03 3.27174931e-03 2.73745662e-03
#  2.41941884e-03 2.22930707e-03 2.11512590e-03 2.04617419e-03
#  2.00426874e-03 1.97860636e-03 1.96274732e-03 1.95283914e-03
#  1.94656796e-03 1.94253776e-03 1.93990190e-03 1.93814373e-03
#  1.93694570e-03 1.93611089e-03 1.93551592e-03 1.93508254e-03
#  1.93476036e-03 1.93451643e-03 1.93432876e-03 1.93418242e-03
#  1.93406700e-03 1.93397512e-03 1.93390144e-03 1.93384199e-03
#  1.93379380e-03 1.93375458e-03 1.93372255e-03 1.93369634e-03
#  1.93367484e-03 1.93365718e-03 1.93364264e-03 1.93363066e-03
#  1.93362077e-03 1.93361261e-03 1.93360586e-03 1.93360028e-03
#  1.93359566e-03]
# toilet140.png.txt
# toilet140.png.txt
# ******************************
# LSPIA方法处理文件./data/dataset/v2/validset//toilet140.png.txt中......
# number of data points: 123
# init number of control points: 30
# parameters of original data(123): [0.         0.00710846 0.01438734 0.0214958  0.02860426 0.03711977
#  0.04422823 0.05133669 0.06094601 0.06805447 0.07597243 0.08308089
#  0.09035977 0.09746823 0.10574456 0.11443157 0.12339222 0.13235287
#  0.14075337 0.14915387 0.15821914 0.16594809 0.17490874 0.18383369
#  0.19275864 0.20168358 0.21060853 0.2189483  0.22788222 0.23694748
#  0.24534799 0.25325975 0.26103481 0.26876377 0.27604265 0.28332152
#  0.2906004  0.29787928 0.30498774 0.3120962  0.31920466 0.32828227
#  0.33679778 0.34407665 0.35135553 0.35963186 0.36839656 0.37617162
#  0.38328008 0.39038854 0.39945381 0.40837876 0.4173037  0.42622865
#  0.4351536  0.44407855 0.45300349 0.46192844 0.47085339 0.47977833
#  0.48870328 0.49848007 0.50650124 0.51543515 0.52383565 0.53161071
#  0.53997138 0.54774644 0.55608622 0.56510434 0.57301611 0.58092788
#  0.58870294 0.596478   0.60420695 0.61352898 0.62063744 0.62778966
#  0.63570142 0.64361319 0.65138825 0.65978875 0.66770052 0.67739041
#  0.68635106 0.69531171 0.70423666 0.71316161 0.72208655 0.7310472
#  0.73998111 0.74891503 0.75783997 0.76676492 0.77568987 0.78465052
#  0.79361116 0.80232959 0.80948181 0.81788231 0.82726116 0.83517293
#  0.84347174 0.8513835  0.85915856 0.86693362 0.87470869 0.88243764
#  0.8901666  0.89789555 0.90580732 0.91420782 0.92260833 0.93132675
#  0.93972726 0.94802606 0.95593783 0.96366678 0.97094566 0.97867462
#  0.98578308 0.99289154 1.        ]
# init knot vector(34): [0.         0.         0.         0.         0.02544494 0.06173584
#  0.09509874 0.13421964 0.17291749 0.21338846 0.25238067 0.28655658
#  0.31920466 0.35595349 0.39139579 0.43217862 0.47283671 0.51344984
#  0.55052637 0.58783904 0.6238162  0.65978875 0.70027002 0.74097377
#  0.78166363 0.8199665  0.85743077 0.89274292 0.93035804 0.96690184
#  1.         1.         1.         1.        ]
# Finish iterating 76 times. 误差值(全部数据点误差之和)(以规范化后的数据计算): 0.12104321394236779
# MSE error: 0.004034773798078926
# LSPIA 处理文件./data/dataset/v2/validset//toilet140.png.txt完毕。返回结果包括：数据点参数、节点向量、控制顶点。使用GenerateBSplineCurveData来获取数据
# ##############################
# 前76次迭代的MSE误差(规范化数据):[7.89582340e+00 4.96219845e+00 3.42828764e+00 2.43028978e+00
#  1.74878301e+00 1.27124350e+00 9.31185113e-01 6.86301491e-01
#  5.08474137e-01 3.78488655e-01 2.82962014e-01 2.12441535e-01
#  1.60178713e-01 1.21314533e-01 9.23261510e-02 7.06446909e-02
#  5.43877015e-02 4.21698655e-02 3.29678953e-02 2.60234022e-02
#  2.07726306e-02 1.67953600e-02 1.37775710e-02 1.14840584e-02
#  9.73826676e-03 8.40739468e-03 7.39135935e-03 6.61459749e-03
#  6.01995882e-03 5.56414711e-03 5.21430926e-03 4.94547796e-03
#  4.73865059e-03 4.57934346e-03 4.45650178e-03 4.36167647e-03
#  4.28840150e-03 4.23172214e-03 4.18783698e-03 4.15382602e-03
#  4.12744359e-03 4.10696072e-03 4.09104476e-03 4.07866743e-03
#  4.06903445e-03 4.06153173e-03 4.05568397e-03 4.05112297e-03
#  4.04756325e-03 4.04478324e-03 4.04261084e-03 4.04091226e-03
#  4.03958344e-03 4.03854333e-03 4.03772880e-03 4.03709062e-03
#  4.03659038e-03 4.03619809e-03 4.03589033e-03 4.03564880e-03
#  4.03545917e-03 4.03531023e-03 4.03519321e-03 4.03510125e-03
#  4.03502895e-03 4.03497210e-03 4.03492737e-03 4.03489219e-03
#  4.03486449e-03 4.03484269e-03 4.03482553e-03 4.03481201e-03
#  4.03480136e-03 4.03479297e-03 4.03478636e-03 4.03478115e-03]
# LSPIA 总用时8.2 秒

# %% [markdown]
# # SplineCNN

# %% [markdown]
# # NeuroNURBS
